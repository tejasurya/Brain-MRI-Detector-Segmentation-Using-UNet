# %% [markdown]
# <a href="https://www.kaggle.com/code/tejasurya/unet-from-scratch-segmentation-tumour?scriptVersionId=131333196" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="background-color:red;color:white;font-size:22px;text-align:center;border-radius:10px 10px;font-weight:bold;border:2px solid black">Brain MRI Detector | Segmentation | Using UNet</p>
#
# <center><img src= "https://www.mayoclinic.org/-/media/kcms/gbs/patient-consumer/images/2014/10/30/15/17/mcdc7_brain_cancer-8col.jpg" alt ="Brain-MRI" style='width:300px;'></center>
#
# **Image source** : Mayo Clinic

# %% [markdown]
# # Quick Index
#
# * [Introduction](#1)
# * [What is Image Segmentation?](#1.1)
# * [EDA](#2)
# * [Image Visualization](#2.1)
# * [Data Generator](#3)
# * [Build UNet](#4)
#     * [UNet Architecture](#4.1)
# * [UNet Implementation](#5)
#     * [Callbacks](#5.1)
#     * [Performance Metrics](#5.2)
#     * [Model Fit](#5.3)
#     * [Save UNet Model](#5.4)
# * [Evaluation](#6)
# * [Prediction](#7)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Introduction</span> <a id=1></a>
# A brain tumor is a mass or growth of abnormal cells in your brain.Many different types of brain tumors exist. Some brain tumors are noncancerous (benign), and some brain tumors are cancerous (malignant). Brain tumors can begin in your brain (primary brain tumors), or cancer can begin in other parts of your body and spread to your brain as secondary (metastatic) brain tumors.
#
# How quickly a brain tumor grows can vary greatly. The growth rate as well as the location of a brain tumor determines how it will affect the function of your nervous system.
#
# Brain tumor treatment options depend on the type of brain tumor you have, as well as its size and location. <br>
# **Source credits** : [Mayo Clinic](https://www.mayoclinic.org/diseases-conditions/brain-tumor/symptoms-causes/syc-20350084)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">What is Image Segmentation?</span> <a id=1.1></a> <br>
#  *  The objective of the Image Segmentation is to classify each pixel of an image with the class it represents, by predicting each pixel in image. <br>
#  *  Here in this notebook,we will implement the U-Net model, its a U-shaped architecture (in keras).
# We will also apply our model to a Brain MRI tumor detection problem to see how it performs.

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Import Libraries</span> <a id=1.1.1></a> <br>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import glob

import time
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
from IPython.display import Image
from skimage import io

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.layers.experimental import preprocessing
from keras.utils.vis_utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
import cv2
from sklearn.preprocessing import StandardScaler, normalize
from IPython.display import display

# %%
img_data = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
img_data.head()
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0

# %%
img_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
img_data.shape
# Out:
# (110, 18)

# %%
data_path = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            mask_path = sub_dir_path + '/' + filename
            data_path.extend([dir_name, mask_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
filenames = data_path[::2]
masks = data_path[1::2]

# %%
df = pd.DataFrame(data={"patient_id": filenames,"img_path": masks})
df
# Out:
#                  patient_id                                           img_path
# 0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                     ...                                                ...
# 7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [7858 rows x 2 columns]

# %%
original_img     = df[~df['img_path'].str.contains("mask")]
mask_img = df[df['img_path'].str.contains("mask")]

# %%
original_img,mask_img
# Out:
# (                 patient_id                                           img_path
#  0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  5     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7849  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7850  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7852  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns],
#                   patient_id                                           img_path
#  1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  8     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  9     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  11    TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7846  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7851  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns])

# %%
imgs = sorted(original_img["img_path"].values, key=lambda x : int(x[89:-4]))
masks = sorted(mask_img["img_path"].values, key=lambda x : int(x[89:-9]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Image path:", imgs[idx], "\nMask path:", masks[idx])
# Out:
# Image path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_8166_19970322/TCGA_DU_8166_19970322_18.tif
# Mask path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_8166_19970322/TCGA_DU_8166_19970322_18_mask.tif

# %%
mri_df = pd.DataFrame({"patient_id": original_img.patient_id.values,"img_path": imgs,
                           'mask_path':masks})
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [3929 rows x 3 columns]

# %%
def get_diagnosis(img_path):
    value = np.max(cv2.imread(img_path))
    if value > 0 : 
        return 1
    else:
        return 0

# %%
mri_df.head()
# Out:
#               patient_id                                           img_path  \
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
mri_df['mask'] = mri_df['mask_path'].apply(lambda x: get_diagnosis(x))

mri_df['mask_path'] = mri_df['mask_path'].apply(lambda x: str(x))
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# ...                                                 ...   ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
# [3929 rows x 4 columns]

# %%
mri_df.drop(columns=['patient_id'],inplace=True)

# %%
mri_train, mri_test = train_test_split(mri_df,test_size = 0.1)
mri_train, mri_val = train_test_split(mri_train,test_size = 0.2)

print('Training data shape is {0}'.format(mri_train.values.shape))
print('Test data shape is {0}'.format(mri_test.values.shape))
mri_train.sample(n=5)
# Out:
# Training data shape is (2828, 3)
# Test data shape is (393, 3)
#                                                img_path  \
# 2963  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1400  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2089  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1872  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3429  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 2963  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1400  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 2089  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 1872  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 3429  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0

# %% [markdown]
# # <h2 class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">EDA</h2> <a id=2></a> <br>
#
# Check Balancing in Data

# %%
mri_df['mask'].value_counts().plot(kind='bar',color=['g','r'],
                title='Count of Tumour vs No Tumour')
# Out:
# <AxesSubplot:title={'center':'Count of Tumour vs No Tumour'}>

# %%
mri_df['mask'].value_counts()
# Out:
# 0    2556
# 1    1373
# Name: mask, dtype: int64

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Image Visualization</span> <a id=2.1></a> <br>
#
# Visualising the Brain MRI with Tumour

# %%
count = 0
i = 0
fig,axs = plt.subplots(3,3, figsize=(20,15))
for mask in mri_df['mask']:
    if (mask==1):
        img = io.imread(mri_df.img_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(mri_df.mask_path[i])
        axs[count][1].title.set_text("Mask =" + str(mri_df['mask'][i]))
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (255,0,0)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask =" + str(mri_df['mask'][i]))
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==3):
        break
        
fig.tight_layout()

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Data Generator</span> <a id=3></a> <br>
# ### Reference : **[UNet](https://github.com/zhixuhao/unet)**

# %%
from keras_preprocessing.image import ImageDataGenerator

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "img_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

# %%
def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(mri_train, 32,
                                train_generator_args,
                                target_size=(256, 256))
    
val_gen = train_generator(mri_val, 32,
                                dict(),
                                target_size=(256, 256))

# %% [markdown]
# # <p style="color:#FF0000;background-color:white;font-size:25px">Build UNet Model</span> <a id=4></a> <br>
#
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Architecture</span> <a id=4.1></a>
#
# <center><img src= "https://miro.medium.com/max/1200/1*f7YOaE4TWubwaFF7Z1fzNw.png" alt ="UNet" style='width:800px;'></center>

# %% [markdown]
# UNet is named after the shape of it's architecture (U - shaped). UNet model is used to solve Image Segmentation problems especially in Medical related problems.
#
# The input layer has 572x572x1 dimension in the above architecture. The 1 column dimension specifies the input is b/w image. If the input dimension was 572x572x3 , the input image is rgb coloured image.
# After the input layer,we can divide this UNet architecture into 4 parts
# * Encoder Part (Contracting path)
# * Upsampling2D
# * Decoder part (Expanding Path)
# * Skip Connection (Residual connection)
#
#
# Briefly into the Details of these parts: <br>
# **Encoder Part**
# The initial half of the U-shaped architecture is the Contracting path(Encoder part). As the name Contracting path denotes, the dimension of the input image keeps reducing as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=64 followed by Maxpool2D layer (reduces size divided by 2). Now again 2 - Conv2D layers (128 filters) and 1 Maxpooling2D , 2 - Conv2D layers (256 filters) and 1 Maxpooling2D completely contracts the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Upsampling2D**
# The Upsampling2D layer upsamples the layer output dimension by duplicating the row values twice.The concatenation of the upsampling2D and contracting path happens here leading into the Expanding path.
# The Upsampling layer is present after 2 conv2D layers in Decoder part, similar to presence of  Maxpooling as in Encoder part.
#
# **Decoder Path**
# The second half of the U-shaped architecture is the Expanding path(Decoder part). As the name Expanding path denotes, the dimension of the image keeps expanding as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=512 followed by Upsampling2D layer (duplicates size divided by 2). Now again 2 - Conv2D layers (256 filters) and 1 Upsampling2D ,2 - Conv2D layers (128 filters) and 1 Upsampling2D, 2 - Conv2D layers (64 filters) completely expands the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Skip Connection (Residual connection)**
# The Skip Connection (Residual connection) alias the identity mapping is present after each of the 2 Conv2D layers in Encoder to the corresponding same shaped dimension layer in the Decoder part . In the above architecture the copy and crop does residual connection task.The Concatenate layer does the work of adding those two layers. This skip connection doesnot harm the model in any way even in worst case but definitely benificial to the output in the model.
#
# Finally the decoder part ends with the Output Segmentation map with filters 2. This layer is again passed through a Conv2D with Sigmoid activation and filters 1. The output classifies each pixel if tumour is present or not in it.
#
# **UNet Model build**
# Here in the model built below, after each of second Convolutional layer,Batch Normalization layer with axis=3 is added to prevent "internal covariance shift" , the Activation layer "relu" is added here instead of that second Convolutional layer.
#
# ### Reference : [UNet](https://github.com/zhixuhao/unet)

# %%
def unet(pretrained_weights = None,input_size = (256,256,3)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv1)
    bn_1 = BatchNormalization(axis=3)(conv1)
    act_1 = Activation('relu')(bn_1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(act_1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    bn_2 = BatchNormalization(axis=3)(conv2)
    act_2 = Activation('relu')(bn_2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(act_2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv3)
    bn_3 = BatchNormalization(axis=3)(conv3)
    act_3 = Activation('relu')(bn_3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(act_3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv4)
    bn_4 = BatchNormalization(axis=3)(conv4)
    act_4 = Activation('relu')(bn_4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(act_4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv5)
    bn_5 = BatchNormalization(axis=3)(conv5)
    act_5 = Activation('relu')(bn_5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv6)
    bn_6 = BatchNormalization(axis=3)(conv6)
    act_6 = Activation('relu')(bn_6)
    
    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv7)
    bn_7 = BatchNormalization(axis=3)(conv7)
    act_7 = Activation('relu')(bn_7)

    
    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv8)
    bn_8 = BatchNormalization(axis=3)(conv8)
    act_8 = Activation('relu')(bn_8)
    
    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv9)
    bn_9 = BatchNormalization(axis=3)(conv9)
    act_9 = Activation('relu')(bn_9)
    
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(act_9)

    model = model = Model(inputs=[inputs] , outputs = [conv10])    
    return model

# %%
model = unet()
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 256, 2)  8           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 2)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 1)  3           activation_8[0][0]
# ==================================================================================================
# Total params: 31,044,365
# Trainable params: 31,038,601
# Non-trainable params: 5,764
# __________________________________________________________________________________________________

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Model architecture</span> <a id=5></a>

# %%
plot_model(model, to_file='unet_model.png', show_shapes=True)
Image("unet_model.png")

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Callbacks</span> <a id=5.1></a> <br>
#
# The Callbacks used are
# * Learning Rate reduction
# * Early Stopping
# * Model Checkpoint

# %%
lr_reduction = ReduceLROnPlateau(monitor='val_iou',patience=8, verbose=1,
                                 factor=0.4, min_lr=0.0001)

early_stop = EarlyStopping(monitor='val_iou', min_delta=0.00001, patience=6, 
                           mode='auto', restore_best_weights=True)

model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', verbose=1,monitor='val_iou',
                                   save_best_only=True)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Performance Metrics</span> <a id=5.2></a>

# %%
smooth =100
def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Model Fit</span> <a id=5.3></a>

# %%
EPOCH = 100
learning_rate = 1e-3

# %%
model.compile(optimizer=Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-3/32, amsgrad=False), 
              loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

# %%
history = model.fit(train_gen,steps_per_epoch=len(mri_train)/32,
                    epochs=EPOCH ,validation_data=val_gen,validation_steps=len(mri_val) / 32,
                    callbacks=[model_checkpoint])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# Epoch 1/100
# 89/88 [==============================] - ETA: 0s - loss: 0.9699 - binary_accuracy: 0.9894 - iou: 0.0153 - dice_coef: 0.0299Found 708 validated image filenames.
# Found 708 validated image filenames.
# 88/88 [==============================] - 131s 1s/step - loss: 0.9699 - binary_accuracy: 0.9894 - iou: 0.0153 - dice_coef: 0.0299 - val_loss: 0.9815 - val_binary_accuracy: 0.9907 - val_iou: 0.0091 - val_dice_coef: 0.0179
#
# Epoch 00001: val_iou improved from inf to 0.00910, saving model to unet_membrane.hdf5
# Epoch 2/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9653 - binary_accuracy: 0.9894 - iou: 0.0178 - dice_coef: 0.0347 - val_loss: 0.9628 - val_binary_accuracy: 0.9906 - val_iou: 0.0191 - val_dice_coef: 0.0370
#
# Epoch 00002: val_iou did not improve from 0.00910
# Epoch 3/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9641 - binary_accuracy: 0.9894 - iou: 0.0185 - dice_coef: 0.0360 - val_loss: 0.9666 - val_binary_accuracy: 0.9905 - val_iou: 0.0174 - val_dice_coef: 0.0340
#
# Epoch 00003: val_iou did not improve from 0.00910
# Epoch 4/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9500 - binary_accuracy: 0.9894 - iou: 0.0258 - dice_coef: 0.0500 - val_loss: 0.9439 - val_binary_accuracy: 0.9910 - val_iou: 0.0287 - val_dice_coef: 0.0553
#
# Epoch 00004: val_iou did not improve from 0.00910
# Epoch 5/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9310 - binary_accuracy: 0.9894 - iou: 0.0362 - dice_coef: 0.0692 - val_loss: 0.9014 - val_binary_accuracy: 0.9901 - val_iou: 0.0520 - val_dice_coef: 0.0974
#
# Epoch 00005: val_iou did not improve from 0.00910
# Epoch 6/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9022 - binary_accuracy: 0.9894 - iou: 0.0519 - dice_coef: 0.0976 - val_loss: 0.8526 - val_binary_accuracy: 0.9907 - val_iou: 0.0787 - val_dice_coef: 0.1429
#
# Epoch 00006: val_iou did not improve from 0.00910
# Epoch 7/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.8580 - binary_accuracy: 0.9894 - iou: 0.0782 - dice_coef: 0.1430 - val_loss: 0.8836 - val_binary_accuracy: 0.9911 - val_iou: 0.0634 - val_dice_coef: 0.1176
#
# Epoch 00007: val_iou did not improve from 0.00910
# Epoch 8/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.7912 - binary_accuracy: 0.9894 - iou: 0.1188 - dice_coef: 0.2093 - val_loss: 0.7967 - val_binary_accuracy: 0.9909 - val_iou: 0.1117 - val_dice_coef: 0.1968
#
# Epoch 00008: val_iou did not improve from 0.00910
# Epoch 9/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.7111 - binary_accuracy: 0.9894 - iou: 0.1720 - dice_coef: 0.2900 - val_loss: 0.6571 - val_binary_accuracy: 0.9901 - val_iou: 0.2094 - val_dice_coef: 0.3408
#
# Epoch 00009: val_iou did not improve from 0.00910
# Epoch 10/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.6458 - binary_accuracy: 0.9899 - iou: 0.2195 - dice_coef: 0.3558 - val_loss: 0.8632 - val_binary_accuracy: 0.9109 - val_iou: 0.0731 - val_dice_coef: 0.1346
#
# Epoch 00010: val_iou did not improve from 0.00910
# Epoch 11/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.5723 - binary_accuracy: 0.9915 - iou: 0.2763 - dice_coef: 0.4282 - val_loss: 0.7587 - val_binary_accuracy: 0.9579 - val_iou: 0.1456 - val_dice_coef: 0.2503
#
# Epoch 00011: val_iou did not improve from 0.00910
# Epoch 12/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.5060 - binary_accuracy: 0.9931 - iou: 0.3326 - dice_coef: 0.4941 - val_loss: 0.4803 - val_binary_accuracy: 0.9936 - val_iou: 0.3605 - val_dice_coef: 0.5239
#
# Epoch 00012: val_iou did not improve from 0.00910
# Epoch 13/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.4843 - binary_accuracy: 0.9937 - iou: 0.3528 - dice_coef: 0.5147 - val_loss: 0.4754 - val_binary_accuracy: 0.9946 - val_iou: 0.3495 - val_dice_coef: 0.5071
#
# Epoch 00013: val_iou did not improve from 0.00910
# Epoch 14/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.4561 - binary_accuracy: 0.9939 - iou: 0.3778 - dice_coef: 0.5439 - val_loss: 0.6219 - val_binary_accuracy: 0.9799 - val_iou: 0.2317 - val_dice_coef: 0.3706
#
# Epoch 00014: val_iou did not improve from 0.00910
# Epoch 15/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.4250 - binary_accuracy: 0.9943 - iou: 0.4071 - dice_coef: 0.5736 - val_loss: 0.5219 - val_binary_accuracy: 0.9896 - val_iou: 0.3129 - val_dice_coef: 0.4632
#
# Epoch 00015: val_iou did not improve from 0.00910
# Epoch 16/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.4018 - binary_accuracy: 0.9946 - iou: 0.4316 - dice_coef: 0.5988 - val_loss: 0.4060 - val_binary_accuracy: 0.9953 - val_iou: 0.4382 - val_dice_coef: 0.5976
#
# Epoch 00016: val_iou did not improve from 0.00910
# Epoch 17/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3910 - binary_accuracy: 0.9946 - iou: 0.4437 - dice_coef: 0.6096 - val_loss: 0.4113 - val_binary_accuracy: 0.9956 - val_iou: 0.4166 - val_dice_coef: 0.5800
#
# Epoch 00017: val_iou did not improve from 0.00910
# Epoch 18/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3720 - binary_accuracy: 0.9949 - iou: 0.4623 - dice_coef: 0.6285 - val_loss: 0.3777 - val_binary_accuracy: 0.9946 - val_iou: 0.4434 - val_dice_coef: 0.6018
#
# Epoch 00018: val_iou did not improve from 0.00910
# Epoch 19/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3592 - binary_accuracy: 0.9949 - iou: 0.4782 - dice_coef: 0.6414 - val_loss: 0.3719 - val_binary_accuracy: 0.9961 - val_iou: 0.4596 - val_dice_coef: 0.6213
#
# Epoch 00019: val_iou did not improve from 0.00910
# Epoch 20/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3724 - binary_accuracy: 0.9947 - iou: 0.4647 - dice_coef: 0.6276 - val_loss: 0.4189 - val_binary_accuracy: 0.9919 - val_iou: 0.4141 - val_dice_coef: 0.5800
#
# Epoch 00020: val_iou did not improve from 0.00910
# Epoch 21/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9179 - binary_accuracy: 0.9651 - iou: 0.0461 - dice_coef: 0.0828 - val_loss: 0.7093 - val_binary_accuracy: 0.9660 - val_iou: 0.1828 - val_dice_coef: 0.3031
#
# Epoch 00021: val_iou did not improve from 0.00910
# Epoch 22/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3776 - binary_accuracy: 0.9923 - iou: 0.4633 - dice_coef: 0.6223 - val_loss: 0.3568 - val_binary_accuracy: 0.9959 - val_iou: 0.4850 - val_dice_coef: 0.6486
#
# Epoch 00022: val_iou did not improve from 0.00910
# Epoch 23/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3235 - binary_accuracy: 0.9953 - iou: 0.5153 - dice_coef: 0.6756 - val_loss: 0.9540 - val_binary_accuracy: 0.9826 - val_iou: 0.0536 - val_dice_coef: 0.0758
#
# Epoch 00023: val_iou did not improve from 0.00910
# Epoch 24/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3240 - binary_accuracy: 0.9952 - iou: 0.5181 - dice_coef: 0.6765 - val_loss: 0.3083 - val_binary_accuracy: 0.9961 - val_iou: 0.5486 - val_dice_coef: 0.6971
#
# Epoch 00024: val_iou did not improve from 0.00910
# Epoch 25/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.3071 - binary_accuracy: 0.9954 - iou: 0.5392 - dice_coef: 0.6929 - val_loss: 0.3036 - val_binary_accuracy: 0.9961 - val_iou: 0.5425 - val_dice_coef: 0.6985
#
# Epoch 00025: val_iou did not improve from 0.00910
# Epoch 26/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2954 - binary_accuracy: 0.9957 - iou: 0.5492 - dice_coef: 0.7030 - val_loss: 0.2842 - val_binary_accuracy: 0.9963 - val_iou: 0.5739 - val_dice_coef: 0.7205
#
# Epoch 00026: val_iou did not improve from 0.00910
# Epoch 27/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2914 - binary_accuracy: 0.9956 - iou: 0.5556 - dice_coef: 0.7092 - val_loss: 0.2769 - val_binary_accuracy: 0.9965 - val_iou: 0.5768 - val_dice_coef: 0.7281
#
# Epoch 00027: val_iou did not improve from 0.00910
# Epoch 28/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2791 - binary_accuracy: 0.9958 - iou: 0.5677 - dice_coef: 0.7206 - val_loss: 0.2677 - val_binary_accuracy: 0.9966 - val_iou: 0.5888 - val_dice_coef: 0.7371
#
# Epoch 00028: val_iou did not improve from 0.00910
# Epoch 29/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2716 - binary_accuracy: 0.9958 - iou: 0.5792 - dice_coef: 0.7286 - val_loss: 0.3219 - val_binary_accuracy: 0.9954 - val_iou: 0.5248 - val_dice_coef: 0.6833
#
# Epoch 00029: val_iou did not improve from 0.00910
# Epoch 30/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2704 - binary_accuracy: 0.9958 - iou: 0.5805 - dice_coef: 0.7296 - val_loss: 0.2681 - val_binary_accuracy: 0.9967 - val_iou: 0.5718 - val_dice_coef: 0.7189
#
# Epoch 00030: val_iou did not improve from 0.00910
# Epoch 31/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2551 - binary_accuracy: 0.9961 - iou: 0.6014 - dice_coef: 0.7449 - val_loss: 0.2541 - val_binary_accuracy: 0.9965 - val_iou: 0.6111 - val_dice_coef: 0.7502
#
# Epoch 00031: val_iou did not improve from 0.00910
# Epoch 32/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2502 - binary_accuracy: 0.9961 - iou: 0.6068 - dice_coef: 0.7503 - val_loss: 0.2806 - val_binary_accuracy: 0.9965 - val_iou: 0.5745 - val_dice_coef: 0.7251
#
# Epoch 00032: val_iou did not improve from 0.00910
# Epoch 33/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2338 - binary_accuracy: 0.9964 - iou: 0.6259 - dice_coef: 0.7665 - val_loss: 0.2311 - val_binary_accuracy: 0.9971 - val_iou: 0.6376 - val_dice_coef: 0.7741
#
# Epoch 00033: val_iou did not improve from 0.00910
# Epoch 34/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2372 - binary_accuracy: 0.9962 - iou: 0.6221 - dice_coef: 0.7623 - val_loss: 0.2221 - val_binary_accuracy: 0.9967 - val_iou: 0.6368 - val_dice_coef: 0.7677
#
# Epoch 00034: val_iou did not improve from 0.00910
# Epoch 35/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2239 - binary_accuracy: 0.9964 - iou: 0.6404 - dice_coef: 0.7761 - val_loss: 0.2150 - val_binary_accuracy: 0.9973 - val_iou: 0.6539 - val_dice_coef: 0.7872
#
# Epoch 00035: val_iou did not improve from 0.00910
# Epoch 36/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2259 - binary_accuracy: 0.9964 - iou: 0.6380 - dice_coef: 0.7740 - val_loss: 0.2397 - val_binary_accuracy: 0.9964 - val_iou: 0.6245 - val_dice_coef: 0.7640
#
# Epoch 00036: val_iou did not improve from 0.00910
# Epoch 37/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2160 - binary_accuracy: 0.9965 - iou: 0.6497 - dice_coef: 0.7838 - val_loss: 0.2473 - val_binary_accuracy: 0.9963 - val_iou: 0.6138 - val_dice_coef: 0.7559
#
# Epoch 00037: val_iou did not improve from 0.00910
# Epoch 38/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2154 - binary_accuracy: 0.9966 - iou: 0.6494 - dice_coef: 0.7803 - val_loss: 0.2196 - val_binary_accuracy: 0.9970 - val_iou: 0.6462 - val_dice_coef: 0.7821
#
# Epoch 00038: val_iou did not improve from 0.00910
# Epoch 39/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2103 - binary_accuracy: 0.9966 - iou: 0.6582 - dice_coef: 0.7894 - val_loss: 0.1962 - val_binary_accuracy: 0.9969 - val_iou: 0.6680 - val_dice_coef: 0.7990
#
# Epoch 00039: val_iou did not improve from 0.00910
# Epoch 40/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9018 - binary_accuracy: 0.9704 - iou: 0.0553 - dice_coef: 0.0981 - val_loss: 0.6891 - val_binary_accuracy: 0.9792 - val_iou: 0.1832 - val_dice_coef: 0.2998
#
# Epoch 00040: val_iou did not improve from 0.00910
# Epoch 41/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2834 - binary_accuracy: 0.9927 - iou: 0.5750 - dice_coef: 0.7160 - val_loss: 0.2171 - val_binary_accuracy: 0.9970 - val_iou: 0.6329 - val_dice_coef: 0.7634
#
# Epoch 00041: val_iou did not improve from 0.00910
# Epoch 42/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2230 - binary_accuracy: 0.9962 - iou: 0.6418 - dice_coef: 0.7777 - val_loss: 0.2047 - val_binary_accuracy: 0.9970 - val_iou: 0.6622 - val_dice_coef: 0.7945
#
# Epoch 00042: val_iou did not improve from 0.00910
# Epoch 43/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2092 - binary_accuracy: 0.9966 - iou: 0.6596 - dice_coef: 0.7909 - val_loss: 0.2768 - val_binary_accuracy: 0.9965 - val_iou: 0.5841 - val_dice_coef: 0.7293
#
# Epoch 00043: val_iou did not improve from 0.00910
# Epoch 44/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.9438 - binary_accuracy: 0.9683 - iou: 0.0303 - dice_coef: 0.0558 - val_loss: 0.8756 - val_binary_accuracy: 0.9789 - val_iou: 0.0991 - val_dice_coef: 0.1499
#
# Epoch 00044: val_iou did not improve from 0.00910
# Epoch 45/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.2931 - binary_accuracy: 0.9930 - iou: 0.5712 - dice_coef: 0.7077 - val_loss: 0.2486 - val_binary_accuracy: 0.9960 - val_iou: 0.6207 - val_dice_coef: 0.7593
#
# Epoch 00045: val_iou did not improve from 0.00910
# Epoch 46/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1981 - binary_accuracy: 0.9966 - iou: 0.6744 - dice_coef: 0.8026 - val_loss: 0.2637 - val_binary_accuracy: 0.9964 - val_iou: 0.6000 - val_dice_coef: 0.7432
#
# Epoch 00046: val_iou did not improve from 0.00910
# Epoch 47/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1964 - binary_accuracy: 0.9966 - iou: 0.6775 - dice_coef: 0.8040 - val_loss: 0.1940 - val_binary_accuracy: 0.9971 - val_iou: 0.6851 - val_dice_coef: 0.8092
#
# Epoch 00047: val_iou did not improve from 0.00910
# Epoch 48/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1839 - binary_accuracy: 0.9968 - iou: 0.6934 - dice_coef: 0.8158 - val_loss: 0.1911 - val_binary_accuracy: 0.9971 - val_iou: 0.6839 - val_dice_coef: 0.8104
#
# Epoch 00048: val_iou did not improve from 0.00910
# Epoch 49/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1748 - binary_accuracy: 0.9970 - iou: 0.7073 - dice_coef: 0.8249 - val_loss: 0.1775 - val_binary_accuracy: 0.9975 - val_iou: 0.6975 - val_dice_coef: 0.8195
#
# Epoch 00049: val_iou did not improve from 0.00910
# Epoch 50/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1734 - binary_accuracy: 0.9970 - iou: 0.7065 - dice_coef: 0.8251 - val_loss: 0.1928 - val_binary_accuracy: 0.9971 - val_iou: 0.6732 - val_dice_coef: 0.8025
#
# Epoch 00050: val_iou did not improve from 0.00910
# Epoch 51/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1796 - binary_accuracy: 0.9969 - iou: 0.7025 - dice_coef: 0.8202 - val_loss: 0.1746 - val_binary_accuracy: 0.9974 - val_iou: 0.7092 - val_dice_coef: 0.8276
#
# Epoch 00051: val_iou did not improve from 0.00910
# Epoch 52/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1705 - binary_accuracy: 0.9970 - iou: 0.7136 - dice_coef: 0.8289 - val_loss: 0.1837 - val_binary_accuracy: 0.9971 - val_iou: 0.7040 - val_dice_coef: 0.8218
#
# Epoch 00052: val_iou did not improve from 0.00910
# Epoch 53/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1672 - binary_accuracy: 0.9971 - iou: 0.7192 - dice_coef: 0.8326 - val_loss: 0.1720 - val_binary_accuracy: 0.9976 - val_iou: 0.6968 - val_dice_coef: 0.8135
#
# Epoch 00053: val_iou did not improve from 0.00910
# Epoch 54/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1668 - binary_accuracy: 0.9970 - iou: 0.7185 - dice_coef: 0.8326 - val_loss: 0.1634 - val_binary_accuracy: 0.9973 - val_iou: 0.7246 - val_dice_coef: 0.8389
#
# Epoch 00054: val_iou did not improve from 0.00910
# Epoch 55/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1767 - binary_accuracy: 0.9968 - iou: 0.7025 - dice_coef: 0.8213 - val_loss: 0.1883 - val_binary_accuracy: 0.9972 - val_iou: 0.6846 - val_dice_coef: 0.8096
#
# Epoch 00055: val_iou did not improve from 0.00910
# Epoch 56/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1824 - binary_accuracy: 0.9966 - iou: 0.6977 - dice_coef: 0.8181 - val_loss: 0.1569 - val_binary_accuracy: 0.9974 - val_iou: 0.7352 - val_dice_coef: 0.8452
#
# Epoch 00056: val_iou did not improve from 0.00910
# Epoch 57/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1621 - binary_accuracy: 0.9970 - iou: 0.7273 - dice_coef: 0.8385 - val_loss: 0.1639 - val_binary_accuracy: 0.9973 - val_iou: 0.7202 - val_dice_coef: 0.8356
#
# Epoch 00057: val_iou did not improve from 0.00910
# Epoch 58/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1556 - binary_accuracy: 0.9972 - iou: 0.7351 - dice_coef: 0.8440 - val_loss: 0.1509 - val_binary_accuracy: 0.9975 - val_iou: 0.7412 - val_dice_coef: 0.8500
#
# Epoch 00058: val_iou did not improve from 0.00910
# Epoch 59/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1502 - binary_accuracy: 0.9972 - iou: 0.7442 - dice_coef: 0.8496 - val_loss: 0.1735 - val_binary_accuracy: 0.9971 - val_iou: 0.7012 - val_dice_coef: 0.8201
#
# Epoch 00059: val_iou did not improve from 0.00910
# Epoch 60/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1470 - binary_accuracy: 0.9974 - iou: 0.7476 - dice_coef: 0.8532 - val_loss: 0.1498 - val_binary_accuracy: 0.9977 - val_iou: 0.7386 - val_dice_coef: 0.8481
#
# Epoch 00060: val_iou did not improve from 0.00910
# Epoch 61/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1479 - binary_accuracy: 0.9974 - iou: 0.7467 - dice_coef: 0.8517 - val_loss: 0.1628 - val_binary_accuracy: 0.9975 - val_iou: 0.7330 - val_dice_coef: 0.8415
#
# Epoch 00061: val_iou did not improve from 0.00910
# Epoch 62/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1578 - binary_accuracy: 0.9972 - iou: 0.7334 - dice_coef: 0.8423 - val_loss: 0.1603 - val_binary_accuracy: 0.9974 - val_iou: 0.7233 - val_dice_coef: 0.8361
#
# Epoch 00062: val_iou did not improve from 0.00910
# Epoch 63/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1461 - binary_accuracy: 0.9973 - iou: 0.7482 - dice_coef: 0.8525 - val_loss: 0.1393 - val_binary_accuracy: 0.9975 - val_iou: 0.7611 - val_dice_coef: 0.8628
#
# Epoch 00063: val_iou did not improve from 0.00910
# Epoch 64/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1396 - binary_accuracy: 0.9975 - iou: 0.7591 - dice_coef: 0.8604 - val_loss: 0.1517 - val_binary_accuracy: 0.9977 - val_iou: 0.7448 - val_dice_coef: 0.8517
#
# Epoch 00064: val_iou did not improve from 0.00910
# Epoch 65/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1460 - binary_accuracy: 0.9973 - iou: 0.7513 - dice_coef: 0.8537 - val_loss: 0.1606 - val_binary_accuracy: 0.9974 - val_iou: 0.7384 - val_dice_coef: 0.8449
#
# Epoch 00065: val_iou did not improve from 0.00910
# Epoch 66/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1461 - binary_accuracy: 0.9973 - iou: 0.7512 - dice_coef: 0.8535 - val_loss: 0.1572 - val_binary_accuracy: 0.9977 - val_iou: 0.7256 - val_dice_coef: 0.8373
#
# Epoch 00066: val_iou did not improve from 0.00910
# Epoch 67/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1439 - binary_accuracy: 0.9974 - iou: 0.7538 - dice_coef: 0.8565 - val_loss: 0.1376 - val_binary_accuracy: 0.9976 - val_iou: 0.7628 - val_dice_coef: 0.8638
#
# Epoch 00067: val_iou did not improve from 0.00910
# Epoch 68/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1437 - binary_accuracy: 0.9974 - iou: 0.7529 - dice_coef: 0.8569 - val_loss: 0.1594 - val_binary_accuracy: 0.9974 - val_iou: 0.7343 - val_dice_coef: 0.8445
#
# Epoch 00068: val_iou did not improve from 0.00910
# Epoch 69/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1428 - binary_accuracy: 0.9973 - iou: 0.7547 - dice_coef: 0.8573 - val_loss: 0.1988 - val_binary_accuracy: 0.9970 - val_iou: 0.6556 - val_dice_coef: 0.7763
#
# Epoch 00069: val_iou did not improve from 0.00910
# Epoch 70/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1624 - binary_accuracy: 0.9970 - iou: 0.7286 - dice_coef: 0.8378 - val_loss: 0.1554 - val_binary_accuracy: 0.9975 - val_iou: 0.7398 - val_dice_coef: 0.8481
#
# Epoch 00070: val_iou did not improve from 0.00910
# Epoch 71/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1523 - binary_accuracy: 0.9973 - iou: 0.7429 - dice_coef: 0.8481 - val_loss: 0.1496 - val_binary_accuracy: 0.9974 - val_iou: 0.7265 - val_dice_coef: 0.8278
#
# Epoch 00071: val_iou did not improve from 0.00910
# Epoch 72/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1362 - binary_accuracy: 0.9974 - iou: 0.7657 - dice_coef: 0.8636 - val_loss: 0.1532 - val_binary_accuracy: 0.9976 - val_iou: 0.7468 - val_dice_coef: 0.8523
#
# Epoch 00072: val_iou did not improve from 0.00910
# Epoch 73/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1349 - binary_accuracy: 0.9974 - iou: 0.7675 - dice_coef: 0.8652 - val_loss: 0.1425 - val_binary_accuracy: 0.9975 - val_iou: 0.7542 - val_dice_coef: 0.8582
#
# Epoch 00073: val_iou did not improve from 0.00910
# Epoch 74/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1307 - binary_accuracy: 0.9975 - iou: 0.7748 - dice_coef: 0.8697 - val_loss: 0.1324 - val_binary_accuracy: 0.9976 - val_iou: 0.7765 - val_dice_coef: 0.8723
#
# Epoch 00074: val_iou did not improve from 0.00910
# Epoch 75/100
# 88/88 [==============================] - 98s 1s/step - loss: 0.1303 - binary_accuracy: 0.9975 - iou: 0.7731 - dice_coef: 0.8694 - val_loss: 0.1450 - val_binary_accuracy: 0.9976 - val_iou: 0.7525 - val_dice_coef: 0.8567
#
# Epoch 00075: val_iou did not improve from 0.00910
# Epoch 76/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.9453 - binary_accuracy: 0.9782 - iou: 0.0305 - dice_coef: 0.0559 - val_loss: 0.2614 - val_binary_accuracy: 0.9944 - val_iou: 0.5986 - val_dice_coef: 0.7440
#
# Epoch 00076: val_iou did not improve from 0.00910
# Epoch 77/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1457 - binary_accuracy: 0.9971 - iou: 0.7540 - dice_coef: 0.8547 - val_loss: 0.1450 - val_binary_accuracy: 0.9976 - val_iou: 0.7557 - val_dice_coef: 0.8591
#
# Epoch 00077: val_iou did not improve from 0.00910
# Epoch 78/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1280 - binary_accuracy: 0.9976 - iou: 0.7800 - dice_coef: 0.8723 - val_loss: 0.1418 - val_binary_accuracy: 0.9976 - val_iou: 0.7499 - val_dice_coef: 0.8555
#
# Epoch 00078: val_iou did not improve from 0.00910
# Epoch 79/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1228 - binary_accuracy: 0.9977 - iou: 0.7858 - dice_coef: 0.8767 - val_loss: 0.1334 - val_binary_accuracy: 0.9979 - val_iou: 0.7650 - val_dice_coef: 0.8645
#
# Epoch 00079: val_iou did not improve from 0.00910
# Epoch 80/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1220 - binary_accuracy: 0.9977 - iou: 0.7833 - dice_coef: 0.8755 - val_loss: 0.1369 - val_binary_accuracy: 0.9976 - val_iou: 0.7654 - val_dice_coef: 0.8654
#
# Epoch 00080: val_iou did not improve from 0.00910
# Epoch 81/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1448 - binary_accuracy: 0.9973 - iou: 0.7531 - dice_coef: 0.8553 - val_loss: 0.1509 - val_binary_accuracy: 0.9976 - val_iou: 0.7246 - val_dice_coef: 0.8245
#
# Epoch 00081: val_iou did not improve from 0.00910
# Epoch 82/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1378 - binary_accuracy: 0.9974 - iou: 0.7624 - dice_coef: 0.8621 - val_loss: 0.1341 - val_binary_accuracy: 0.9975 - val_iou: 0.7657 - val_dice_coef: 0.8662
#
# Epoch 00082: val_iou did not improve from 0.00910
# Epoch 83/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1284 - binary_accuracy: 0.9975 - iou: 0.7766 - dice_coef: 0.8719 - val_loss: 0.1261 - val_binary_accuracy: 0.9979 - val_iou: 0.7871 - val_dice_coef: 0.8785
#
# Epoch 00083: val_iou did not improve from 0.00910
# Epoch 84/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1209 - binary_accuracy: 0.9977 - iou: 0.7849 - dice_coef: 0.8779 - val_loss: 0.1473 - val_binary_accuracy: 0.9976 - val_iou: 0.7533 - val_dice_coef: 0.8568
#
# Epoch 00084: val_iou did not improve from 0.00910
# Epoch 85/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1385 - binary_accuracy: 0.9974 - iou: 0.7621 - dice_coef: 0.8617 - val_loss: 0.1489 - val_binary_accuracy: 0.9976 - val_iou: 0.7412 - val_dice_coef: 0.8478
#
# Epoch 00085: val_iou did not improve from 0.00910
# Epoch 86/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1319 - binary_accuracy: 0.9975 - iou: 0.7721 - dice_coef: 0.8683 - val_loss: 0.2710 - val_binary_accuracy: 0.9955 - val_iou: 0.5912 - val_dice_coef: 0.7361
#
# Epoch 00086: val_iou did not improve from 0.00910
# Epoch 87/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1637 - binary_accuracy: 0.9969 - iou: 0.7280 - dice_coef: 0.8365 - val_loss: 0.1464 - val_binary_accuracy: 0.9975 - val_iou: 0.7464 - val_dice_coef: 0.8516
#
# Epoch 00087: val_iou did not improve from 0.00910
# Epoch 88/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1256 - binary_accuracy: 0.9976 - iou: 0.7827 - dice_coef: 0.8742 - val_loss: 0.1330 - val_binary_accuracy: 0.9978 - val_iou: 0.7768 - val_dice_coef: 0.8719
#
# Epoch 00088: val_iou did not improve from 0.00910
# Epoch 89/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1200 - binary_accuracy: 0.9976 - iou: 0.7874 - dice_coef: 0.8780 - val_loss: 0.1232 - val_binary_accuracy: 0.9978 - val_iou: 0.7835 - val_dice_coef: 0.8773
#
# Epoch 00089: val_iou did not improve from 0.00910
# Epoch 90/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1187 - binary_accuracy: 0.9977 - iou: 0.7924 - dice_coef: 0.8817 - val_loss: 0.1340 - val_binary_accuracy: 0.9978 - val_iou: 0.7700 - val_dice_coef: 0.8680
#
# Epoch 00090: val_iou did not improve from 0.00910
# Epoch 91/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1170 - binary_accuracy: 0.9977 - iou: 0.7944 - dice_coef: 0.8830 - val_loss: 0.1341 - val_binary_accuracy: 0.9978 - val_iou: 0.7755 - val_dice_coef: 0.8709
#
# Epoch 00091: val_iou did not improve from 0.00910
# Epoch 92/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1180 - binary_accuracy: 0.9977 - iou: 0.7915 - dice_coef: 0.8821 - val_loss: 0.1350 - val_binary_accuracy: 0.9976 - val_iou: 0.7753 - val_dice_coef: 0.8700
#
# Epoch 00092: val_iou did not improve from 0.00910
# Epoch 93/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1294 - binary_accuracy: 0.9975 - iou: 0.7766 - dice_coef: 0.8706 - val_loss: 0.1487 - val_binary_accuracy: 0.9975 - val_iou: 0.7393 - val_dice_coef: 0.8458
#
# Epoch 00093: val_iou did not improve from 0.00910
# Epoch 94/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.9421 - binary_accuracy: 0.9787 - iou: 0.0320 - dice_coef: 0.0583 - val_loss: 0.2899 - val_binary_accuracy: 0.9936 - val_iou: 0.5575 - val_dice_coef: 0.7118
#
# Epoch 00094: val_iou did not improve from 0.00910
# Epoch 95/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1321 - binary_accuracy: 0.9973 - iou: 0.7721 - dice_coef: 0.8678 - val_loss: 0.1319 - val_binary_accuracy: 0.9978 - val_iou: 0.7729 - val_dice_coef: 0.8699
#
# Epoch 00095: val_iou did not improve from 0.00910
# Epoch 96/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1127 - binary_accuracy: 0.9978 - iou: 0.8014 - dice_coef: 0.8878 - val_loss: 0.1214 - val_binary_accuracy: 0.9977 - val_iou: 0.7786 - val_dice_coef: 0.8732
#
# Epoch 00096: val_iou did not improve from 0.00910
# Epoch 97/100
# 88/88 [==============================] - 106s 1s/step - loss: 0.1198 - binary_accuracy: 0.9977 - iou: 0.7887 - dice_coef: 0.8787 - val_loss: 0.1300 - val_binary_accuracy: 0.9978 - val_iou: 0.7571 - val_dice_coef: 0.8491
#
# Epoch 00097: val_iou did not improve from 0.00910
# Epoch 98/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.8308 - binary_accuracy: 0.9756 - iou: 0.1032 - dice_coef: 0.1694 - val_loss: 0.8563 - val_binary_accuracy: 0.8954 - val_iou: 0.0771 - val_dice_coef: 0.1416
#
# Epoch 00098: val_iou did not improve from 0.00910
# Epoch 99/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.9182 - binary_accuracy: 0.9495 - iou: 0.0435 - dice_coef: 0.0815 - val_loss: 0.5883 - val_binary_accuracy: 0.9901 - val_iou: 0.2945 - val_dice_coef: 0.4340
#
# Epoch 00099: val_iou did not improve from 0.00910
# Epoch 100/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2058 - binary_accuracy: 0.9947 - iou: 0.6801 - dice_coef: 0.7940 - val_loss: 0.1549 - val_binary_accuracy: 0.9972 - val_iou: 0.7365 - val_dice_coef: 0.8462
#
# Epoch 00100: val_iou did not improve from 0.00910

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Save Model</span> <a id=5.4></a>

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model.h5')

# %%
# saving model achitecture in json file
model_json = model.to_json()
with open("UNet-seg-model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Evaluation</span> <a id=6></a>
#
# Evaluation metrics are listed below

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'iou', 'dice_coef', 'val_loss', 'val_binary_accuracy', 'val_iou', 'val_dice_coef'])

# %% [markdown]
# **Loss function** :  IOU - Intersection over Union

# %% [markdown]
# ![Performance metric : Intersection over Union](data:image/png;base64,...)
#
# ![IOU](data:image/png;base64,...)

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['iou']);
plt.plot(history.history['val_iou']);
plt.title("Segmentation Model IOU Loss");
plt.ylabel("IOU loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Prediction</span> <a id=7></a>

# %%
test_ids = list(mri_test.img_path)
test_mask = list(mri_test.mask_path)

# %%
def prediction(test, model_seg):
  
    # empty list to store results
    mask, image_id,has_mask = [], [], []
    
    #itetrating through each image in test data
    for i in test.img_path:
        

        
        #Creating a empty array of shape 1,256,256,1
        X = np.empty((1,256,256,3))
        # read the image
        img = io.imread(i)
        #resizing the image and coverting them to array of type float64
        img = cv2.resize(img, (256,256))
        img = np.array(img, dtype=np.float64)
        
        # standardising the image
        img -= img.mean()
        img /= img.std()
        #converting the shape of image from 256,256,3 to 1,256,256,3
        X[0,] = img
        
        #make prediction of mask
        predict = model_seg.predict(X)
        
        # if sum of predicted mask is 0 then there is not tumour
        if predict.round().astype(int).sum()==0:
            image_id.append(i)
            has_mask.append(0)
            mask.append('No mask :)')
        else:
        #if the sum of pixel values are more than 0, then there is tumour
            image_id.append(i)
            has_mask.append(1)
            mask.append(predict)
            
    return pd.DataFrame({'img_path': image_id,'predicted_mask': mask,'has_mask': has_mask})

# %%
df_pred = prediction(mri_test, model)
df_pred
# Out:
#                                               img_path  \
# 0    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ..                                                 ...
# 388  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 389  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 390  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 391  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 392  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                         predicted_mask  has_mask
# 0    [[[[1.353177e-09], [1.9964687e-14], [6.1445185...         1
# 1    [[[[1.9506531e-07], [8.721512e-11], [1.4563897...         1
# 2    [[[[5.3655425e-13], [4.3649875e-12], [9.824233...         1
# 3    [[[[2.5299457e-11], [3.2695902e-17], [1.763584...         1
# 4    [[[[1.9702657e-09], [6.2913325e-14], [2.484098...         1
# ..                                                 ...       ...
# 388  [[[[2.4337215e-11], [3.2817484e-17], [1.805413...         1
# 389  [[[[9.143025e-12], [7.241927e-18], [4.6372523e...         1
# 390  [[[[6.702629e-08], [1.4524489e-11], [2.1335686...         1
# 391  [[[[8.029516e-11], [2.6234254e-16], [1.3263075...         1
# 392  [[[[6.4105377e-10], [7.236719e-15], [2.1520879...         1
#
# [393 rows x 3 columns]

# %%
df_pred = mri_test.merge(df_pred, on='img_path')
df_pred.head()
# Out:
#                                             img_path  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path  mask  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
#                                       predicted_mask  has_mask
# 0  [[[[1.353177e-09], [1.9964687e-14], [6.1445185...         1
# 1  [[[[1.9506531e-07], [8.721512e-11], [1.4563897...         1
# 2  [[[[5.3655425e-13], [4.3649875e-12], [9.824233...         1
# 3  [[[[2.5299457e-11], [3.2695902e-17], [1.763584...         1
# 4  [[[[1.9702657e-09], [6.2913325e-14], [2.484098...         1

# %%
count = 0
fig, axs = plt.subplots(3,5, figsize=(30,15))

for i in range(len(df_pred)):
    if df_pred.has_mask[i]==1 and count<15:
        #read mri images
        img = io.imread(df_pred.img_path[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        axs[count][0].imshow(img)
        axs[count][0].title.set_text('Brain MRI')
        
        #read original mask
        mask = io.imread(df_pred.mask_path[i])
        axs[count][1].imshow(mask)
        axs[count][1].title.set_text('Ground Truth')
        
        #read predicted mask
        pred = np.array(df_pred.predicted_mask[i]).squeeze().round()
        axs[count][2].imshow(pred)
        axs[count][2].title.set_text('predicted mask')
        
        #overlay original mask with MRI
        img[mask==255] = (255,0,0)
        axs[count][3].imshow(img)
        axs[count][3].title.set_text('Brain MRI with original mask (Ground Truth)')
        
        #overlay predicted mask and MRI
        img_ = io.imread(df_pred.img_path[i])
        img_ = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
        img_[pred==1] = (0,255,150)
        axs[count][4].imshow(img_)
        axs[count][4].title.set_text('MRI with PREDICTED MASK')
        
        count +=1
    if (count==3):
        break

fig.tight_layout()

# %% [markdown]
# **Reference:**
# * [UNet model Original creator Reference link](https://github.com/zhixuhao/unet)
# * [Kaggle Notebook - SAMUEL CORTINHAS](https://www.kaggle.com/code/samuelcortinhas/case-study-u-net-from-scratch#Application:-Tumor-detection)
