# %% [markdown]
# <a href="https://www.kaggle.com/code/tejasurya/unet-guide-image-segmentation?scriptVersionId=108262608" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="background-color:red;color:white;font-size:22px;text-align:center;border-radius:10px 10px;font-weight:bold;border:2px solid black">Brain MRI Detector | Segmentation | Using UNet</p>
#
# <center><img src= "https://www.mayoclinic.org/-/media/kcms/gbs/patient-consumer/images/2014/10/30/15/17/mcdc7_brain_cancer-8col.jpg" alt ="Brain-MRI" style='width:300px;'></center>
#
# **Image source** : Mayo Clinic

# %% [markdown]
# # <h3 class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Introduction</p> <a id=1></a>
# A brain tumor is a mass or growth of abnormal cells in your brain.Many different types of brain tumors exist. Some brain tumors are noncancerous (benign), and some brain tumors are cancerous (malignant). Brain tumors can begin in your brain (primary brain tumors), or cancer can begin in other parts of your body and spread to your brain as secondary (metastatic) brain tumors.
#
# How quickly a brain tumor grows can vary greatly. The growth rate as well as the location of a brain tumor determines how it will affect the function of your nervous system.
#
# Brain tumor treatment options depend on the type of brain tumor you have, as well as its size and location. <br>
# **Source credits** : [Mayo Clinic](https://www.mayoclinic.org/diseases-conditions/brain-tumor/symptoms-causes/syc-20350084)

# %% [markdown]
# ## <p class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">What is Image Segmentation?</p> <a id=1.1></a> <br>
#  *  The objective of the Image Segmentation is to classify each pixel of an image with the class it represents, by predicting each pixel in image. <br>
#  *  Here in this notebook,we will implement the U-Net model, its a U-shaped architecture (in keras).
# We will also apply our model to a Brain MRI tumor detection problem to see how it performs.

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Import Libraries</p> <a id=1.1></a> <br>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import glob

import time
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
from IPython.display import Image
from skimage import io

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.layers.experimental import preprocessing
from keras.utils.vis_utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
import cv2
from sklearn.preprocessing import StandardScaler, normalize
from IPython.display import display

# %%
img_data = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
img_data.head()
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0

# %%
img_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
img_data.shape
# Out:
# (110, 18)

# %%
data_path = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            mask_path = sub_dir_path + '/' + filename
            data_path.extend([dir_name, mask_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
filenames = data_path[::2]
masks = data_path[1::2]

# %%
df = pd.DataFrame(data={"patient_id": filenames,"img_path": masks})
df
# Out:
#                  patient_id                                           img_path
# 0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                     ...                                                ...
# 7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [7858 rows x 2 columns]

# %%
original_img     = df[~df['img_path'].str.contains("mask")]
mask_img = df[df['img_path'].str.contains("mask")]

# %%
original_img,mask_img
# Out:
# (                 patient_id                                           img_path
#  0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  5     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7849  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7850  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7852  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns],
#                   patient_id                                           img_path
#  1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  8     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  9     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  11    TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7846  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7851  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns])

# %%
imgs = sorted(original_img["img_path"].values, key=lambda x : int(x[89:-4]))
masks = sorted(mask_img["img_path"].values, key=lambda x : int(x[89:-9]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Image path:", imgs[idx], "\nMask path:", masks[idx])
# Out:
# Image path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_2.tif
# Mask path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_DU_7294_19890104/TCGA_DU_7294_19890104_2_mask.tif

# %%
mri_df = pd.DataFrame({"patient_id": original_img.patient_id.values,"img_path": imgs,
                           'mask_path':masks})
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [3929 rows x 3 columns]

# %%
def get_diagnosis(img_path):
    value = np.max(cv2.imread(img_path))
    if value > 0 : 
        return 1
    else:
        return 0

# %%
mri_df.head()
# Out:
#               patient_id                                           img_path  \
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
mri_df['mask'] = mri_df['mask_path'].apply(lambda x: get_diagnosis(x))

mri_df['mask_path'] = mri_df['mask_path'].apply(lambda x: str(x))
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# ...                                                 ...   ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
# [3929 rows x 4 columns]

# %%
mri_df.drop(columns=['patient_id'],inplace=True)

# %%
mri_train, mri_test = train_test_split(mri_df,test_size = 0.1)
mri_train, mri_val = train_test_split(mri_train,test_size = 0.2)

print('Training data shape is {0}'.format(mri_train.values.shape))
print('Test data shape is {0}'.format(mri_test.values.shape))
mri_train.sample(n=5)
# Out:
# Training data shape is (2828, 3)
# Test data shape is (393, 3)
#                                                img_path  \
# 3085  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 999   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2674  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1143  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3627  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 3085  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 999   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2674  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 1143  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3627  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">EDA</p> <a id=2></a> <br>
#
# Check Balancing in Data

# %%
mri_df['mask'].value_counts().plot(kind='bar',color=['g','r'],
                title='Count of Tumour vs No Tumour')
# Out:
# <AxesSubplot:title={'center':'Count of Tumour vs No Tumour'}>

# %%
mri_df['mask'].value_counts()
# Out:
# 0    2556
# 1    1373
# Name: mask, dtype: int64

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Image Visualization</p> <a id=2></a> <br>
#
# Visualising the Brain MRI with Tumour

# %%
count = 0
i = 0
fig,axs = plt.subplots(3,3, figsize=(20,15))
for mask in mri_df['mask']:
    if (mask==1):
        img = io.imread(mri_df.img_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(mri_df.mask_path[i])
        axs[count][1].title.set_text("Mask =" + str(mri_df['mask'][i]))
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (255,0,0)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask =" + str(mri_df['mask'][i]))
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==3):
        break
        
fig.tight_layout()

# %%
# Basic visualizations: Visualize the images (MRI and Mask) in the dataset separately 

fig, axs = plt.subplots(4,2, figsize=(13,13))
count = 0
for x in range(4):
  i = random.randint(0, len(mri_df)) 
  axs[count][0].title.set_text("Brain MRI") 
  axs[count][0].imshow(cv2.imread(mri_df.img_path[i])) 
  axs[count][1].title.set_text("Mask - " + str(mri_df['mask'][i])) 
  axs[count][1].imshow(cv2.imread(mri_df.mask_path[i])) 
  count += 1

fig.tight_layout()

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Data Generator</p> <a id=3></a> <br>
# ### Reference : **[UNet](https://github.com/zhixuhao/unet)**

# %%
from keras_preprocessing.image import ImageDataGenerator

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "img_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

# %%
def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(mri_train, 32,
                                train_generator_args,
                                target_size=(256, 256))
    
val_gen = train_generator(mri_val, 32,
                                dict(),
                                target_size=(256, 256))

# %% [markdown]
# # <p style="color:#FF0000;background-color:white;font-size:25px">Build UNet Model</p> <a id=4></a> <br>
#
# <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Architecture</p> <a id=4.1></a>
#
# <center><img src= "https://miro.medium.com/max/1200/1*f7YOaE4TWubwaFF7Z1fzNw.png" alt ="UNet" style='width:800px;'></center>

# %% [markdown]
# UNet is named after the shape of it's architecture (U - shaped). UNet model is used to solve Image Segmentation problems especially in Medical related problems.
#
# The input layer has 572x572x1 dimension in the above architecture. The 1 column dimension specifies the input is b/w image. If the input dimension was 572x572x3 , the input image is rgb coloured image.
# After the input layer,we can divide this UNet architecture into 4 parts
# * Encoder Part (Contracting path)
# * Upsampling2D
# * Decoder part (Expanding Path)
# * Skip Connection (Residual connection)
#
#
# Briefly into the Details of these parts: <br>
# **Encoder Part**
# The initial half of the U-shaped architecture is the Contracting path(Encoder part). As the name Contracting path denotes, the dimension of the input image keeps reducing as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=64 followed by Maxpool2D layer (reduces size divided by 2). Now again 2 - Conv2D layers (128 filters) and 1 Maxpooling2D , 2 - Conv2D layers (256 filters) and 1 Maxpooling2D completely contracts the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Upsampling2D**
# The Upsampling2D layer upsamples the layer output dimension by duplicating the row values twice.The concatenation of the upsampling2D and contracting path happens here leading into the Expanding path.
# The Upsampling layer is present after 2 conv2D layers in Decoder part, similar to presence of  Maxpooling as in Encoder part.
#
# **Decoder Path**
# The second half of the U-shaped architecture is the Expanding path(Decoder part). As the name Expanding path denotes, the dimension of the image keeps expanding as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=512 followed by Upsampling2D layer (duplicates size divided by 2). Now again 2 - Conv2D layers (256 filters) and 1 Upsampling2D ,2 - Conv2D layers (128 filters) and 1 Upsampling2D, 2 - Conv2D layers (64 filters) completely expands the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Skip Connection (Residual connection)**
# The Skip Connection (Residual connection) alias the identity mapping is present after each of the 2 Conv2D layers in Encoder to the corresponding same shaped dimension layer in the Decoder part . In the above architecture the copy and crop does residual connection task.The Concatenate layer does the work of adding those two layers. This skip connection doesnot harm the model in any way even in worst case but definitely benificial to the output in the model.
#
# Finally the decoder part ends with the Output Segmentation map with filters 2. This layer is again passed through a Conv2D with Sigmoid activation and filters 1. The output classifies each pixel if tumour is present or not in it.
#
# ### Reference : [UNet](https://github.com/zhixuhao/unet)

# %%
def unet(pretrained_weights = None,input_size = (256,256,3)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv1)
    bn_1 = BatchNormalization(axis=3)(conv1)
    act_1 = Activation('relu')(bn_1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(act_1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    bn_2 = BatchNormalization(axis=3)(conv2)
    act_2 = Activation('relu')(bn_2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(act_2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv3)
    bn_3 = BatchNormalization(axis=3)(conv3)
    act_3 = Activation('relu')(bn_3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(act_3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv4)
    bn_4 = BatchNormalization(axis=3)(conv4)
    act_4 = Activation('relu')(bn_4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(act_4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv5)
    bn_5 = BatchNormalization(axis=3)(conv5)
    act_5 = Activation('relu')(bn_5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv6)
    bn_6 = BatchNormalization(axis=3)(conv6)
    act_6 = Activation('relu')(bn_6)
    
    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv7)
    bn_7 = BatchNormalization(axis=3)(conv7)
    act_7 = Activation('relu')(bn_7)

    
    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv8)
    bn_8 = BatchNormalization(axis=3)(conv8)
    act_8 = Activation('relu')(bn_8)
    
    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv9)
    bn_9 = BatchNormalization(axis=3)(conv9)
    act_9 = Activation('relu')(bn_9)
    
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(act_9)

    model = model = Model(inputs=[inputs] , outputs = [conv10])    
    return model

# %%
model = unet()
model.summary()
# Out:
# 2022-10-16 14:55:08.292212: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:08.384469: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:08.385238: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:08.386921: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-16 14:55:08.387239: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:08.387940: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:08.388582: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:10.503919: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:10.504996: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:10.505727: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-16 14:55:10.506387: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 256, 2)  8           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 2)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 1)  3           activation_8[0][0]
# ==================================================================================================
# Total params: 31,044,365
# Trainable params: 31,038,601
# Non-trainable params: 5,764
# __________________________________________________________________________________________________

# %% [markdown]
# <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Model architecture</p> <a id=5></a>

# %%
plot_model(model, to_file='unet_model.png', show_shapes=True)
Image("unet_model.png")

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Callbacks</p> <a id=5.2></a> <br>
#
# The Callbacks used are
# * Learning Rate reduction
# * Early Stopping
# * Model Checkpoint

# %%
lr_reduction = ReduceLROnPlateau(monitor='val_iou',patience=8, verbose=1,
                                 factor=0.4, min_lr=0.0001)

early_stop = EarlyStopping(monitor='val_iou', min_delta=0.00001, patience=6, 
                           mode='auto', restore_best_weights=True)

model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', verbose=1,monitor='val_iou',
                                   save_best_only=True)

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Performance Metrics</p> <a id=5.2></a>

# %%
smooth =100
def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Model Fit</p> <a id=5.3></a>

# %%
EPOCH = 70
learning_rate = 1e-3

# %%
model.compile(optimizer=Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-3/32, amsgrad=False), 
              loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

# %%
history = model.fit(train_gen,steps_per_epoch=len(mri_train) / 32,
                    epochs=EPOCH ,validation_data=val_gen,validation_steps=len(mri_val) / 32,
                    callbacks=[model_checkpoint])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# 2022-10-16 14:55:16.328936: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/70
# 2022-10-16 14:55:19.168058: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 2022-10-16 14:55:33.726990: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-16 14:55:33.807843: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-16 14:55:33.963347: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 89/88 [==============================] - ETA: 0s - loss: 0.9634 - binary_accuracy: 0.8642 - iou: 0.0188 - dice_coef: 0.0368Found 708 validated image filenames.
# Found 708 validated image filenames.
# 88/88 [==============================] - 135s 1s/step - loss: 0.9634 - binary_accuracy: 0.8642 - iou: 0.0188 - dice_coef: 0.0368 - val_loss: 0.9741 - val_binary_accuracy: 0.9835 - val_iou: 0.0137 - val_dice_coef: 0.0269
#
# Epoch 00001: val_iou improved from inf to 0.01373, saving model to unet_membrane.hdf5
# Epoch 2/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9610 - binary_accuracy: 0.9225 - iou: 0.0199 - dice_coef: 0.0388 - val_loss: 0.9702 - val_binary_accuracy: 0.7956 - val_iou: 0.0162 - val_dice_coef: 0.0317
#
# Epoch 00002: val_iou did not improve from 0.01373
# Epoch 3/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9695 - binary_accuracy: 0.7531 - iou: 0.0156 - dice_coef: 0.0306 - val_loss: 0.9693 - val_binary_accuracy: 0.7799 - val_iou: 0.0158 - val_dice_coef: 0.0310
#
# Epoch 00003: val_iou did not improve from 0.01373
# Epoch 4/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.9673 - binary_accuracy: 0.7597 - iou: 0.0168 - dice_coef: 0.0329 - val_loss: 0.9826 - val_binary_accuracy: 0.9703 - val_iou: 0.0087 - val_dice_coef: 0.0171
#
# Epoch 00004: val_iou improved from 0.01373 to 0.00872, saving model to unet_membrane.hdf5
# Epoch 5/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9587 - binary_accuracy: 0.8927 - iou: 0.0212 - dice_coef: 0.0413 - val_loss: 0.9667 - val_binary_accuracy: 0.9206 - val_iou: 0.0164 - val_dice_coef: 0.0321
#
# Epoch 00005: val_iou did not improve from 0.00872
# Epoch 6/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9542 - binary_accuracy: 0.9410 - iou: 0.0236 - dice_coef: 0.0459 - val_loss: 0.9644 - val_binary_accuracy: 0.9675 - val_iou: 0.0196 - val_dice_coef: 0.0380
#
# Epoch 00006: val_iou did not improve from 0.00872
# Epoch 7/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.9508 - binary_accuracy: 0.9496 - iou: 0.0253 - dice_coef: 0.0491 - val_loss: 0.9814 - val_binary_accuracy: 0.9907 - val_iou: 0.0091 - val_dice_coef: 0.0179
#
# Epoch 00007: val_iou did not improve from 0.00872
# Epoch 8/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9473 - binary_accuracy: 0.9580 - iou: 0.0273 - dice_coef: 0.0528 - val_loss: 0.9600 - val_binary_accuracy: 0.9846 - val_iou: 0.0199 - val_dice_coef: 0.0387
#
# Epoch 00008: val_iou did not improve from 0.00872
# Epoch 9/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9439 - binary_accuracy: 0.9570 - iou: 0.0290 - dice_coef: 0.0561 - val_loss: 0.9549 - val_binary_accuracy: 0.9898 - val_iou: 0.0260 - val_dice_coef: 0.0499
#
# Epoch 00009: val_iou did not improve from 0.00872
# Epoch 10/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9393 - binary_accuracy: 0.9628 - iou: 0.0318 - dice_coef: 0.0611 - val_loss: 0.9587 - val_binary_accuracy: 0.9862 - val_iou: 0.0210 - val_dice_coef: 0.0406
#
# Epoch 00010: val_iou did not improve from 0.00872
# Epoch 11/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9333 - binary_accuracy: 0.9697 - iou: 0.0349 - dice_coef: 0.0670 - val_loss: 0.9425 - val_binary_accuracy: 0.9721 - val_iou: 0.0287 - val_dice_coef: 0.0554
#
# Epoch 00011: val_iou did not improve from 0.00872
# Epoch 12/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.9296 - binary_accuracy: 0.9691 - iou: 0.0367 - dice_coef: 0.0703 - val_loss: 0.9556 - val_binary_accuracy: 0.9915 - val_iou: 0.0221 - val_dice_coef: 0.0428
#
# Epoch 00012: val_iou did not improve from 0.00872
# Epoch 13/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.9219 - binary_accuracy: 0.9742 - iou: 0.0411 - dice_coef: 0.0784 - val_loss: 0.9416 - val_binary_accuracy: 0.9872 - val_iou: 0.0293 - val_dice_coef: 0.0563
#
# Epoch 00013: val_iou did not improve from 0.00872
# Epoch 14/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.9598 - binary_accuracy: 0.8242 - iou: 0.0209 - dice_coef: 0.0406 - val_loss: 0.9493 - val_binary_accuracy: 0.8867 - val_iou: 0.0252 - val_dice_coef: 0.0488
#
# Epoch 00014: val_iou did not improve from 0.00872
# Epoch 15/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9213 - binary_accuracy: 0.9508 - iou: 0.0412 - dice_coef: 0.0786 - val_loss: 0.9345 - val_binary_accuracy: 0.9196 - val_iou: 0.0352 - val_dice_coef: 0.0675
#
# Epoch 00015: val_iou did not improve from 0.00872
# Epoch 16/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9063 - binary_accuracy: 0.9790 - iou: 0.0495 - dice_coef: 0.0937 - val_loss: 0.9392 - val_binary_accuracy: 0.9891 - val_iou: 0.0368 - val_dice_coef: 0.0693
#
# Epoch 00016: val_iou did not improve from 0.00872
# Epoch 17/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.8956 - binary_accuracy: 0.9820 - iou: 0.0558 - dice_coef: 0.1049 - val_loss: 0.9107 - val_binary_accuracy: 0.9656 - val_iou: 0.0495 - val_dice_coef: 0.0934
#
# Epoch 00017: val_iou did not improve from 0.00872
# Epoch 18/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.8862 - binary_accuracy: 0.9840 - iou: 0.0613 - dice_coef: 0.1144 - val_loss: 0.9131 - val_binary_accuracy: 0.9872 - val_iou: 0.0481 - val_dice_coef: 0.0908
#
# Epoch 00018: val_iou did not improve from 0.00872
# Epoch 19/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.8728 - binary_accuracy: 0.9843 - iou: 0.0687 - dice_coef: 0.1275 - val_loss: 0.8980 - val_binary_accuracy: 0.9723 - val_iou: 0.0525 - val_dice_coef: 0.0986
#
# Epoch 00019: val_iou did not improve from 0.00872
# Epoch 20/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.8596 - binary_accuracy: 0.9860 - iou: 0.0758 - dice_coef: 0.1396 - val_loss: 0.8848 - val_binary_accuracy: 0.9792 - val_iou: 0.0610 - val_dice_coef: 0.1133
#
# Epoch 00020: val_iou did not improve from 0.00872
# Epoch 21/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.8459 - binary_accuracy: 0.9878 - iou: 0.0847 - dice_coef: 0.1543 - val_loss: 0.8659 - val_binary_accuracy: 0.9891 - val_iou: 0.0704 - val_dice_coef: 0.1298
#
# Epoch 00021: val_iou did not improve from 0.00872
# Epoch 22/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.8274 - binary_accuracy: 0.9898 - iou: 0.0956 - dice_coef: 0.1729 - val_loss: 0.8698 - val_binary_accuracy: 0.9954 - val_iou: 0.0685 - val_dice_coef: 0.1262
#
# Epoch 00022: val_iou did not improve from 0.00872
# Epoch 23/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.8103 - binary_accuracy: 0.9912 - iou: 0.1053 - dice_coef: 0.1885 - val_loss: 0.8376 - val_binary_accuracy: 0.9934 - val_iou: 0.0865 - val_dice_coef: 0.1568
#
# Epoch 00023: val_iou did not improve from 0.00872
# Epoch 24/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.7913 - binary_accuracy: 0.9914 - iou: 0.1181 - dice_coef: 0.2088 - val_loss: 0.8311 - val_binary_accuracy: 0.9950 - val_iou: 0.0957 - val_dice_coef: 0.1716
#
# Epoch 00024: val_iou did not improve from 0.00872
# Epoch 25/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.7737 - binary_accuracy: 0.9915 - iou: 0.1300 - dice_coef: 0.2272 - val_loss: 0.8159 - val_binary_accuracy: 0.9955 - val_iou: 0.1032 - val_dice_coef: 0.1848
#
# Epoch 00025: val_iou did not improve from 0.00872
# Epoch 26/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.7521 - binary_accuracy: 0.9922 - iou: 0.1438 - dice_coef: 0.2483 - val_loss: 0.7850 - val_binary_accuracy: 0.9958 - val_iou: 0.1190 - val_dice_coef: 0.2100
#
# Epoch 00026: val_iou did not improve from 0.00872
# Epoch 27/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.7271 - binary_accuracy: 0.9940 - iou: 0.1603 - dice_coef: 0.2729 - val_loss: 0.7636 - val_binary_accuracy: 0.9957 - val_iou: 0.1432 - val_dice_coef: 0.2454
#
# Epoch 00027: val_iou did not improve from 0.00872
# Epoch 28/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9541 - binary_accuracy: 0.9453 - iou: 0.0240 - dice_coef: 0.0461 - val_loss: 0.8993 - val_binary_accuracy: 0.9332 - val_iou: 0.0529 - val_dice_coef: 0.0991
#
# Epoch 00028: val_iou did not improve from 0.00872
# Epoch 29/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.7293 - binary_accuracy: 0.9834 - iou: 0.1609 - dice_coef: 0.2723 - val_loss: 0.7833 - val_binary_accuracy: 0.9958 - val_iou: 0.1246 - val_dice_coef: 0.2180
#
# Epoch 00029: val_iou did not improve from 0.00872
# Epoch 30/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.6803 - binary_accuracy: 0.9947 - iou: 0.1926 - dice_coef: 0.3197 - val_loss: 0.7289 - val_binary_accuracy: 0.9939 - val_iou: 0.1667 - val_dice_coef: 0.2810
#
# Epoch 00030: val_iou did not improve from 0.00872
# Epoch 31/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.6675 - binary_accuracy: 0.9943 - iou: 0.2040 - dice_coef: 0.3333 - val_loss: 0.6905 - val_binary_accuracy: 0.9943 - val_iou: 0.1878 - val_dice_coef: 0.3126
#
# Epoch 00031: val_iou did not improve from 0.00872
# Epoch 32/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.6362 - binary_accuracy: 0.9952 - iou: 0.2267 - dice_coef: 0.3641 - val_loss: 0.6959 - val_binary_accuracy: 0.9963 - val_iou: 0.1776 - val_dice_coef: 0.2949
#
# Epoch 00032: val_iou did not improve from 0.00872
# Epoch 33/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9479 - binary_accuracy: 0.9308 - iou: 0.0273 - dice_coef: 0.0521 - val_loss: 0.9529 - val_binary_accuracy: 0.9604 - val_iou: 0.0242 - val_dice_coef: 0.0457
#
# Epoch 00033: val_iou did not improve from 0.00872
# Epoch 34/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.9257 - binary_accuracy: 0.8948 - iou: 0.0392 - dice_coef: 0.0747 - val_loss: 0.9801 - val_binary_accuracy: 0.9853 - val_iou: 0.0109 - val_dice_coef: 0.0197
#
# Epoch 00034: val_iou did not improve from 0.00872
# Epoch 35/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9259 - binary_accuracy: 0.8903 - iou: 0.0391 - dice_coef: 0.0746 - val_loss: 0.9181 - val_binary_accuracy: 0.8723 - val_iou: 0.0416 - val_dice_coef: 0.0789
#
# Epoch 00035: val_iou did not improve from 0.00872
# Epoch 36/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.6912 - binary_accuracy: 0.9816 - iou: 0.1880 - dice_coef: 0.3096 - val_loss: 0.8511 - val_binary_accuracy: 0.9932 - val_iou: 0.0882 - val_dice_coef: 0.1573
#
# Epoch 00036: val_iou did not improve from 0.00872
# Epoch 37/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.5969 - binary_accuracy: 0.9949 - iou: 0.2563 - dice_coef: 0.4030 - val_loss: 0.6724 - val_binary_accuracy: 0.9941 - val_iou: 0.1945 - val_dice_coef: 0.3174
#
# Epoch 00037: val_iou did not improve from 0.00872
# Epoch 38/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9041 - binary_accuracy: 0.9479 - iou: 0.0521 - dice_coef: 0.0955 - val_loss: 0.8985 - val_binary_accuracy: 0.8831 - val_iou: 0.0519 - val_dice_coef: 0.0978
#
# Epoch 00038: val_iou did not improve from 0.00872
# Epoch 39/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.6234 - binary_accuracy: 0.9865 - iou: 0.2386 - dice_coef: 0.3764 - val_loss: 0.8127 - val_binary_accuracy: 0.9939 - val_iou: 0.1108 - val_dice_coef: 0.1927
#
# Epoch 00039: val_iou did not improve from 0.00872
# Epoch 40/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.5426 - binary_accuracy: 0.9956 - iou: 0.3023 - dice_coef: 0.4586 - val_loss: 0.6149 - val_binary_accuracy: 0.9967 - val_iou: 0.2394 - val_dice_coef: 0.3792
#
# Epoch 00040: val_iou did not improve from 0.00872
# Epoch 41/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.5213 - binary_accuracy: 0.9959 - iou: 0.3222 - dice_coef: 0.4794 - val_loss: 0.5790 - val_binary_accuracy: 0.9967 - val_iou: 0.2743 - val_dice_coef: 0.4236
#
# Epoch 00041: val_iou did not improve from 0.00872
# Epoch 42/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.4958 - binary_accuracy: 0.9960 - iou: 0.3391 - dice_coef: 0.5016 - val_loss: 0.5386 - val_binary_accuracy: 0.9966 - val_iou: 0.2946 - val_dice_coef: 0.4449
#
# Epoch 00042: val_iou did not improve from 0.00872
# Epoch 43/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.4779 - binary_accuracy: 0.9963 - iou: 0.3600 - dice_coef: 0.5228 - val_loss: 0.5375 - val_binary_accuracy: 0.9974 - val_iou: 0.3035 - val_dice_coef: 0.4572
#
# Epoch 00043: val_iou did not improve from 0.00872
# Epoch 44/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.4602 - binary_accuracy: 0.9963 - iou: 0.3752 - dice_coef: 0.5387 - val_loss: 0.5289 - val_binary_accuracy: 0.9970 - val_iou: 0.3230 - val_dice_coef: 0.4789
#
# Epoch 00044: val_iou did not improve from 0.00872
# Epoch 45/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.4298 - binary_accuracy: 0.9968 - iou: 0.4035 - dice_coef: 0.5700 - val_loss: 0.4841 - val_binary_accuracy: 0.9972 - val_iou: 0.3424 - val_dice_coef: 0.4977
#
# Epoch 00045: val_iou did not improve from 0.00872
# Epoch 46/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.4161 - binary_accuracy: 0.9966 - iou: 0.4167 - dice_coef: 0.5820 - val_loss: 0.4609 - val_binary_accuracy: 0.9965 - val_iou: 0.3612 - val_dice_coef: 0.5201
#
# Epoch 00046: val_iou did not improve from 0.00872
# Epoch 47/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.4040 - binary_accuracy: 0.9968 - iou: 0.4304 - dice_coef: 0.5936 - val_loss: 0.4506 - val_binary_accuracy: 0.9970 - val_iou: 0.3918 - val_dice_coef: 0.5564
#
# Epoch 00047: val_iou did not improve from 0.00872
# Epoch 48/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.3788 - binary_accuracy: 0.9970 - iou: 0.4550 - dice_coef: 0.6209 - val_loss: 0.4357 - val_binary_accuracy: 0.9973 - val_iou: 0.4008 - val_dice_coef: 0.5653
#
# Epoch 00048: val_iou did not improve from 0.00872
# Epoch 49/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.3756 - binary_accuracy: 0.9968 - iou: 0.4618 - dice_coef: 0.6255 - val_loss: 0.4371 - val_binary_accuracy: 0.9972 - val_iou: 0.3893 - val_dice_coef: 0.5515
#
# Epoch 00049: val_iou did not improve from 0.00872
# Epoch 50/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.3583 - binary_accuracy: 0.9968 - iou: 0.4788 - dice_coef: 0.6426 - val_loss: 0.4892 - val_binary_accuracy: 0.9972 - val_iou: 0.3666 - val_dice_coef: 0.5171
#
# Epoch 00050: val_iou did not improve from 0.00872
# Epoch 51/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.9444 - binary_accuracy: 0.9400 - iou: 0.0294 - dice_coef: 0.0555 - val_loss: 0.8498 - val_binary_accuracy: 0.9046 - val_iou: 0.0841 - val_dice_coef: 0.1541
#
# Epoch 00051: val_iou did not improve from 0.00872
# Epoch 52/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.3815 - binary_accuracy: 0.9926 - iou: 0.4609 - dice_coef: 0.6193 - val_loss: 0.4304 - val_binary_accuracy: 0.9973 - val_iou: 0.4115 - val_dice_coef: 0.5760
#
# Epoch 00052: val_iou did not improve from 0.00872
# Epoch 53/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.3339 - binary_accuracy: 0.9971 - iou: 0.5054 - dice_coef: 0.6665 - val_loss: 0.3732 - val_binary_accuracy: 0.9972 - val_iou: 0.4515 - val_dice_coef: 0.6054
#
# Epoch 00053: val_iou did not improve from 0.00872
# Epoch 54/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.3220 - binary_accuracy: 0.9970 - iou: 0.5183 - dice_coef: 0.6783 - val_loss: 0.3744 - val_binary_accuracy: 0.9974 - val_iou: 0.4488 - val_dice_coef: 0.6116
#
# Epoch 00054: val_iou did not improve from 0.00872
# Epoch 55/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.3159 - binary_accuracy: 0.9971 - iou: 0.5273 - dice_coef: 0.6836 - val_loss: 0.3917 - val_binary_accuracy: 0.9972 - val_iou: 0.4481 - val_dice_coef: 0.6114
#
# Epoch 00055: val_iou did not improve from 0.00872
# Epoch 56/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.2998 - binary_accuracy: 0.9972 - iou: 0.5429 - dice_coef: 0.6991 - val_loss: 0.3625 - val_binary_accuracy: 0.9971 - val_iou: 0.4740 - val_dice_coef: 0.6355
#
# Epoch 00056: val_iou did not improve from 0.00872
# Epoch 57/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9602 - binary_accuracy: 0.9802 - iou: 0.0218 - dice_coef: 0.0400 - val_loss: 0.5070 - val_binary_accuracy: 0.9925 - val_iou: 0.3348 - val_dice_coef: 0.4947
#
# Epoch 00057: val_iou did not improve from 0.00872
# Epoch 58/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.3087 - binary_accuracy: 0.9967 - iou: 0.5344 - dice_coef: 0.6896 - val_loss: 0.3812 - val_binary_accuracy: 0.9965 - val_iou: 0.4494 - val_dice_coef: 0.6149
#
# Epoch 00058: val_iou did not improve from 0.00872
# Epoch 59/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.2823 - binary_accuracy: 0.9972 - iou: 0.5648 - dice_coef: 0.7180 - val_loss: 0.3551 - val_binary_accuracy: 0.9974 - val_iou: 0.4916 - val_dice_coef: 0.6501
#
# Epoch 00059: val_iou did not improve from 0.00872
# Epoch 60/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.9525 - binary_accuracy: 0.9744 - iou: 0.0255 - dice_coef: 0.0473 - val_loss: 0.6868 - val_binary_accuracy: 0.9700 - val_iou: 0.1843 - val_dice_coef: 0.3041
#
# Epoch 00060: val_iou did not improve from 0.00872
# Epoch 61/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.3075 - binary_accuracy: 0.9953 - iou: 0.5382 - dice_coef: 0.6925 - val_loss: 0.3303 - val_binary_accuracy: 0.9974 - val_iou: 0.5044 - val_dice_coef: 0.6631
#
# Epoch 00061: val_iou did not improve from 0.00872
# Epoch 62/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.2770 - binary_accuracy: 0.9972 - iou: 0.5758 - dice_coef: 0.7231 - val_loss: 0.3271 - val_binary_accuracy: 0.9975 - val_iou: 0.5123 - val_dice_coef: 0.6712
#
# Epoch 00062: val_iou did not improve from 0.00872
# Epoch 63/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.2642 - binary_accuracy: 0.9971 - iou: 0.5903 - dice_coef: 0.7363 - val_loss: 0.3099 - val_binary_accuracy: 0.9975 - val_iou: 0.5401 - val_dice_coef: 0.6937
#
# Epoch 00063: val_iou did not improve from 0.00872
# Epoch 64/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.2664 - binary_accuracy: 0.9970 - iou: 0.5871 - dice_coef: 0.7345 - val_loss: 0.3313 - val_binary_accuracy: 0.9966 - val_iou: 0.4935 - val_dice_coef: 0.6498
#
# Epoch 00064: val_iou did not improve from 0.00872
# Epoch 65/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.2700 - binary_accuracy: 0.9969 - iou: 0.5838 - dice_coef: 0.7295 - val_loss: 0.3173 - val_binary_accuracy: 0.9974 - val_iou: 0.5358 - val_dice_coef: 0.6894
#
# Epoch 00065: val_iou did not improve from 0.00872
# Epoch 66/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.2527 - binary_accuracy: 0.9971 - iou: 0.6047 - dice_coef: 0.7481 - val_loss: 0.2808 - val_binary_accuracy: 0.9973 - val_iou: 0.5474 - val_dice_coef: 0.6932
#
# Epoch 00066: val_iou did not improve from 0.00872
# Epoch 67/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.2356 - binary_accuracy: 0.9973 - iou: 0.6229 - dice_coef: 0.7627 - val_loss: 0.2897 - val_binary_accuracy: 0.9975 - val_iou: 0.5440 - val_dice_coef: 0.6881
#
# Epoch 00067: val_iou did not improve from 0.00872
# Epoch 68/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.9458 - binary_accuracy: 0.9712 - iou: 0.0292 - dice_coef: 0.0540 - val_loss: 0.8077 - val_binary_accuracy: 0.9385 - val_iou: 0.1037 - val_dice_coef: 0.1851
#
# Epoch 00068: val_iou did not improve from 0.00872
# Epoch 69/70
# 88/88 [==============================] - 100s 1s/step - loss: 0.2946 - binary_accuracy: 0.9933 - iou: 0.5627 - dice_coef: 0.7058 - val_loss: 0.2716 - val_binary_accuracy: 0.9973 - val_iou: 0.5716 - val_dice_coef: 0.7242
#
# Epoch 00069: val_iou did not improve from 0.00872
# Epoch 70/70
# 88/88 [==============================] - 99s 1s/step - loss: 0.2306 - binary_accuracy: 0.9972 - iou: 0.6319 - dice_coef: 0.7694 - val_loss: 0.2749 - val_binary_accuracy: 0.9974 - val_iou: 0.5865 - val_dice_coef: 0.7302
#
# Epoch 00070: val_iou did not improve from 0.00872

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Save Model</p> <a id=5.4></a>

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model.h5')

# %%
# saving model achitecture in json file
model_json = model.to_json()
with open("UNet-seg-model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Evaluation</p> <a id=6></a>
#
# Evaluation metrics are listed below

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'iou', 'dice_coef', 'val_loss', 'val_binary_accuracy', 'val_iou', 'val_dice_coef'])

# %% [markdown]
# **Loss function** :  IOU - Intersection over Union

# %% [markdown]
# ![Performance metric : Intersection over Union](data:image/png;base64,...)
#
# ![IOU](data:image/png;base64,...)

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['iou']);
plt.plot(history.history['val_iou']);
plt.title("Segmentation Model IOU Loss");
plt.ylabel("IOU loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %% [markdown]
# <p class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Prediction</p> <a id=7></a>

# %%
test_ids = list(mri_test.img_path)
test_mask = list(mri_test.mask_path)

# %%
def prediction(test, model_seg):
  
    # empty list to store results
    mask, image_id,has_mask = [], [], []
    
    #itetrating through each image in test data
    for i in test.img_path:
        

        
        #Creating a empty array of shape 1,256,256,1
        X = np.empty((1,256,256,3))
        # read the image
        img = io.imread(i)
        #resizing the image and coverting them to array of type float64
        img = cv2.resize(img, (256,256))
        img = np.array(img, dtype=np.float64)
        
        # standardising the image
        img -= img.mean()
        img /= img.std()
        #converting the shape of image from 256,256,3 to 1,256,256,3
        X[0,] = img
        
        #make prediction of mask
        predict = model_seg.predict(X)
        
        # if sum of predicted mask is 0 then there is not tumour
        if predict.round().astype(int).sum()==0:
            image_id.append(i)
            has_mask.append(0)
            mask.append('No mask :)')
        else:
        #if the sum of pixel values are more than 0, then there is tumour
            image_id.append(i)
            has_mask.append(1)
            mask.append(predict)
            
    return pd.DataFrame({'img_path': image_id,'predicted_mask': mask,'has_mask': has_mask})

# %%
df_pred = prediction(mri_test, model)
df_pred
# Out:
#                                               img_path  \
# 0    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ..                                                 ...
# 388  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 389  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 390  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 391  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 392  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                         predicted_mask  has_mask
# 0                                           No mask :)         0
# 1                                           No mask :)         0
# 2    [[[[0.00236282], [0.00236282], [0.00236282], [...         1
# 3    [[[[0.00236282], [0.00236282], [0.00236282], [...         1
# 4    [[[[0.00236282], [0.00236282], [0.00236282], [...         1
# ..                                                 ...       ...
# 388                                         No mask :)         0
# 389                                         No mask :)         0
# 390  [[[[0.00236282], [0.00236282], [0.00236282], [...         1
# 391                                         No mask :)         0
# 392  [[[[0.00236282], [0.00236282], [0.00236282], [...         1
#
# [393 rows x 3 columns]

# %%
df_pred = mri_test.merge(df_pred, on='img_path')
df_pred.head()
# Out:
#                                             img_path  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path  mask  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
#
#                                       predicted_mask  has_mask
# 0                                         No mask :)         0
# 1                                         No mask :)         0
# 2  [[[[0.00236282], [0.00236282], [0.00236282], [...         1
# 3  [[[[0.00236282], [0.00236282], [0.00236282], [...         1
# 4  [[[[0.00236282], [0.00236282], [0.00236282], [...         1

# %%
count = 0
fig, axs = plt.subplots(3,5, figsize=(30,15))

for i in range(len(df_pred)):
    if df_pred.has_mask[i]==1 and count<15:
        #read mri images
        img = io.imread(df_pred.img_path[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        axs[count][0].imshow(img)
        axs[count][0].title.set_text('Brain MRI')
        
        #read original mask
        mask = io.imread(df_pred.mask_path[i])
        axs[count][1].imshow(mask)
        axs[count][1].title.set_text('Original Mask')
        
        #read predicted mask
        pred = np.array(df_pred.predicted_mask[i]).squeeze().round()
        axs[count][2].imshow(pred)
        axs[count][2].title.set_text('AI predicted mask')
        
        #overlay original mask with MRI
        img[mask==255] = (255,0,0)
        axs[count][3].imshow(img)
        axs[count][3].title.set_text('Brain MRI with original mask (Ground Truth)')
        
        #overlay predicted mask and MRI
        img_ = io.imread(df_pred.img_path[i])
        img_ = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
        img_[pred==1] = (0,255,150)
        axs[count][4].imshow(img_)
        axs[count][4].title.set_text('MRI with AI PREDICTED MASK')
        
        count +=1
    if (count==3):
        break

fig.tight_layout()

# %% [markdown]
# **Reference:**
# * [UNet model Original creator Reference link](https://github.com/zhixuhao/unet)
# * [Kaggle Notebook - SAMUEL CORTINHAS](https://www.kaggle.com/code/samuelcortinhas/case-study-u-net-from-scratch#Application:-Tumor-detection)
