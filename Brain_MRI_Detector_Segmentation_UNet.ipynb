# %% [markdown]
# <a href="https://www.kaggle.com/code/tejasurya/unet-guide-brain-mri-detector?scriptVersionId=108204546" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="background-color:red;color:white;font-size:22px;text-align:center;border-radius:10px 10px;font-weight:bold;border:2px solid black">Brain MRI Detector | Segmentation | Using UNet</p>
#
# <center><img src= "https://www.mayoclinic.org/-/media/kcms/gbs/patient-consumer/images/2014/10/30/15/17/mcdc7_brain_cancer-8col.jpg" alt ="Brain-MRI" style='width:300px;'></center>
#
# **Image source** : Mayo Clinic

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Introduction</span> <a id=1></a>
# A brain tumor is a mass or growth of abnormal cells in your brain.Many different types of brain tumors exist. Some brain tumors are noncancerous (benign), and some brain tumors are cancerous (malignant). Brain tumors can begin in your brain (primary brain tumors), or cancer can begin in other parts of your body and spread to your brain as secondary (metastatic) brain tumors.
#
# How quickly a brain tumor grows can vary greatly. The growth rate as well as the location of a brain tumor determines how it will affect the function of your nervous system.
#
# Brain tumor treatment options depend on the type of brain tumor you have, as well as its size and location. <br>
# **Source credits** : [Mayo Clinic](https://www.mayoclinic.org/diseases-conditions/brain-tumor/symptoms-causes/syc-20350084)

# %% [markdown]
# ## <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">What is Image Segmentation?</span> <a id=1.1></a> <br>
#  *  The objective of the Image Segmentation is to classify each pixel of an image with the class it represents, by predicting each pixel in image. <br>
#  *  Here in this notebook,we will implement the U-Net model, its a U-shaped architecture (in keras).
# We will also apply our model to a Brain MRI tumor detection problem to see how it performs.

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Import Libraries</span> <a id=1.1></a> <br>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import glob

import time
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
from IPython.display import Image
from skimage import io

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.layers.experimental import preprocessing
from keras.utils.vis_utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
import cv2
from sklearn.preprocessing import StandardScaler, normalize
from IPython.display import display

# %%
img_data = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
img_data.head()
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0

# %%
img_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
img_data.shape
# Out:
# (110, 18)

# %%
data_path = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            mask_path = sub_dir_path + '/' + filename
            data_path.extend([dir_name, mask_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
filenames = data_path[::2]
masks = data_path[1::2]

# %%
df = pd.DataFrame(data={"patient_id": filenames,"img_path": masks})
df
# Out:
#                  patient_id                                           img_path
# 0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                     ...                                                ...
# 7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [7858 rows x 2 columns]

# %%
original_img     = df[~df['img_path'].str.contains("mask")]
mask_img = df[df['img_path'].str.contains("mask")]

# %%
original_img,mask_img
# Out:
# (                 patient_id                                           img_path
#  0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  5     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7849  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7850  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7852  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns],
#                   patient_id                                           img_path
#  1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  8     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  9     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  11    TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7846  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7851  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns])

# %%
imgs = sorted(original_img["img_path"].values, key=lambda x : int(x[89:-4]))
masks = sorted(mask_img["img_path"].values, key=lambda x : int(x[89:-9]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Image path:", imgs[idx], "\nMask path:", masks[idx])
# Out:
# Image path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_5962_20000626/TCGA_FG_5962_20000626_33.tif
# Mask path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_5962_20000626/TCGA_FG_5962_20000626_33_mask.tif

# %%
mri_df = pd.DataFrame({"patient_id": original_img.patient_id.values,"img_path": imgs,
                           'mask_path':masks})
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [3929 rows x 3 columns]

# %%
def get_diagnosis(img_path):
    value = np.max(cv2.imread(img_path))
    if value > 0 : 
        return 1
    else:
        return 0

# %%
mri_df.head()
# Out:
#               patient_id                                           img_path  \
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
mri_df['mask'] = mri_df['mask_path'].apply(lambda x: get_diagnosis(x))

mri_df['mask_path'] = mri_df['mask_path'].apply(lambda x: str(x))
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# ...                                                 ...   ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
# [3929 rows x 4 columns]

# %%
mri_df.drop(columns=['patient_id'],inplace=True)

# %%
mri_train, mri_test = train_test_split(mri_df,test_size = 0.1)
mri_train, mri_val = train_test_split(mri_train,test_size = 0.2)

print('Training data shape is {0}'.format(mri_train.values.shape))
print('Test data shape is {0}'.format(mri_test.values.shape))
mri_train.sample(n=5)
# Out:
# Training data shape is (2828, 3)
# Test data shape is (393, 3)
#                                                img_path  \
# 1923  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 133   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1669  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2416  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3052  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 1923  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 133   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1669  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 2416  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3052  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">EDA</span> <a id=2></a> <br>
#
# Check Balancing in Data

# %%
mri_df['mask'].value_counts().plot(kind='bar',color=['g','r'],
                title='Count of Tumour vs No Tumour')
# Out:
# <AxesSubplot:title={'center':'Count of Tumour vs No Tumour'}>

# %%
mri_df['mask'].value_counts()
# Out:
# 0    2556
# 1    1373
# Name: mask, dtype: int64

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Image Visualization</span> <a id=2></a> <br>
#
# Visualising the Brain MRI with Tumour

# %%
count = 0
i = 0
fig,axs = plt.subplots(3,3, figsize=(20,20))
for mask in mri_df['mask']:
    if (mask==1):
        img = io.imread(mri_df.img_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(mri_df.mask_path[i])
        axs[count][1].title.set_text("Mask =" + str(mri_df['mask'][i]))
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (255,0,0)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask =" + str(mri_df['mask'][i]))
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==3):
        break
        
fig.tight_layout()

# %%
# Basic visualizations: Visualize the images (MRI and Mask) in the dataset separately 

fig, axs = plt.subplots(4,2, figsize=(13,26))
count = 0
for x in range(4):
  i = random.randint(0, len(mri_df)) 
  axs[count][0].title.set_text("Brain MRI") 
  axs[count][0].imshow(cv2.imread(mri_df.img_path[i])) 
  axs[count][1].title.set_text("Mask - " + str(mri_df['mask'][i])) 
  axs[count][1].imshow(cv2.imread(mri_df.mask_path[i])) 
  count += 1

fig.tight_layout()

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Data Generator</span> <a id=3></a> <br>
# ### Reference : **[UNet](https://github.com/zhixuhao/unet)**

# %%
from keras_preprocessing.image import ImageDataGenerator

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "img_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

# %%
def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(mri_train, 16,
                                train_generator_args,
                                target_size=(256, 256))
    
val_gen = train_generator(mri_val, 16,
                                dict(),
                                target_size=(256, 256))

# %% [markdown]
# # <span style="color:#FF0000;background-color:white;font-size:25px">Build UNet Model</span> <a id=4></a> <br>
#
# <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Architecture</span> <a id=4.1></a>
#
# <center><img src= "https://miro.medium.com/max/1200/1*f7YOaE4TWubwaFF7Z1fzNw.png" alt ="UNet" style='width:800px;'></center>

# %% [markdown]
# UNet is named after the shape of it's architecture (U - shaped). UNet model is used to solve Image Segmentation problems especially in Medical related problems.
#
# The input layer has 572x572x1 dimension in the above architecture. The 1 column dimension specifies the input is b/w image. If the input dimension was 572x572x3 , the input image is rgb coloured image.
# After the input layer,we can divide this UNet architecture into 4 parts
# * Encoder Part (Contracting path)
# * Upsampling2D
# * Decoder part (Expanding Path)
# * Skip Connection (Residual connection)
#
#
# Briefly into the Details of these parts: <br>
# **Encoder Part**
# The initial half of the U-shaped architecture is the Contracting path(Encoder part). As the name Contracting path denotes, the dimension of the input image keeps reducing as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=64 followed by Maxpool2D layer (reduces size divided by 2). Now again 2 - Conv2D layers (128 filters) and 1 Maxpooling2D , 2 - Conv2D layers (256 filters) and 1 Maxpooling2D completely contracts the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Upsampling2D**
# The Upsampling2D layer upsamples the layer output dimension by duplicating the row values twice.The concatenation of the upsampling2D and contracting path happens here leading into the Expanding path.
# The Upsampling layer is present after 2 conv2D layers in Decoder part, similar to presence of  Maxpooling as in Encoder part.
#
# **Decoder Path**
# The second half of the U-shaped architecture is the Expanding path(Decoder part). As the name Expanding path denotes, the dimension of the image keeps expanding as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=512 followed by Upsampling2D layer (duplicates size divided by 2). Now again 2 - Conv2D layers (256 filters) and 1 Upsampling2D ,2 - Conv2D layers (128 filters) and 1 Upsampling2D, 2 - Conv2D layers (64 filters) completely expands the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Skip Connection (Residual connection)**
# The Skip Connection (Residual connection) alias the identity mapping is present after each of the 2 Conv2D layers in Encoder to the corresponding same shaped dimension layer in the Decoder part . In the above architecture the copy and crop does residual connection task.The Concatenate layer does the work of adding those two layers. This skip connection doesnot harm the model in any way even in worst case but definitely benificial to the output in the model.
#
# Finally the decoder part ends with the Output Segmentation map with filters 2. This layer is again passed through a Conv2D with Sigmoid activation and filters 1. The output classifies each pixel if tumour is present or not in it.
#
# ### Reference : [UNet](https://github.com/zhixuhao/unet)

# %%
def unet(pretrained_weights = None,input_size = (256,256,3)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(conv1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(conv2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(conv3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv4)
    drop4 = Dropout(0.5)(conv4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(drop4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv5)
    drop5 = Dropout(0.5)(conv5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(drop5))
    merge6 = concatenate([drop4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv6)

    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv7)

    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv8)

    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(conv8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)

    model = model = Model(inputs=[inputs] , outputs = [conv10])    
    return model

# %%
model = unet()
model.summary()
# Out:
# 2022-10-15 22:42:17.434886: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:17.533415: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:17.534322: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:17.535578: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-15 22:42:17.535918: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:17.536651: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:17.537359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:19.904661: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:19.905536: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:19.906209: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-15 22:42:19.906825: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# dropout (Dropout)               (None, 32, 32, 512)  0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           dropout[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# dropout_1 (Dropout)             (None, 16, 16, 1024) 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           dropout_1[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           dropout[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 1)  3           conv2d_22[0][0]
# ==================================================================================================
# Total params: 31,032,837
# Trainable params: 31,032,837
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Model architecture</span> <a id=5></a>

# %%
plot_model(model, to_file='unet_model.png', show_shapes=True)
Image("unet_model.png")

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Callbacks</span> <a id=5.2></a> <br>
#
# The Callbacks used are
# * Learning Rate reduction
# * Early Stopping
# * Model Checkpoint

# %%
lr_reduction = ReduceLROnPlateau(monitor='loss',patience=8, verbose=1,
                                 factor=0.4, min_lr=0.0001)

early_stop = EarlyStopping(monitor='loss', min_delta=0.00001, patience=8, 
                           mode='auto', restore_best_weights=True)

model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1,
                                   save_best_only=True)

# %%
EPOCH = 300
learning_rate = 1e-4

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Performance Metrics</span> <a id=5.2></a>

# %%
smooth =100
def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Model Fit</span> <a id=5.3></a>

# %%
model.compile(optimizer=Adam(learning_rate=1e-4, beta_1=0.9, beta_2=0.9, epsilon=None), 
              loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

# %%
history = model.fit(train_gen,steps_per_epoch=len(mri_train) / 16,
                    epochs=EPOCH ,validation_data=val_gen,validation_steps=len(mri_val) / 16,
                    callbacks=[model_checkpoint,lr_reduction])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# 2022-10-15 22:42:26.128409: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/300
# 2022-10-15 22:42:28.604079: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 177/176 [==============================] - ETA: 0s - loss: 0.9604 - binary_accuracy: 0.8887 - iou: 0.0263 - dice_coef: 0.0395Found 708 validated image filenames.
# Found 708 validated image filenames.
# 176/176 [==============================] - 130s 645ms/step - loss: 0.9604 - binary_accuracy: 0.8887 - iou: 0.0263 - dice_coef: 0.0395 - val_loss: 0.9871 - val_binary_accuracy: 0.9901 - val_iou: 0.0138 - val_dice_coef: 0.0138
#
# Epoch 00001: loss improved from inf to 0.96042, saving model to unet_membrane.hdf5
# Epoch 2/300
# 176/176 [==============================] - 98s 553ms/step - loss: 0.9873 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9878 - val_binary_accuracy: 0.9901 - val_iou: 0.0132 - val_dice_coef: 0.0132
#
# Epoch 00002: loss did not improve from 0.96042
# Epoch 3/300
# 176/176 [==============================] - 97s 549ms/step - loss: 0.9862 - binary_accuracy: 0.9898 - iou: 0.0139 - dice_coef: 0.0139 - val_loss: 0.9863 - val_binary_accuracy: 0.9901 - val_iou: 0.0137 - val_dice_coef: 0.0137
#
# Epoch 00003: loss did not improve from 0.96042
# Epoch 4/300
# 176/176 [==============================] - 97s 549ms/step - loss: 0.9873 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9858 - val_binary_accuracy: 0.9903 - val_iou: 0.0146 - val_dice_coef: 0.0146
#
# Epoch 00004: loss did not improve from 0.96042
# Epoch 5/300
# 176/176 [==============================] - 97s 550ms/step - loss: 0.9873 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9878 - val_binary_accuracy: 0.9902 - val_iou: 0.0125 - val_dice_coef: 0.0125
#
# Epoch 00005: loss did not improve from 0.96042
# Epoch 6/300
# 176/176 [==============================] - 97s 552ms/step - loss: 0.9864 - binary_accuracy: 0.9899 - iou: 0.0136 - dice_coef: 0.0136 - val_loss: 0.9857 - val_binary_accuracy: 0.9899 - val_iou: 0.0144 - val_dice_coef: 0.0144
#
# Epoch 00006: loss did not improve from 0.96042
# Epoch 7/300
# 176/176 [==============================] - 97s 550ms/step - loss: 0.9821 - binary_accuracy: 0.9898 - iou: 0.0179 - dice_coef: 0.0179 - val_loss: 0.9841 - val_binary_accuracy: 0.9904 - val_iou: 0.0166 - val_dice_coef: 0.0166
#
# Epoch 00007: loss did not improve from 0.96042
# Epoch 8/300
# 176/176 [==============================] - 97s 551ms/step - loss: 0.9839 - binary_accuracy: 0.9898 - iou: 0.0161 - dice_coef: 0.0161 - val_loss: 0.9775 - val_binary_accuracy: 0.9900 - val_iou: 0.0225 - val_dice_coef: 0.0225
#
# Epoch 00008: loss did not improve from 0.96042
# Epoch 9/300
# 176/176 [==============================] - 97s 549ms/step - loss: 0.9852 - binary_accuracy: 0.9898 - iou: 0.0148 - dice_coef: 0.0148 - val_loss: 0.9862 - val_binary_accuracy: 0.9905 - val_iou: 0.0151 - val_dice_coef: 0.0151
#
# Epoch 00009: loss did not improve from 0.96042
# Epoch 10/300
# 176/176 [==============================] - 97s 551ms/step - loss: 0.9874 - binary_accuracy: 0.9898 - iou: 0.0126 - dice_coef: 0.0126 - val_loss: 0.9816 - val_binary_accuracy: 0.9899 - val_iou: 0.0183 - val_dice_coef: 0.0183
#
# Epoch 00010: loss did not improve from 0.96042
# Epoch 11/300
# 176/176 [==============================] - 97s 550ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0125 - dice_coef: 0.0125 - val_loss: 0.9879 - val_binary_accuracy: 0.9902 - val_iou: 0.0127 - val_dice_coef: 0.0127
#
# Epoch 00011: loss did not improve from 0.96042
# Epoch 12/300
# 176/176 [==============================] - 98s 552ms/step - loss: 0.9872 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9880 - val_binary_accuracy: 0.9900 - val_iou: 0.0120 - val_dice_coef: 0.0120
#
# Epoch 00012: loss did not improve from 0.96042
# Epoch 13/300
# 176/176 [==============================] - 98s 552ms/step - loss: 0.9800 - binary_accuracy: 0.9898 - iou: 0.0199 - dice_coef: 0.0199 - val_loss: 0.9854 - val_binary_accuracy: 0.9900 - val_iou: 0.0167 - val_dice_coef: 0.0167
#
# Epoch 00013: loss did not improve from 0.96042
# Epoch 14/300
# 176/176 [==============================] - 98s 552ms/step - loss: 0.9814 - binary_accuracy: 0.9898 - iou: 0.0187 - dice_coef: 0.0187 - val_loss: 0.9829 - val_binary_accuracy: 0.9902 - val_iou: 0.0172 - val_dice_coef: 0.0172
#
# Epoch 00014: loss did not improve from 0.96042
# Epoch 15/300
# Epoch 35/300
# 176/176 [==============================] - 98s 553ms/step - loss: 0.9867 - binary_accuracy: 0.9898 - iou: 0.0134 - dice_coef: 0.0134 - val_loss: 0.9884 - val_binary_accuracy: 0.9893 - val_iou: 0.0117 - val_dice_coef: 0.0117
#
# Epoch 00035: loss did not improve from 0.96042
# Epoch 36/300
# 176/176 [==============================] - 97s 552ms/step - loss: 0.9869 - binary_accuracy: 0.9898 - iou: 0.0132 - dice_coef: 0.0132 - val_loss: 0.9865 - val_binary_accuracy: 0.9907 - val_iou: 0.0135 - val_dice_coef: 0.0135
#
# Epoch 00036: loss did not improve from 0.96042
# Epoch 37/300
# 176/176 [==============================] - 98s 552ms/step - loss: 0.9882 - binary_accuracy: 0.9898 - iou: 0.0118 - dice_coef: 0.0118 - val_loss: 0.9878 - val_binary_accuracy: 0.9899 - val_iou: 0.0140 - val_dice_coef: 0.0140
#
# Epoch 00037: loss did not improve from 0.96042
# Epoch 38/300
# 176/176 [==============================] - 98s 553ms/step - loss: 0.9877 - binary_accuracy: 0.9899 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9853 - val_binary_accuracy: 0.9908 - val_iou: 0.0149 - val_dice_coef: 0.0149
#
# Epoch 00038: loss did not improve from 0.96042
# Epoch 39/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9876 - binary_accuracy: 0.9898 - iou: 0.0124 - dice_coef: 0.0124 - val_loss: 0.9628 - val_binary_accuracy: 0.9901 - val_iou: 0.0369 - val_dice_coef: 0.0369
#
# Epoch 00039: loss did not improve from 0.96042
# Epoch 40/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9787 - binary_accuracy: 0.9898 - iou: 0.0213 - dice_coef: 0.0213 - val_loss: 0.9807 - val_binary_accuracy: 0.9903 - val_iou: 0.0227 - val_dice_coef: 0.0227
#
# Epoch 00040: loss did not improve from 0.96042
# Epoch 41/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9876 - binary_accuracy: 0.9898 - iou: 0.0124 - dice_coef: 0.0124 - val_loss: 0.9808 - val_binary_accuracy: 0.9895 - val_iou: 0.0356 - val_dice_coef: 0.0356
#
# Epoch 00041: loss did not improve from 0.96042
# Epoch 42/300
# 176/176 [==============================] - 98s 553ms/step - loss: 0.9876 - binary_accuracy: 0.9898 - iou: 0.0124 - dice_coef: 0.0124 - val_loss: 0.9846 - val_binary_accuracy: 0.9902 - val_iou: 0.0166 - val_dice_coef: 0.0166
#
# Epoch 00042: loss did not improve from 0.96042
# Epoch 43/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9862 - binary_accuracy: 0.9898 - iou: 0.0138 - dice_coef: 0.0138 - val_loss: 0.9879 - val_binary_accuracy: 0.9901 - val_iou: 0.0125 - val_dice_coef: 0.0125
#
# Epoch 00043: loss did not improve from 0.96042
# Epoch 44/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9878 - binary_accuracy: 0.9898 - iou: 0.0122 - dice_coef: 0.0122 - val_loss: 0.9824 - val_binary_accuracy: 0.9902 - val_iou: 0.0340 - val_dice_coef: 0.0340
#
# Epoch 00044: loss did not improve from 0.96042
# Epoch 45/300
# 176/176 [==============================] - 97s 551ms/step - loss: 0.9876 - binary_accuracy: 0.9898 - iou: 0.0124 - dice_coef: 0.0124 - val_loss: 0.9867 - val_binary_accuracy: 0.9902 - val_iou: 0.0149 - val_dice_coef: 0.0149
#
# Epoch 00045: loss did not improve from 0.96042
# Epoch 46/300
# 176/176 [==============================] - 97s 551ms/step - loss: 0.9872 - binary_accuracy: 0.9899 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9864 - val_binary_accuracy: 0.9901 - val_iou: 0.0142 - val_dice_coef: 0.0142
#
# Epoch 00046: loss did not improve from 0.96042
# Epoch 47/300
# 176/176 [==============================] - 97s 551ms/step - loss: 0.9862 - binary_accuracy: 0.9898 - iou: 0.0138 - dice_coef: 0.0138 - val_loss: 0.9873 - val_binary_accuracy: 0.9903 - val_iou: 0.0127 - val_dice_coef: 0.0127
#
# Epoch 00047: loss did not improve from 0.96042
# Epoch 48/300
# 176/176 [==============================] - 98s 553ms/step - loss: 0.9853 - binary_accuracy: 0.9898 - iou: 0.0147 - dice_coef: 0.0147 - val_loss: 0.9888 - val_binary_accuracy: 0.9900 - val_iou: 0.0117 - val_dice_coef: 0.0117
#
# Epoch 00048: loss did not improve from 0.96042
# Epoch 49/300
# 176/176 [==============================] - 97s 552ms/step - loss: 0.9839 - binary_accuracy: 0.9898 - iou: 0.0160 - dice_coef: 0.0160 - val_loss: 0.9881 - val_binary_accuracy: 0.9905 - val_iou: 0.0125 - val_dice_coef: 0.0125
#
# Epoch 00049: loss did not improve from 0.96042
# Epoch 50/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9848 - binary_accuracy: 0.9898 - iou: 0.0152 - dice_coef: 0.0152 - val_loss: 0.9879 - val_binary_accuracy: 0.9899 - val_iou: 0.0127 - val_dice_coef: 0.0127
#
# Epoch 00050: loss did not improve from 0.96042
# Epoch 51/300
# 176/176 [==============================] - 98s 553ms/step - loss: 0.9816 - binary_accuracy: 0.9898 - iou: 0.0184 - dice_coef: 0.0184 - val_loss: 0.9861 - val_binary_accuracy: 0.9901 - val_iou: 0.0140 - val_dice_coef: 0.0140
#
# Epoch 00051: loss did not improve from 0.96042
# Epoch 52/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9843 - binary_accuracy: 0.9898 - iou: 0.0157 - dice_coef: 0.0157 - val_loss: 0.9830 - val_binary_accuracy: 0.9900 - val_iou: 0.0334 - val_dice_coef: 0.0334
#
# Epoch 00052: loss did not improve from 0.96042
# Epoch 53/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9803 - binary_accuracy: 0.9898 - iou: 0.0197 - dice_coef: 0.0197 - val_loss: 0.9875 - val_binary_accuracy: 0.9897 - val_iou: 0.0131 - val_dice_coef: 0.0131
#
# Epoch 00053: loss did not improve from 0.96042
# Epoch 54/300
# 176/176 [==============================] - 97s 551ms/step - loss: 0.9864 - binary_accuracy: 0.9898 - iou: 0.0136 - dice_coef: 0.0136 - val_loss: 0.9854 - val_binary_accuracy: 0.9909 - val_iou: 0.0160 - val_dice_coef: 0.0160
#
# Epoch 00054: loss did not improve from 0.96042
# Epoch 55/300
# 176/176 [==============================] - 98s 552ms/step - loss: 0.9869 - binary_accuracy: 0.9898 - iou: 0.0131 - dice_coef: 0.0131 - val_loss: 0.9872 - val_binary_accuracy: 0.9897 - val_iou: 0.0134 - val_dice_coef: 0.0134
#
# Epoch 00055: loss did not improve from 0.96042
# Epoch 56/300
# 176/176 [==============================] - 98s 552ms/step - loss: 0.9882 - binary_accuracy: 0.9898 - iou: 0.0118 - dice_coef: 0.0118 - val_loss: 0.9815 - val_binary_accuracy: 0.9903 - val_iou: 0.0349 - val_dice_coef: 0.0349
#
# Epoch 00056: loss did not improve from 0.96042
# Epoch 57/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0125 - dice_coef: 0.0125 - val_loss: 0.9811 - val_binary_accuracy: 0.9907 - val_iou: 0.0190 - val_dice_coef: 0.0190
#
# Epoch 00057: loss did not improve from 0.96042
# Epoch 58/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9865 - val_binary_accuracy: 0.9893 - val_iou: 0.0137 - val_dice_coef: 0.0137
#
# Epoch 00058: loss did not improve from 0.96042
# Epoch 59/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9876 - binary_accuracy: 0.9898 - iou: 0.0124 - dice_coef: 0.0124 - val_loss: 0.9877 - val_binary_accuracy: 0.9902 - val_iou: 0.0131 - val_dice_coef: 0.0131
#
# Epoch 00059: loss did not improve from 0.96042
# Epoch 60/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9872 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9743 - val_binary_accuracy: 0.9905 - val_iou: 0.0257 - val_dice_coef: 0.0257
#
# Epoch 00060: loss did not improve from 0.96042
# Epoch 61/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9763 - val_binary_accuracy: 0.9900 - val_iou: 0.0243 - val_dice_coef: 0.0243
#
# Epoch 00061: loss did not improve from 0.96042
# Epoch 62/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9858 - binary_accuracy: 0.9898 - iou: 0.0142 - dice_coef: 0.0142 - val_loss: 0.9874 - val_binary_accuracy: 0.9903 - val_iou: 0.0147 - val_dice_coef: 0.0147
#
# Epoch 00062: loss did not improve from 0.96042
# Epoch 63/300
# 176/176 [==============================] - 98s 553ms/step - loss: 0.9856 - binary_accuracy: 0.9898 - iou: 0.0144 - dice_coef: 0.0144 - val_loss: 0.9886 - val_binary_accuracy: 0.9894 - val_iou: 0.0132 - val_dice_coef: 0.0132
#
# Epoch 00063: loss did not improve from 0.96042
# Epoch 64/300
# 176/176 [==============================] - 98s 552ms/step - loss: 0.9878 - binary_accuracy: 0.9898 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9873 - val_binary_accuracy: 0.9901 - val_iou: 0.0130 - val_dice_coef: 0.0130
#
# Epoch 00064: loss did not improve from 0.96042
# Epoch 65/300
# 176/176 [==============================] - 98s 552ms/step - loss: 0.9856 - binary_accuracy: 0.9898 - iou: 0.0144 - dice_coef: 0.0144 - val_loss: 0.9880 - val_binary_accuracy: 0.9904 - val_iou: 0.0122 - val_dice_coef: 0.0122
#
# Epoch 00065: loss did not improve from 0.96042
# Epoch 66/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9825 - val_binary_accuracy: 0.9901 - val_iou: 0.0174 - val_dice_coef: 0.0174
#
# Epoch 00066: loss did not improve from 0.96042
# Epoch 67/300
# 176/176 [==============================] - 98s 556ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0124 - dice_coef: 0.0124 - val_loss: 0.9876 - val_binary_accuracy: 0.9902 - val_iou: 0.0126 - val_dice_coef: 0.0126
#
# Epoch 00067: loss did not improve from 0.96042
# Epoch 68/300
# 176/176 [==============================] - 98s 556ms/step - loss: 0.9878 - binary_accuracy: 0.9898 - iou: 0.0122 - dice_coef: 0.0122 - val_loss: 0.9857 - val_binary_accuracy: 0.9896 - val_iou: 0.0159 - val_dice_coef: 0.0159
#
# Epoch 00068: loss did not improve from 0.96042
# Epoch 69/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9779 - binary_accuracy: 0.9898 - iou: 0.0221 - dice_coef: 0.0221 - val_loss: 0.9639 - val_binary_accuracy: 0.9908 - val_iou: 0.0380 - val_dice_coef: 0.0380
#
# Epoch 00069: loss did not improve from 0.96042
# Epoch 70/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9870 - val_binary_accuracy: 0.9901 - val_iou: 0.0131 - val_dice_coef: 0.0131
#
# Epoch 00070: loss did not improve from 0.96042
# Epoch 71/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9873 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9812 - val_binary_accuracy: 0.9901 - val_iou: 0.0351 - val_dice_coef: 0.0351
#
# Epoch 00071: loss did not improve from 0.96042
# Epoch 72/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9873 - binary_accuracy: 0.9899 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9876 - val_binary_accuracy: 0.9907 - val_iou: 0.0132 - val_dice_coef: 0.0132
#
# Epoch 00072: loss did not improve from 0.96042
# Epoch 73/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9878 - binary_accuracy: 0.9898 - iou: 0.0122 - dice_coef: 0.0122 - val_loss: 0.9865 - val_binary_accuracy: 0.9904 - val_iou: 0.0179 - val_dice_coef: 0.0179
#
# Epoch 00073: loss did not improve from 0.96042
# Epoch 74/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9881 - binary_accuracy: 0.9898 - iou: 0.0119 - dice_coef: 0.0119 - val_loss: 0.9862 - val_binary_accuracy: 0.9896 - val_iou: 0.0146 - val_dice_coef: 0.0146
#
# Epoch 00074: loss did not improve from 0.96042
# Epoch 75/300
# 176/176 [==============================] - 98s 556ms/step - loss: 0.9782 - binary_accuracy: 0.9898 - iou: 0.0232 - dice_coef: 0.0232 - val_loss: 0.9713 - val_binary_accuracy: 0.9906 - val_iou: 0.0287 - val_dice_coef: 0.0287
#
# Epoch 00075: loss did not improve from 0.96042
# Epoch 76/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9818 - binary_accuracy: 0.9898 - iou: 0.0183 - dice_coef: 0.0183 - val_loss: 0.9867 - val_binary_accuracy: 0.9891 - val_iou: 0.0139 - val_dice_coef: 0.0139
#
# Epoch 00076: loss did not improve from 0.96042
# Epoch 77/300
# 176/176 [==============================] - 98s 556ms/step - loss: 0.9872 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9565 - val_binary_accuracy: 0.9904 - val_iou: 0.0595 - val_dice_coef: 0.0595
#
# Epoch 00077: loss did not improve from 0.96042
# Epoch 78/300
# 176/176 [==============================] - 99s 558ms/step - loss: 0.9863 - binary_accuracy: 0.9898 - iou: 0.0137 - dice_coef: 0.0137 - val_loss: 0.9603 - val_binary_accuracy: 0.9902 - val_iou: 0.0557 - val_dice_coef: 0.0557
#
# Epoch 00078: loss did not improve from 0.96042
# Epoch 79/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9868 - binary_accuracy: 0.9898 - iou: 0.0133 - dice_coef: 0.0133 - val_loss: 0.9871 - val_binary_accuracy: 0.9907 - val_iou: 0.0129 - val_dice_coef: 0.0129
#
# Epoch 00079: loss did not improve from 0.96042
# Epoch 80/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9869 - binary_accuracy: 0.9898 - iou: 0.0131 - dice_coef: 0.0131 - val_loss: 0.9875 - val_binary_accuracy: 0.9907 - val_iou: 0.0132 - val_dice_coef: 0.0132
#
# Epoch 00080: loss did not improve from 0.96042
# Epoch 81/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9872 - val_binary_accuracy: 0.9896 - val_iou: 0.0129 - val_dice_coef: 0.0129
#
# Epoch 00081: loss did not improve from 0.96042
# Epoch 82/300
# 176/176 [==============================] - 98s 556ms/step - loss: 0.9841 - binary_accuracy: 0.9898 - iou: 0.0160 - dice_coef: 0.0160 - val_loss: 0.9854 - val_binary_accuracy: 0.9899 - val_iou: 0.0146 - val_dice_coef: 0.0146
#
# Epoch 00082: loss did not improve from 0.96042
# Epoch 83/300
# 176/176 [==============================] - 98s 554ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0125 - dice_coef: 0.0125 - val_loss: 0.9880 - val_binary_accuracy: 0.9903 - val_iou: 0.0123 - val_dice_coef: 0.0123
#
# Epoch 00083: loss did not improve from 0.96042
# Epoch 84/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9873 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9846 - val_binary_accuracy: 0.9905 - val_iou: 0.0168 - val_dice_coef: 0.0168
#
# Epoch 00084: loss did not improve from 0.96042
# Epoch 85/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9809 - binary_accuracy: 0.9898 - iou: 0.0191 - dice_coef: 0.0191 - val_loss: 0.9878 - val_binary_accuracy: 0.9898 - val_iou: 0.0124 - val_dice_coef: 0.0124
#
# Epoch 00085: loss did not improve from 0.96042
# Epoch 86/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9849 - binary_accuracy: 0.9898 - iou: 0.0151 - dice_coef: 0.0151 - val_loss: 0.9832 - val_binary_accuracy: 0.9901 - val_iou: 0.0179 - val_dice_coef: 0.0179
#
# Epoch 00086: loss did not improve from 0.96042
# Epoch 87/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9866 - binary_accuracy: 0.9898 - iou: 0.0134 - dice_coef: 0.0134 - val_loss: 0.9865 - val_binary_accuracy: 0.9900 - val_iou: 0.0135 - val_dice_coef: 0.0135
#
# Epoch 00087: loss did not improve from 0.96042
# Epoch 88/300
# 176/176 [==============================] - 98s 557ms/step - loss: 0.9798 - binary_accuracy: 0.9898 - iou: 0.0202 - dice_coef: 0.0202 - val_loss: 0.9865 - val_binary_accuracy: 0.9901 - val_iou: 0.0136 - val_dice_coef: 0.0136
#
# Epoch 00088: loss did not improve from 0.96042
# Epoch 89/300
# 176/176 [==============================] - 98s 556ms/step - loss: 0.9819 - binary_accuracy: 0.9898 - iou: 0.0181 - dice_coef: 0.0181 - val_loss: 0.9882 - val_binary_accuracy: 0.9904 - val_iou: 0.0120 - val_dice_coef: 0.0120
#
# Epoch 00089: loss did not improve from 0.96042
# Epoch 90/300
# 176/176 [==============================] - 98s 555ms/step - loss: 0.9864 - binary_accuracy: 0.9898 - iou: 0.0136 - dice_coef: 0.0136 - val_loss: 0.9805 - val_binary_accuracy: 0.9901 - val_iou: 0.0198 - val_dice_coef: 0.0198
#
# Epoch 00090: loss did not improve from 0.96042
# Epoch 91/300
# 176/176 [==============================] - 98s 557ms/step - loss: 0.9868 - binary_accuracy: 0.9899 - iou: 0.0133 - dice_coef: 0.0133 - val_loss: 0.9879 - val_binary_accuracy: 0.9901 - val_iou: 0.0125 - val_dice_coef: 0.0125
#
# Epoch 00091: loss did not improve from 0.96042
# Epoch 92/300
# 176/176 [==============================] - 99s 558ms/step - loss: 0.9860 - binary_accuracy: 0.9898 - iou: 0.0140 - dice_coef: 0.0140 - val_loss: 0.9854 - val_binary_accuracy: 0.9901 - val_iou: 0.0149 - val_dice_coef: 0.0149
#
# Epoch 00092: loss did not improve from 0.96042
# Epoch 93/300
# 176/176 [==============================] - 99s 561ms/step - loss: 0.9879 - binary_accuracy: 0.9898 - iou: 0.0121 - dice_coef: 0.0121 - val_loss: 0.9848 - val_binary_accuracy: 0.9898 - val_iou: 0.0153 - val_dice_coef: 0.0153
#
# Epoch 00093: loss did not improve from 0.96042
# Epoch 94/300
# 176/176 [==============================] - 98s 557ms/step - loss: 0.9863 - binary_accuracy: 0.9898 - iou: 0.0137 - dice_coef: 0.0137 - val_loss: 0.9854 - val_binary_accuracy: 0.9904 - val_iou: 0.0201 - val_dice_coef: 0.0201
#
# Epoch 00094: loss did not improve from 0.96042
# Epoch 95/300
# 176/176 [==============================] - 99s 558ms/step - loss: 0.9874 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9785 - val_binary_accuracy: 0.9909 - val_iou: 0.0378 - val_dice_coef: 0.0378
#
# Epoch 00095: loss did not improve from 0.96042
# Epoch 96/300
# 176/176 [==============================] - 99s 558ms/step - loss: 0.9877 - binary_accuracy: 0.9898 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9881 - val_binary_accuracy: 0.9895 - val_iou: 0.0125 - val_dice_coef: 0.0125
#
# Epoch 00096: loss did not improve from 0.96042
# Epoch 97/300
# 176/176 [==============================] - 99s 559ms/step - loss: 0.9864 - binary_accuracy: 0.9898 - iou: 0.0136 - dice_coef: 0.0136 - val_loss: 0.9808 - val_binary_accuracy: 0.9909 - val_iou: 0.0355 - val_dice_coef: 0.0355
#
# Epoch 00097: loss did not improve from 0.96042
# Epoch 98/300
# 176/176 [==============================] - 99s 558ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9873 - val_binary_accuracy: 0.9898 - val_iou: 0.0130 - val_dice_coef: 0.0130
#
# Epoch 00098: loss did not improve from 0.96042
# Epoch 99/300
#
# Epoch 00118: loss did not improve from 0.96042
# Epoch 119/300
# 176/176 [==============================] - 99s 558ms/step - loss: 0.9877 - binary_accuracy: 0.9898 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9883 - val_binary_accuracy: 0.9900 - val_iou: 0.0122 - val_dice_coef: 0.0122
#
# Epoch 00119: loss did not improve from 0.96042
# Epoch 120/300
# 176/176 [==============================] - 99s 560ms/step - loss: 0.9872 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9868 - val_binary_accuracy: 0.9903 - val_iou: 0.0134 - val_dice_coef: 0.0134
#
# Epoch 00120: loss did not improve from 0.96042
# Epoch 121/300
# 176/176 [==============================] - 99s 561ms/step - loss: 0.9845 - binary_accuracy: 0.9898 - iou: 0.0155 - dice_coef: 0.0155 - val_loss: 0.9889 - val_binary_accuracy: 0.9890 - val_iou: 0.0124 - val_dice_coef: 0.0124
#
# Epoch 00121: loss did not improve from 0.96042
# Epoch 122/300
# 176/176 [==============================] - 99s 561ms/step - loss: 0.9874 - binary_accuracy: 0.9898 - iou: 0.0126 - dice_coef: 0.0126 - val_loss: 0.9778 - val_binary_accuracy: 0.9906 - val_iou: 0.0226 - val_dice_coef: 0.0226
#
# Epoch 00122: loss did not improve from 0.96042
# Epoch 123/300
# 176/176 [==============================] - 99s 561ms/step - loss: 0.9772 - binary_accuracy: 0.9898 - iou: 0.0228 - dice_coef: 0.0228 - val_loss: 0.9857 - val_binary_accuracy: 0.9905 - val_iou: 0.0147 - val_dice_coef: 0.0147
#
# Epoch 00123: loss did not improve from 0.96042
# Epoch 124/300
# 176/176 [==============================] - 100s 563ms/step - loss: 0.9863 - binary_accuracy: 0.9898 - iou: 0.0137 - dice_coef: 0.0137 - val_loss: 0.9813 - val_binary_accuracy: 0.9907 - val_iou: 0.0351 - val_dice_coef: 0.0351
#
# Epoch 00124: loss did not improve from 0.96042
# Epoch 125/300
# 176/176 [==============================] - 99s 560ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9880 - val_binary_accuracy: 0.9898 - val_iou: 0.0127 - val_dice_coef: 0.0127
#
# Epoch 00125: loss did not improve from 0.96042
# Epoch 126/300
# 176/176 [==============================] - 99s 560ms/step - loss: 0.9873 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9813 - val_binary_accuracy: 0.9903 - val_iou: 0.0351 - val_dice_coef: 0.0351
#
# Epoch 00126: loss did not improve from 0.96042
# Epoch 127/300
# 176/176 [==============================] - 99s 563ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9885 - val_binary_accuracy: 0.9893 - val_iou: 0.0116 - val_dice_coef: 0.0116
#
# Epoch 00127: loss did not improve from 0.96042
# Epoch 128/300
# Epoch 00147: loss did not improve from 0.96042
# Epoch 148/300
# 176/176 [==============================] - 99s 561ms/step - loss: 0.9864 - binary_accuracy: 0.9898 - iou: 0.0136 - dice_coef: 0.0136 - val_loss: 0.9887 - val_binary_accuracy: 0.9894 - val_iou: 0.0117 - val_dice_coef: 0.0117
#
# Epoch 00148: loss did not improve from 0.96042
# Epoch 149/300
# 176/176 [==============================] - 99s 563ms/step - loss: 0.9853 - binary_accuracy: 0.9898 - iou: 0.0148 - dice_coef: 0.0148 - val_loss: 0.9844 - val_binary_accuracy: 0.9908 - val_iou: 0.0156 - val_dice_coef: 0.0156
#
# Epoch 00149: loss did not improve from 0.96042
# Epoch 150/300
# 176/176 [==============================] - 99s 563ms/step - loss: 0.9863 - binary_accuracy: 0.9898 - iou: 0.0137 - dice_coef: 0.0137 - val_loss: 0.9874 - val_binary_accuracy: 0.9893 - val_iou: 0.0154 - val_dice_coef: 0.0154
#
# Epoch 00150: loss did not improve from 0.96042
# Epoch 151/300
# 176/176 [==============================] - 100s 564ms/step - loss: 0.9886 - binary_accuracy: 0.9898 - iou: 0.0114 - dice_coef: 0.0114 - val_loss: 0.9809 - val_binary_accuracy: 0.9910 - val_iou: 0.0354 - val_dice_coef: 0.0354
#
# Epoch 00151: loss did not improve from 0.96042
# Epoch 152/300
# 176/176 [==============================] - 100s 567ms/step - loss: 0.9877 - binary_accuracy: 0.9898 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9875 - val_binary_accuracy: 0.9898 - val_iou: 0.0137 - val_dice_coef: 0.0137
#
# Epoch 00152: loss did not improve from 0.96042
# Epoch 153/300
# 176/176 [==============================] - 100s 565ms/step - loss: 0.9867 - binary_accuracy: 0.9898 - iou: 0.0133 - dice_coef: 0.0133 - val_loss: 0.9868 - val_binary_accuracy: 0.9903 - val_iou: 0.0139 - val_dice_coef: 0.0139
#
# Epoch 00153: loss did not improve from 0.96042
# Epoch 154/300
# 176/176 [==============================] - 100s 564ms/step - loss: 0.9854 - binary_accuracy: 0.9898 - iou: 0.0146 - dice_coef: 0.0146 - val_loss: 0.9880 - val_binary_accuracy: 0.9904 - val_iou: 0.0128 - val_dice_coef: 0.0128
#
# Epoch 00154: loss did not improve from 0.96042
# Epoch 155/300
# 176/176 [==============================] - 100s 565ms/step - loss: 0.9871 - binary_accuracy: 0.9898 - iou: 0.0129 - dice_coef: 0.0129 - val_loss: 0.9864 - val_binary_accuracy: 0.9904 - val_iou: 0.0138 - val_dice_coef: 0.0138
#
# Epoch 00155: loss did not improve from 0.96042
# Epoch 156/300
# 176/176 [==============================] - 100s 564ms/step - loss: 0.9848 - binary_accuracy: 0.9898 - iou: 0.0152 - dice_coef: 0.0152 - val_loss: 0.9871 - val_binary_accuracy: 0.9895 - val_iou: 0.0129 - val_dice_coef: 0.0129
#
# Epoch 00156: loss did not improve from 0.96042
# Epoch 157/300
# 176/176 [==============================] - 99s 562ms/step - loss: 0.9865 - binary_accuracy: 0.9899 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9841 - val_binary_accuracy: 0.9907 - val_iou: 0.0163 - val_dice_coef: 0.0163
#
# Epoch 00157: loss did not improve from 0.96042
# Epoch 158/300
# 176/176 [==============================] - 99s 563ms/step - loss: 0.9877 - binary_accuracy: 0.9898 - iou: 0.0124 - dice_coef: 0.0124 - val_loss: 0.9884 - val_binary_accuracy: 0.9893 - val_iou: 0.0117 - val_dice_coef: 0.0117
#
# Epoch 00158: loss did not improve from 0.96042
# Epoch 159/300
# 176/176 [==============================] - 100s 565ms/step - loss: 0.9866 - binary_accuracy: 0.9898 - iou: 0.0134 - dice_coef: 0.0134 - val_loss: 0.9868 - val_binary_accuracy: 0.9900 - val_iou: 0.0148 - val_dice_coef: 0.0148
#
# Epoch 00159: loss did not improve from 0.96042
# Epoch 160/300
# 176/176 [==============================] - 100s 564ms/step - loss: 0.9856 - binary_accuracy: 0.9898 - iou: 0.0144 - dice_coef: 0.0144 - val_loss: 0.9817 - val_binary_accuracy: 0.9899 - val_iou: 0.0346 - val_dice_coef: 0.0346
#
# Epoch 00160: loss did not improve from 0.96042
# Epoch 161/300
# 176/176 [==============================] - 100s 565ms/step - loss: 0.9826 - binary_accuracy: 0.9898 - iou: 0.0175 - dice_coef: 0.0175 - val_loss: 0.9856 - val_binary_accuracy: 0.9900 - val_iou: 0.0221 - val_dice_coef: 0.0221
#
# Epoch 00161: loss did not improve from 0.96042
# Epoch 162/300
# 176/176 [==============================] - 100s 566ms/step - loss: 0.9866 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9805 - val_binary_accuracy: 0.9904 - val_iou: 0.0359 - val_dice_coef: 0.0359
#
# Epoch 00162: loss did not improve from 0.96042
# Epoch 163/300
# 176/176 [==============================] - 100s 566ms/step - loss: 0.9873 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9885 - val_binary_accuracy: 0.9895 - val_iou: 0.0117 - val_dice_coef: 0.0117
#
# Epoch 00163: loss did not improve from 0.96042
# Epoch 164/300
# 176/176 [==============================] - 100s 564ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0125 - dice_coef: 0.0125 - val_loss: 0.9862 - val_binary_accuracy: 0.9908 - val_iou: 0.0148 - val_dice_coef: 0.0148
#
# Epoch 00164: loss did not improve from 0.96042
# Epoch 165/300
# 176/176 [==============================] - 99s 562ms/step - loss: 0.9878 - binary_accuracy: 0.9898 - iou: 0.0122 - dice_coef: 0.0122 - val_loss: 0.9867 - val_binary_accuracy: 0.9897 - val_iou: 0.0171 - val_dice_coef: 0.0171
#
# Epoch 00165: loss did not improve from 0.96042
# Epoch 166/300
# 176/176 [==============================] - 100s 566ms/step - loss: 0.9872 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9824 - val_binary_accuracy: 0.9897 - val_iou: 0.0339 - val_dice_coef: 0.0339
#
# Epoch 00166: loss did not improve from 0.96042
# Epoch 167/300
# ...
#
# Epoch 00245: loss did not improve from 0.96042
# Epoch 246/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9818 - binary_accuracy: 0.9898 - iou: 0.0182 - dice_coef: 0.0182 - val_loss: 0.9830 - val_binary_accuracy: 0.9901 - val_iou: 0.0334 - val_dice_coef: 0.0334
#
# Epoch 00246: loss did not improve from 0.96042
# Epoch 247/300
# 176/176 [==============================] - 100s 568ms/step - loss: 0.9878 - binary_accuracy: 0.9898 - iou: 0.0122 - dice_coef: 0.0122 - val_loss: 0.9883 - val_binary_accuracy: 0.9903 - val_iou: 0.0120 - val_dice_coef: 0.0120
#
# Epoch 00247: loss did not improve from 0.96042
# Epoch 248/300
# 176/176 [==============================] - 101s 570ms/step - loss: 0.9850 - binary_accuracy: 0.9898 - iou: 0.0150 - dice_coef: 0.0150 - val_loss: 0.9883 - val_binary_accuracy: 0.9898 - val_iou: 0.0121 - val_dice_coef: 0.0121
#
# Epoch 00248: loss did not improve from 0.96042
# Epoch 249/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9856 - binary_accuracy: 0.9898 - iou: 0.0144 - dice_coef: 0.0144 - val_loss: 0.9429 - val_binary_accuracy: 0.9911 - val_iou: 0.0568 - val_dice_coef: 0.0568
#
# Epoch 00249: loss did not improve from 0.96042
# Epoch 250/300
# 176/176 [==============================] - 99s 562ms/step - loss: 0.9876 - binary_accuracy: 0.9898 - iou: 0.0124 - dice_coef: 0.0124 - val_loss: 0.9880 - val_binary_accuracy: 0.9889 - val_iou: 0.0122 - val_dice_coef: 0.0122
#
# Epoch 00250: loss did not improve from 0.96042
# Epoch 251/300
# 176/176 [==============================] - 101s 570ms/step - loss: 0.9815 - binary_accuracy: 0.9898 - iou: 0.0185 - dice_coef: 0.0185 - val_loss: 0.9862 - val_binary_accuracy: 0.9906 - val_iou: 0.0158 - val_dice_coef: 0.0158
#
# Epoch 00251: loss did not improve from 0.96042
# Epoch 252/300
# 176/176 [==============================] - 101s 570ms/step - loss: 0.9810 - binary_accuracy: 0.9898 - iou: 0.0190 - dice_coef: 0.0190 - val_loss: 0.9764 - val_binary_accuracy: 0.9905 - val_iou: 0.0242 - val_dice_coef: 0.0242
#
# Epoch 00252: loss did not improve from 0.96042
# Epoch 253/300
# 176/176 [==============================] - 104s 588ms/step - loss: 0.9817 - binary_accuracy: 0.9898 - iou: 0.0183 - dice_coef: 0.0183 - val_loss: 0.9859 - val_binary_accuracy: 0.9903 - val_iou: 0.0141 - val_dice_coef: 0.0141
#
# Epoch 00253: loss did not improve from 0.96042
# Epoch 254/300
# 176/176 [==============================] - 101s 570ms/step - loss: 0.9815 - binary_accuracy: 0.9898 - iou: 0.0185 - dice_coef: 0.0185 - val_loss: 0.9832 - val_binary_accuracy: 0.9891 - val_iou: 0.0332 - val_dice_coef: 0.0332
#
# Epoch 00254: loss did not improve from 0.96042
# Epoch 255/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9813 - binary_accuracy: 0.9898 - iou: 0.0187 - dice_coef: 0.0187 - val_loss: 0.9850 - val_binary_accuracy: 0.9905 - val_iou: 0.0163 - val_dice_coef: 0.0163
#
# Epoch 00255: loss did not improve from 0.96042
# Epoch 256/300
# 176/176 [==============================] - 99s 562ms/step - loss: 0.9866 - binary_accuracy: 0.9898 - iou: 0.0134 - dice_coef: 0.0134 - val_loss: 0.9846 - val_binary_accuracy: 0.9901 - val_iou: 0.0202 - val_dice_coef: 0.0202
#
# Epoch 00256: loss did not improve from 0.96042
# Epoch 257/300
# 176/176 [==============================] - 100s 569ms/step - loss: 0.9855 - binary_accuracy: 0.9898 - iou: 0.0145 - dice_coef: 0.0145 - val_loss: 0.9870 - val_binary_accuracy: 0.9903 - val_iou: 0.0132 - val_dice_coef: 0.0132
#
# Epoch 00257: loss did not improve from 0.96042
# Epoch 258/300
# 176/176 [==============================] - 101s 572ms/step - loss: 0.9819 - binary_accuracy: 0.9898 - iou: 0.0181 - dice_coef: 0.0181 - val_loss: 0.9868 - val_binary_accuracy: 0.9910 - val_iou: 0.0138 - val_dice_coef: 0.0138
#
# Epoch 00258: loss did not improve from 0.96042
# Epoch 259/300
# 176/176 [==============================] - 101s 572ms/step - loss: 0.9867 - binary_accuracy: 0.9898 - iou: 0.0134 - dice_coef: 0.0134 - val_loss: 0.9827 - val_binary_accuracy: 0.9900 - val_iou: 0.0173 - val_dice_coef: 0.0173
#
# Epoch 00259: loss did not improve from 0.96042
# Epoch 260/300
# 176/176 [==============================] - 100s 568ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0125 - dice_coef: 0.0125 - val_loss: 0.9862 - val_binary_accuracy: 0.9892 - val_iou: 0.0141 - val_dice_coef: 0.0141
#
# Epoch 00260: loss did not improve from 0.96042
# Epoch 261/300
# 176/176 [==============================] - 100s 565ms/step - loss: 0.9848 - binary_accuracy: 0.9898 - iou: 0.0152 - dice_coef: 0.0152 - val_loss: 0.9864 - val_binary_accuracy: 0.9903 - val_iou: 0.0148 - val_dice_coef: 0.0148
#
# Epoch 00261: loss did not improve from 0.96042
# Epoch 262/300
# 176/176 [==============================] - 99s 562ms/step - loss: 0.9877 - binary_accuracy: 0.9898 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9802 - val_binary_accuracy: 0.9905 - val_iou: 0.0361 - val_dice_coef: 0.0361
#
# Epoch 00262: loss did not improve from 0.96042
# Epoch 263/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9872 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9853 - val_binary_accuracy: 0.9897 - val_iou: 0.0151 - val_dice_coef: 0.0151
#
# Epoch 00263: loss did not improve from 0.96042
# Epoch 264/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9814 - binary_accuracy: 0.9898 - iou: 0.0186 - dice_coef: 0.0186 - val_loss: 0.9547 - val_binary_accuracy: 0.9905 - val_iou: 0.0612 - val_dice_coef: 0.0612
#
# Epoch 00264: loss did not improve from 0.96042
# Epoch 265/300
# 176/176 [==============================] - 101s 569ms/step - loss: 0.9849 - binary_accuracy: 0.9898 - iou: 0.0150 - dice_coef: 0.0150 - val_loss: 0.9825 - val_binary_accuracy: 0.9902 - val_iou: 0.0339 - val_dice_coef: 0.0339
#
# Epoch 00265: loss did not improve from 0.96042
# Epoch 266/300
# 176/176 [==============================] - 100s 566ms/step - loss: 0.9822 - binary_accuracy: 0.9898 - iou: 0.0178 - dice_coef: 0.0178 - val_loss: 0.9860 - val_binary_accuracy: 0.9905 - val_iou: 0.0140 - val_dice_coef: 0.0140
#
# Epoch 00266: loss did not improve from 0.96042
# Epoch 267/300
# 176/176 [==============================] - 100s 564ms/step - loss: 0.9870 - binary_accuracy: 0.9898 - iou: 0.0130 - dice_coef: 0.0130 - val_loss: 0.9669 - val_binary_accuracy: 0.9896 - val_iou: 0.0329 - val_dice_coef: 0.0329
#
# Epoch 00267: loss did not improve from 0.96042
# Epoch 268/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9868 - binary_accuracy: 0.9898 - iou: 0.0132 - dice_coef: 0.0132 - val_loss: 0.9865 - val_binary_accuracy: 0.9901 - val_iou: 0.0137 - val_dice_coef: 0.0137
#
# Epoch 00268: loss did not improve from 0.96042
# Epoch 269/300
# 176/176 [==============================] - 101s 572ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9862 - val_binary_accuracy: 0.9902 - val_iou: 0.0139 - val_dice_coef: 0.0139
#
# Epoch 00269: loss did not improve from 0.96042
# Epoch 270/300
# 176/176 [==============================] - 101s 572ms/step - loss: 0.9800 - binary_accuracy: 0.9898 - iou: 0.0200 - dice_coef: 0.0200 - val_loss: 0.9872 - val_binary_accuracy: 0.9902 - val_iou: 0.0134 - val_dice_coef: 0.0134
#
# Epoch 00270: loss did not improve from 0.96042
# Epoch 271/300
# 176/176 [==============================] - 101s 573ms/step - loss: 0.9814 - binary_accuracy: 0.9898 - iou: 0.0186 - dice_coef: 0.0186 - val_loss: 0.9869 - val_binary_accuracy: 0.9901 - val_iou: 0.0136 - val_dice_coef: 0.0136
#
# Epoch 00271: loss did not improve from 0.96042
# Epoch 272/300
# 176/176 [==============================] - 99s 561ms/step - loss: 0.9836 - binary_accuracy: 0.9898 - iou: 0.0164 - dice_coef: 0.0164 - val_loss: 0.9819 - val_binary_accuracy: 0.9900 - val_iou: 0.0344 - val_dice_coef: 0.0344
#
# Epoch 00272: loss did not improve from 0.96042
# Epoch 273/300
# 176/176 [==============================] - 101s 570ms/step - loss: 0.9800 - binary_accuracy: 0.9898 - iou: 0.0200 - dice_coef: 0.0200 - val_loss: 0.9873 - val_binary_accuracy: 0.9901 - val_iou: 0.0141 - val_dice_coef: 0.0141
#
# Epoch 00273: loss did not improve from 0.96042
# Epoch 274/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9790 - binary_accuracy: 0.9899 - iou: 0.0210 - dice_coef: 0.0210 - val_loss: 0.9814 - val_binary_accuracy: 0.9902 - val_iou: 0.0349 - val_dice_coef: 0.0349
#
# Epoch 00274: loss did not improve from 0.96042
# Epoch 275/300
# 176/176 [==============================] - 101s 572ms/step - loss: 0.9822 - binary_accuracy: 0.9898 - iou: 0.0178 - dice_coef: 0.0178 - val_loss: 0.9841 - val_binary_accuracy: 0.9905 - val_iou: 0.0160 - val_dice_coef: 0.0160
#
# Epoch 00275: loss did not improve from 0.96042
# Epoch 276/300
# 176/176 [==============================] - 100s 565ms/step - loss: 0.9880 - binary_accuracy: 0.9899 - iou: 0.0121 - dice_coef: 0.0121 - val_loss: 0.9859 - val_binary_accuracy: 0.9903 - val_iou: 0.0142 - val_dice_coef: 0.0142
#
# Epoch 00276: loss did not improve from 0.96042
# Epoch 277/300
# 176/176 [==============================] - 100s 565ms/step - loss: 0.9855 - binary_accuracy: 0.9898 - iou: 0.0145 - dice_coef: 0.0145 - val_loss: 0.9866 - val_binary_accuracy: 0.9898 - val_iou: 0.0136 - val_dice_coef: 0.0136
#
# Epoch 00277: loss did not improve from 0.96042
# Epoch 278/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9883 - binary_accuracy: 0.9898 - iou: 0.0117 - dice_coef: 0.0117 - val_loss: 0.9866 - val_binary_accuracy: 0.9903 - val_iou: 0.0135 - val_dice_coef: 0.0135
#
# Epoch 00278: loss did not improve from 0.96042
# Epoch 279/300
# 176/176 [==============================] - 101s 575ms/step - loss: 0.9839 - binary_accuracy: 0.9898 - iou: 0.0161 - dice_coef: 0.0161 - val_loss: 0.9885 - val_binary_accuracy: 0.9899 - val_iou: 0.0120 - val_dice_coef: 0.0120
#
# Epoch 00279: loss did not improve from 0.96042
# Epoch 280/300
# 176/176 [==============================] - 101s 573ms/step - loss: 0.9866 - binary_accuracy: 0.9898 - iou: 0.0134 - dice_coef: 0.0134 - val_loss: 0.9817 - val_binary_accuracy: 0.9901 - val_iou: 0.0347 - val_dice_coef: 0.0347
#
# Epoch 00280: loss did not improve from 0.96042
# Epoch 281/300
# 176/176 [==============================] - 100s 567ms/step - loss: 0.9764 - binary_accuracy: 0.9898 - iou: 0.0236 - dice_coef: 0.0236 - val_loss: 0.9874 - val_binary_accuracy: 0.9903 - val_iou: 0.0126 - val_dice_coef: 0.0126
#
# Epoch 00281: loss did not improve from 0.96042
# Epoch 282/300
# 176/176 [==============================] - 100s 566ms/step - loss: 0.9877 - binary_accuracy: 0.9898 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9846 - val_binary_accuracy: 0.9900 - val_iou: 0.0161 - val_dice_coef: 0.0161
#
# Epoch 00282: loss did not improve from 0.96042
# Epoch 283/300
# 176/176 [==============================] - 101s 572ms/step - loss: 0.9872 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9855 - val_binary_accuracy: 0.9900 - val_iou: 0.0161 - val_dice_coef: 0.0161
#
# Epoch 00283: loss did not improve from 0.96042
# Epoch 284/300
# 176/176 [==============================] - 101s 574ms/step - loss: 0.9869 - binary_accuracy: 0.9899 - iou: 0.0131 - dice_coef: 0.0131 - val_loss: 0.9857 - val_binary_accuracy: 0.9905 - val_iou: 0.0143 - val_dice_coef: 0.0143
#
# Epoch 00284: loss did not improve from 0.96042
# Epoch 285/300
# 176/176 [==============================] - 102s 575ms/step - loss: 0.9796 - binary_accuracy: 0.9898 - iou: 0.0204 - dice_coef: 0.0204 - val_loss: 0.9879 - val_binary_accuracy: 0.9896 - val_iou: 0.0135 - val_dice_coef: 0.0135
#
# Epoch 00285: loss did not improve from 0.96042
# Epoch 286/300
# 176/176 [==============================] - 100s 568ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0125 - dice_coef: 0.0125 - val_loss: 0.9832 - val_binary_accuracy: 0.9909 - val_iou: 0.0167 - val_dice_coef: 0.0167
#
# Epoch 00286: loss did not improve from 0.96042
# Epoch 287/300
# 176/176 [==============================] - 100s 566ms/step - loss: 0.9869 - binary_accuracy: 0.9898 - iou: 0.0131 - dice_coef: 0.0131 - val_loss: 0.9864 - val_binary_accuracy: 0.9899 - val_iou: 0.0136 - val_dice_coef: 0.0136
#
# Epoch 00287: loss did not improve from 0.96042
# Epoch 288/300
# 176/176 [==============================] - 101s 574ms/step - loss: 0.9871 - binary_accuracy: 0.9898 - iou: 0.0129 - dice_coef: 0.0129 - val_loss: 0.9867 - val_binary_accuracy: 0.9899 - val_iou: 0.0159 - val_dice_coef: 0.0159
#
# Epoch 00288: loss did not improve from 0.96042
# Epoch 289/300
# 176/176 [==============================] - 101s 571ms/step - loss: 0.9853 - binary_accuracy: 0.9898 - iou: 0.0147 - dice_coef: 0.0147 - val_loss: 0.9852 - val_binary_accuracy: 0.9903 - val_iou: 0.0149 - val_dice_coef: 0.0149
#
# Epoch 00289: loss did not improve from 0.96042
# Epoch 290/300
# 176/176 [==============================] - 102s 576ms/step - loss: 0.9875 - binary_accuracy: 0.9898 - iou: 0.0125 - dice_coef: 0.0125 - val_loss: 0.9873 - val_binary_accuracy: 0.9897 - val_iou: 0.0131 - val_dice_coef: 0.0131
#
# Epoch 00290: loss did not improve from 0.96042
# Epoch 291/300
# 176/176 [==============================] - 100s 567ms/step - loss: 0.9879 - binary_accuracy: 0.9898 - iou: 0.0121 - dice_coef: 0.0121 - val_loss: 0.9811 - val_binary_accuracy: 0.9904 - val_iou: 0.0353 - val_dice_coef: 0.0353
#
# Epoch 00291: loss did not improve from 0.96042
# Epoch 292/300
# 176/176 [==============================] - 100s 565ms/step - loss: 0.9872 - binary_accuracy: 0.9898 - iou: 0.0128 - dice_coef: 0.0128 - val_loss: 0.9884 - val_binary_accuracy: 0.9899 - val_iou: 0.0119 - val_dice_coef: 0.0119
#
# Epoch 00292: loss did not improve from 0.96042
# Epoch 293/300
# 176/176 [==============================] - 102s 577ms/step - loss: 0.9877 - binary_accuracy: 0.9898 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9822 - val_binary_accuracy: 0.9905 - val_iou: 0.0209 - val_dice_coef: 0.0209
#
# Epoch 00293: loss did not improve from 0.96042
# Epoch 294/300
# 176/176 [==============================] - 101s 574ms/step - loss: 0.9850 - binary_accuracy: 0.9898 - iou: 0.0150 - dice_coef: 0.0150 - val_loss: 0.9878 - val_binary_accuracy: 0.9896 - val_iou: 0.0123 - val_dice_coef: 0.0123
#
# Epoch 00294: loss did not improve from 0.96042
# Epoch 295/300
# 176/176 [==============================] - 101s 574ms/step - loss: 0.9878 - binary_accuracy: 0.9898 - iou: 0.0122 - dice_coef: 0.0122 - val_loss: 0.9659 - val_binary_accuracy: 0.9901 - val_iou: 0.0345 - val_dice_coef: 0.0345
#
# Epoch 00295: loss did not improve from 0.96042
# Epoch 296/300
# 176/176 [==============================] - 100s 567ms/step - loss: 0.9873 - binary_accuracy: 0.9898 - iou: 0.0127 - dice_coef: 0.0127 - val_loss: 0.9862 - val_binary_accuracy: 0.9903 - val_iou: 0.0139 - val_dice_coef: 0.0139
#
# Epoch 00296: loss did not improve from 0.96042
# Epoch 297/300
# 176/176 [==============================] - 100s 564ms/step - loss: 0.9874 - binary_accuracy: 0.9898 - iou: 0.0126 - dice_coef: 0.0126 - val_loss: 0.9863 - val_binary_accuracy: 0.9909 - val_iou: 0.0137 - val_dice_coef: 0.0137
#
# Epoch 00297: loss did not improve from 0.96042
# Epoch 298/300
# 176/176 [==============================] - 102s 575ms/step - loss: 0.9878 - binary_accuracy: 0.9898 - iou: 0.0123 - dice_coef: 0.0123 - val_loss: 0.9606 - val_binary_accuracy: 0.9895 - val_iou: 0.0392 - val_dice_coef: 0.0392
#
# Epoch 00298: loss did not improve from 0.96042
# Epoch 299/300
# 176/176 [==============================] - 101s 574ms/step - loss: 0.9867 - binary_accuracy: 0.9898 - iou: 0.0133 - dice_coef: 0.0133 - val_loss: 0.9881 - val_binary_accuracy: 0.9895 - val_iou: 0.0121 - val_dice_coef: 0.0121
#
# Epoch 00299: loss did not improve from 0.96042
# Epoch 300/300
# 176/176 [==============================] - 105s 592ms/step - loss: 0.9865 - binary_accuracy: 0.9898 - iou: 0.0135 - dice_coef: 0.0135 - val_loss: 0.9781 - val_binary_accuracy: 0.9911 - val_iou: 0.0382 - val_dice_coef: 0.0382
#
# Epoch 00300: loss did not improve from 0.96042

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Save Model</span> <a id=5.4></a>

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model.h5')

# %%
# saving model achitecture in json file
model_json = model.to_json()
with open("UNet-seg-model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Evaluation</span> <a id=6></a>
#
# Evaluation metrics are listed below

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'iou', 'dice_coef', 'val_loss', 'val_binary_accuracy', 'val_iou', 'val_dice_coef', 'lr'])

# %% [markdown]
# **Loss function** :  IOU - Intersection over Union

# %% [markdown]
# ![Performance metric : Intersection over Union](data:image/png;base64,...)
#
# ![IOU](data:image/png;base64,...)

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['loss']);
plt.plot(history.history['val_loss']);
plt.title("Segmentation Model IOU Loss");
plt.ylabel("IOU loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %% [markdown]
# <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Prediction</span> <a id=7></a>

# %%
test_ids = list(mri_test.img_path)
test_mask = list(mri_test.mask_path)

# %%
def prediction(test, model_seg):
  
    # empty list to store results
    mask, image_id,has_mask = [], [], []
    
    #itetrating through each image in test data
    for i in test.img_path:
        

        
        #Creating a empty array of shape 1,256,256,1
        X = np.empty((1,256,256,3))
        # read the image
        img = io.imread(i)
        #resizing the image and coverting them to array of type float64
        img = cv2.resize(img, (256,256))
        img = np.array(img, dtype=np.float64)
        
        # standardising the image
        img -= img.mean()
        img /= img.std()
        #converting the shape of image from 256,256,3 to 1,256,256,3
        X[0,] = img
        
        #make prediction of mask
        predict = model_seg.predict(X)
        
        # if sum of predicted mask is 0 then there is not tumour
        if predict.round().astype(int).sum()==0:
            image_id.append(i)
            has_mask.append(0)
            mask.append('No mask :)')
        else:
        #if the sum of pixel values are more than 0, then there is tumour
            image_id.append(i)
            has_mask.append(1)
            mask.append(predict)
            
    return pd.DataFrame({'img_path': image_id,'predicted_mask': mask,'has_mask': has_mask})

# %%
df_pred = prediction(mri_test, model)
df_pred
# Out:
#                                               img_path predicted_mask  \
# 0    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# 1    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# 2    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# 3    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# 4    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# ..                                                 ...            ...
# 388  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# 389  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# 390  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# 391  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
# 392  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     No mask :)
#
#      has_mask
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ..        ...
# 388         0
# 389         0
# 390         0
# 391         0
# 392         0
#
# [393 rows x 3 columns]

# %%
df_pred = mri_test.merge(df_pred, on='img_path')
df_pred.head()
# Out:
#                                             img_path  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path  mask predicted_mask  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1     No mask :)
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0     No mask :)
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0     No mask :)
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0     No mask :)
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1     No mask :)
#
#    has_mask
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
count = 0
fig, axs = plt.subplots(5,5, figsize=(30,70))

for i in range(len(df_pred)):
    if df_pred.has_mask[i]==1 and count<15:
        #read mri images
        img = io.imread(df_pred.img_path[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        axs[count][0].imshow(img)
        axs[count][0].title.set_text('Brain MRI')
        
        #read original mask
        mask = io.imread(df_pred.mask_path[i])
        axs[count][1].imshow(mask)
        axs[count][1].title.set_text('Original Mask')
        
        #read predicted mask
        pred = np.array(df_pred.predicted_mask[i]).squeeze().round()
        axs[count][2].imshow(pred)
        axs[count][2].title.set_text('AI predicted mask')
        
        #overlay original mask with MRI
        img[mask==255] = (255,0,0)
        axs[count][3].imshow(img)
        axs[count][3].title.set_text('Brain MRI with original mask (Ground Truth)')
        
        #overlay predicted mask and MRI
        img_ = io.imread(df_pred.img_path[i])
        img_ = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
        img_[pred==1] = (0,255,150)
        axs[count][4].imshow(img_)
        axs[count][4].title.set_text('MRI with AI PREDICTED MASK')
        
        count +=1
    if (count==15):
        break

fig.tight_layout()

# %% [markdown]
# **Reference:**
# * [UNet model Original creator Reference link](https://github.com/zhixuhao/unet)
# * [Kaggle Notebook - SAMUEL CORTINHAS](https://www.kaggle.com/code/samuelcortinhas/case-study-u-net-from-scratch#Application:-Tumor-detection)
