# %% [markdown]
# <a href="https://www.kaggle.com/code/tejasurya/unet-guide-image-segmentation?scriptVersionId=109326756" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <p style="background-color:red;color:white;font-size:22px;text-align:center;border-radius:10px 10px;font-weight:bold;border:2px solid black">Brain MRI Detector | Segmentation | Using UNet</p>
#
# <center><img src= "https://www.mayoclinic.org/-/media/kcms/gbs/patient-consumer/images/2014/10/30/15/17/mcdc7_brain_cancer-8col.jpg" alt ="Brain-MRI" style='width:300px;'></center>
#
# **Image source** : Mayo Clinic

# %% [markdown]
# # Quick Index
#
# * [Introduction](#1)
# * [What is Image Segmentation?](#1.1)
# * [EDA](#2)
# * [Image Visualization](#2.1)
# * [Data Generator](#3)
# * [Build UNet](#4)
#     * [UNet Architecture](#4.1)
# * [UNet Implementation](#5)
#     * [Callbacks](#5.1)
#     * [Performance Metrics](#5.2)
#     * [Model Fit](#5.3)
#     * [Save UNet Model](#5.4)
# * [Evaluation](#6)
# * [Prediction](#7)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Introduction</span> <a id=1></a>
# A brain tumor is a mass or growth of abnormal cells in your brain.Many different types of brain tumors exist. Some brain tumors are noncancerous (benign), and some brain tumors are cancerous (malignant). Brain tumors can begin in your brain (primary brain tumors), or cancer can begin in other parts of your body and spread to your brain as secondary (metastatic) brain tumors.
#
# How quickly a brain tumor grows can vary greatly. The growth rate as well as the location of a brain tumor determines how it will affect the function of your nervous system.
#
# Brain tumor treatment options depend on the type of brain tumor you have, as well as its size and location. <br>
# **Source credits** : [Mayo Clinic](https://www.mayoclinic.org/diseases-conditions/brain-tumor/symptoms-causes/syc-20350084)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">What is Image Segmentation?</span> <a id=1.1></a> <br>
#  *  The objective of the Image Segmentation is to classify each pixel of an image with the class it represents, by predicting each pixel in image. <br>
#  *  Here in this notebook,we will implement the U-Net model, its a U-shaped architecture (in keras).
# We will also apply our model to a Brain MRI tumor detection problem to see how it performs.

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:red;background-color:white;font-size:22px">Import Libraries</span> <a id=1.1.1></a> <br>

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import random
import glob

import time
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline
from IPython.display import Image
from skimage import io

import tensorflow as tf
from skimage.color import rgb2gray
from tensorflow.python.keras import Sequential
from tensorflow.keras import layers, optimizers
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import glorot_uniform
from tensorflow.keras.models import Model, load_model, save_model
from tensorflow.keras.callbacks import ReduceLROnPlateau, EarlyStopping, ModelCheckpoint,LearningRateScheduler
from tensorflow.keras.layers import Input, Activation, BatchNormalization, Dropout, Lambda, Conv2D, Conv2DTranspose, MaxPooling2D, concatenate
from tensorflow.keras.layers.experimental import preprocessing
from keras.utils.vis_utils import plot_model
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import backend as K
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import plot_model

from sklearn.model_selection import train_test_split
import cv2
from sklearn.preprocessing import StandardScaler, normalize
from IPython.display import display

# %%
img_data = pd.read_csv('../input/lgg-mri-segmentation/kaggle_3m/data.csv')
img_data.head()
# Out:
#         Patient  RNASeqCluster  MethylationCluster  miRNACluster  CNCluster  \
# 0  TCGA_CS_4941            2.0                 4.0             2        2.0
# 1  TCGA_CS_4942            1.0                 5.0             2        1.0
# 2  TCGA_CS_4943            1.0                 5.0             2        1.0
# 3  TCGA_CS_4944            NaN                 5.0             2        1.0
# 4  TCGA_CS_5393            4.0                 5.0             2        1.0
#
#    RPPACluster  OncosignCluster  COCCluster  histological_type  \
# 0          NaN              3.0           2                1.0
# 1          1.0              2.0           1                1.0
# 2          2.0              2.0           1                1.0
# 3          2.0              1.0           1                1.0
# 4          2.0              3.0           1                1.0
#
#    neoplasm_histologic_grade  tumor_tissue_site  laterality  tumor_location  \
# 0                        2.0                1.0         3.0             2.0
# 1                        2.0                1.0         3.0             2.0
# 2                        2.0                1.0         1.0             2.0
# 3                        1.0                1.0         3.0             6.0
# 4                        2.0                1.0         1.0             6.0
#
#    gender  age_at_initial_pathologic  race  ethnicity  death01
# 0     2.0                       67.0   3.0        2.0      1.0
# 1     1.0                       44.0   2.0        NaN      1.0
# 2     2.0                       37.0   3.0        NaN      0.0
# 3     2.0                       50.0   3.0        NaN      0.0
# 4     2.0                       39.0   3.0        NaN      0.0

# %%
img_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110 entries, 0 to 109
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient                    110 non-null    object
#  1   RNASeqCluster              92 non-null     float64
#  2   MethylationCluster         109 non-null    float64
#  3   miRNACluster               110 non-null    int64
#  4   CNCluster                  108 non-null    float64
#  5   RPPACluster                98 non-null     float64
#  6   OncosignCluster            105 non-null    float64
#  7   COCCluster                 110 non-null    int64
#  8   histological_type          109 non-null    float64
#  9   neoplasm_histologic_grade  109 non-null    float64
#  10  tumor_tissue_site          109 non-null    float64
#  11  laterality                 109 non-null    float64
#  12  tumor_location             109 non-null    float64
#  13  gender                     109 non-null    float64
#  14  age_at_initial_pathologic  109 non-null    float64
#  15  race                       108 non-null    float64
#  16  ethnicity                  102 non-null    float64
#  17  death01                    109 non-null    float64
# dtypes: float64(15), int64(2), object(1)
# memory usage: 15.6+ KB

# %%
img_data.shape
# Out:
# (110, 18)

# %%
data_path = []
for sub_dir_path in glob.glob("/kaggle/input/lgg-mri-segmentation/kaggle_3m/"+"*"):
    try:
        dir_name = sub_dir_path.split('/')[-1]
        for filename in os.listdir(sub_dir_path):
            mask_path = sub_dir_path + '/' + filename
            data_path.extend([dir_name, mask_path])
    except Exception as e:
        print(e)
# Out:
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/README.md'
# [Errno 20] Not a directory: '/kaggle/input/lgg-mri-segmentation/kaggle_3m/data.csv'

# %%
filenames = data_path[::2]
masks = data_path[1::2]

# %%
df = pd.DataFrame(data={"patient_id": filenames,"img_path": masks})
df
# Out:
#                  patient_id                                           img_path
# 0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                     ...                                                ...
# 7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [7858 rows x 2 columns]

# %%
original_img     = df[~df['img_path'].str.contains("mask")]
mask_img = df[df['img_path'].str.contains("mask")]

# %%
original_img,mask_img
# Out:
# (                 patient_id                                           img_path
#  0     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  2     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  3     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  4     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  5     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7849  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7850  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7852  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7854  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7856  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns],
#                   patient_id                                           img_path
#  1     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  8     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  9     TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  11    TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  ...                     ...                                                ...
#  7846  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7851  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7853  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7855  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#  7857  TCGA_DU_7306_19930512  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#  [3929 rows x 2 columns])

# %%
imgs = sorted(original_img["img_path"].values, key=lambda x : int(x[89:-4]))
masks = sorted(mask_img["img_path"].values, key=lambda x : int(x[89:-9]))

# Sorting check
idx = random.randint(0, len(imgs)-1)
print("Image path:", imgs[idx], "\nMask path:", masks[idx])
# Out:
# Image path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_6690_20020226/TCGA_FG_6690_20020226_44.tif
# Mask path: /kaggle/input/lgg-mri-segmentation/kaggle_3m/TCGA_FG_6690_20020226/TCGA_FG_6690_20020226_44_mask.tif

# %%
mri_df = pd.DataFrame({"patient_id": original_img.patient_id.values,"img_path": imgs,
                           'mask_path':masks})
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
# [3929 rows x 3 columns]

# %%
def get_diagnosis(img_path):
    value = np.max(cv2.imread(img_path))
    if value > 0 : 
        return 1
    else:
        return 0

# %%
mri_df.head()
# Out:
#               patient_id                                           img_path  \
# 0  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  TCGA_DU_7010_19860307  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...

# %%
mri_df['mask'] = mri_df['mask_path'].apply(lambda x: get_diagnosis(x))

mri_df['mask_path'] = mri_df['mask_path'].apply(lambda x: str(x))
mri_df
# Out:
#                  patient_id  \
# 0     TCGA_DU_7010_19860307
# 1     TCGA_DU_7010_19860307
# 2     TCGA_DU_7010_19860307
# 3     TCGA_DU_7010_19860307
# 4     TCGA_DU_7010_19860307
# ...                     ...
# 3924  TCGA_DU_7306_19930512
# 3925  TCGA_DU_7306_19930512
# 3926  TCGA_DU_7306_19930512
# 3927  TCGA_DU_7306_19930512
# 3928  TCGA_DU_7306_19930512
#
#                                                img_path  \
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ...                                                 ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 0     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 4     /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# ...                                                 ...   ...
# 3924  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3925  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3926  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3927  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3928  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
# [3929 rows x 4 columns]

# %%
mri_df.drop(columns=['patient_id'],inplace=True)

# %%
mri_train, mri_test = train_test_split(mri_df,test_size = 0.1)
mri_train, mri_val = train_test_split(mri_train,test_size = 0.2)

print('Training data shape is {0}'.format(mri_train.values.shape))
print('Test data shape is {0}'.format(mri_test.values.shape))
mri_train.sample(n=5)
# Out:
# Training data shape is (2828, 3)
# Test data shape is (393, 3)
#                                                img_path  \
# 2236  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2513  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 526   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3339  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 393   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                               mask_path  mask
# 2236  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 2513  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 526   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3339  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 393   /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">EDA</span> <a id=2></a> <br>
#
# Check Balancing in Data

# %%
mri_df['mask'].value_counts().plot(kind='bar',color=['g','r'],
                title='Count of Tumour vs No Tumour')
# Out:
# <AxesSubplot:title={'center':'Count of Tumour vs No Tumour'}>

# %%
mri_df['mask'].value_counts()
# Out:
# 0    2556
# 1    1373
# Name: mask, dtype: int64

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Image Visualization</span> <a id=2.1></a> <br>
#
# Visualising the Brain MRI with Tumour

# %%
count = 0
i = 0
fig,axs = plt.subplots(3,3, figsize=(20,15))
for mask in mri_df['mask']:
    if (mask==1):
        img = io.imread(mri_df.img_path[i])
        axs[count][0].title.set_text("Brain MRI")
        axs[count][0].imshow(img)
        
        mask = io.imread(mri_df.mask_path[i])
        axs[count][1].title.set_text("Mask =" + str(mri_df['mask'][i]))
        axs[count][1].imshow(mask, cmap='gray')
        
        img[mask==255] = (255,0,0)  # change pixel color at the position of mask
        axs[count][2].title.set_text("MRI with Mask =" + str(mri_df['mask'][i]))
        axs[count][2].imshow(img)
        count +=1
    i += 1
    if (count==3):
        break
        
fig.tight_layout()

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Data Generator</span> <a id=3></a> <br>
# ### Reference : **[UNet](https://github.com/zhixuhao/unet)**

# %%
from keras_preprocessing.image import ImageDataGenerator

# %%
def train_generator(data_frame, batch_size, aug_dict,
        image_color_mode="rgb",
        mask_color_mode="grayscale",
        image_save_prefix="image",
        mask_save_prefix="mask",
        save_to_dir=None,
        target_size=(256,256),
        seed=1):

    image_datagen = ImageDataGenerator(**aug_dict)
    mask_datagen = ImageDataGenerator(**aug_dict)
    
    image_generator = image_datagen.flow_from_dataframe(
        data_frame,
        x_col = "img_path",
        class_mode = None,
        color_mode = image_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = image_save_prefix,
        seed = seed)

    mask_generator = mask_datagen.flow_from_dataframe(
        data_frame,
        x_col = "mask_path",
        class_mode = None,
        color_mode = mask_color_mode,
        target_size = target_size,
        batch_size = batch_size,
        save_to_dir = save_to_dir,
        save_prefix  = mask_save_prefix,
        seed = seed)

    train_gen = zip(image_generator, mask_generator)
    
    for (img, mask) in train_gen:
        img, mask = adjust_data(img, mask)
        yield (img,mask)

# %%
def adjust_data(img,mask):
    img = img / 255
    mask = mask / 255
    mask[mask > 0.5] = 1
    mask[mask <= 0.5] = 0
    
    return (img, mask)

# %%
train_generator_args = dict(rotation_range=0.2,
                            width_shift_range=0.05,
                            height_shift_range=0.05,
                            shear_range=0.05,
                            zoom_range=0.05,
                            horizontal_flip=True,
                            fill_mode='nearest')

train_gen = train_generator(mri_train, 32,
                                train_generator_args,
                                target_size=(256, 256))
    
val_gen = train_generator(mri_val, 32,
                                dict(),
                                target_size=(256, 256))

# %% [markdown]
# # <p style="color:#FF0000;background-color:white;font-size:25px">Build UNet Model</span> <a id=4></a> <br>
#
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Architecture</span> <a id=4.1></a>
#
# <center><img src= "https://miro.medium.com/max/1200/1*f7YOaE4TWubwaFF7Z1fzNw.png" alt ="UNet" style='width:800px;'></center>

# %% [markdown]
# UNet is named after the shape of it's architecture (U - shaped). UNet model is used to solve Image Segmentation problems especially in Medical related problems.
#
# The input layer has 572x572x1 dimension in the above architecture. The 1 column dimension specifies the input is b/w image. If the input dimension was 572x572x3 , the input image is rgb coloured image.
# After the input layer,we can divide this UNet architecture into 4 parts
# * Encoder Part (Contracting path)
# * Upsampling2D
# * Decoder part (Expanding Path)
# * Skip Connection (Residual connection)
#
#
# Briefly into the Details of these parts: <br>
# **Encoder Part**
# The initial half of the U-shaped architecture is the Contracting path(Encoder part). As the name Contracting path denotes, the dimension of the input image keeps reducing as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=64 followed by Maxpool2D layer (reduces size divided by 2). Now again 2 - Conv2D layers (128 filters) and 1 Maxpooling2D , 2 - Conv2D layers (256 filters) and 1 Maxpooling2D completely contracts the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Upsampling2D**
# The Upsampling2D layer upsamples the layer output dimension by duplicating the row values twice.The concatenation of the upsampling2D and contracting path happens here leading into the Expanding path.
# The Upsampling layer is present after 2 conv2D layers in Decoder part, similar to presence of  Maxpooling as in Encoder part.
#
# **Decoder Path**
# The second half of the U-shaped architecture is the Expanding path(Decoder part). As the name Expanding path denotes, the dimension of the image keeps expanding as it passes through 2 Conv2D 3X3 kernel size, ReLU activation and filters=512 followed by Upsampling2D layer (duplicates size divided by 2). Now again 2 - Conv2D layers (256 filters) and 1 Upsampling2D ,2 - Conv2D layers (128 filters) and 1 Upsampling2D, 2 - Conv2D layers (64 filters) completely expands the output dimension through layers. This is similar to the Zoom in of the image through each layer.
#
# **Skip Connection (Residual connection)**
# The Skip Connection (Residual connection) alias the identity mapping is present after each of the 2 Conv2D layers in Encoder to the corresponding same shaped dimension layer in the Decoder part . In the above architecture the copy and crop does residual connection task.The Concatenate layer does the work of adding those two layers. This skip connection doesnot harm the model in any way even in worst case but definitely benificial to the output in the model.
#
# Finally the decoder part ends with the Output Segmentation map with filters 2. This layer is again passed through a Conv2D with Sigmoid activation and filters 1. The output classifies each pixel if tumour is present or not in it.
#
# ### Reference : [UNet](https://github.com/zhixuhao/unet)

# %%
def unet(pretrained_weights = None,input_size = (256,256,3)):
    inputs = Input(input_size)
    conv1 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(inputs)
    conv1 = Conv2D(64, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv1)
    bn_1 = BatchNormalization(axis=3)(conv1)
    act_1 = Activation('relu')(bn_1)
    pool1 = MaxPooling2D(pool_size=(2, 2))(act_1)
    conv2 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool1)
    conv2 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv2)
    bn_2 = BatchNormalization(axis=3)(conv2)
    act_2 = Activation('relu')(bn_2)
    pool2 = MaxPooling2D(pool_size=(2, 2))(act_2)
    conv3 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool2)
    conv3 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv3)
    bn_3 = BatchNormalization(axis=3)(conv3)
    act_3 = Activation('relu')(bn_3)
    pool3 = MaxPooling2D(pool_size=(2, 2))(act_3)
    conv4 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool3)
    conv4 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv4)
    bn_4 = BatchNormalization(axis=3)(conv4)
    act_4 = Activation('relu')(bn_4)
    pool4 = MaxPooling2D(pool_size=(2, 2))(act_4)

    conv5 = Conv2D(1024, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(pool4)
    conv5 = Conv2D(1024, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv5)
    bn_5 = BatchNormalization(axis=3)(conv5)
    act_5 = Activation('relu')(bn_5)

    up6 = Conv2D(512, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_5))
    merge6 = concatenate([conv4,up6], axis = 3)
    conv6 = Conv2D(512, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge6)
    conv6 = Conv2D(512, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv6)
    bn_6 = BatchNormalization(axis=3)(conv6)
    act_6 = Activation('relu')(bn_6)
    
    up7 = Conv2D(256, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_6))
    merge7 = concatenate([conv3,up7], axis = 3)
    conv7 = Conv2D(256, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge7)
    conv7 = Conv2D(256, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv7)
    bn_7 = BatchNormalization(axis=3)(conv7)
    act_7 = Activation('relu')(bn_7)

    
    up8 = Conv2D(128, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_7))
    merge8 = concatenate([conv2,up8], axis = 3)
    conv8 = Conv2D(128, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge8)
    conv8 = Conv2D(128, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv8)
    bn_8 = BatchNormalization(axis=3)(conv8)
    act_8 = Activation('relu')(bn_8)
    
    up9 = Conv2D(64, 2, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(UpSampling2D(size = (2,2))(act_8))
    merge9 = concatenate([conv1,up9], axis = 3)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(merge9)
    conv9 = Conv2D(64, 3, activation = 'relu', padding = 'same', kernel_initializer = 'he_normal')(conv9)
    conv9 = Conv2D(2, 3, activation = None, padding = 'same', kernel_initializer = 'he_normal')(conv9)
    bn_9 = BatchNormalization(axis=3)(conv9)
    act_9 = Activation('relu')(bn_9)
    
    conv10 = Conv2D(1, 1, activation = 'sigmoid')(act_9)

    model = model = Model(inputs=[inputs] , outputs = [conv10])    
    return model

# %%
model = unet()
model.summary()
# Out:
# 2022-10-27 19:44:22.785256: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:22.882211: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:22.883214: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:22.884901: I tensorflow/core/platform/cpu_feature_guard.cc:142] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-10-27 19:44:22.885314: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:22.886024: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:22.886681: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:25.199874: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:25.200779: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:25.201476: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:937] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-10-27 19:44:25.202164: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1510] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15401 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 256, 256, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 256, 256, 64) 1792        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 256, 256, 64) 36928       conv2d[0][0]
# __________________________________________________________________________________________________
# batch_normalization (BatchNorma (None, 256, 256, 64) 256         conv2d_1[0][0]
# __________________________________________________________________________________________________
# activation (Activation)         (None, 256, 256, 64) 0           batch_normalization[0][0]
# __________________________________________________________________________________________________
# max_pooling2d (MaxPooling2D)    (None, 128, 128, 64) 0           activation[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 128, 128, 128 73856       max_pooling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 128, 128, 128 147584      conv2d_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_1 (BatchNor (None, 128, 128, 128 512         conv2d_3[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, 128, 128, 128 0           batch_normalization_1[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, 64, 64, 128)  0           activation_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 64, 64, 256)  295168      max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 64, 64, 256)  590080      conv2d_4[0][0]
# __________________________________________________________________________________________________
# batch_normalization_2 (BatchNor (None, 64, 64, 256)  1024        conv2d_5[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, 64, 64, 256)  0           batch_normalization_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, 32, 32, 256)  0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 32, 32, 512)  1180160     max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 32, 32, 512)  2359808     conv2d_6[0][0]
# __________________________________________________________________________________________________
# batch_normalization_3 (BatchNor (None, 32, 32, 512)  2048        conv2d_7[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, 32, 32, 512)  0           batch_normalization_3[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 16, 16, 512)  0           activation_3[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 16, 16, 1024) 4719616     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 16, 16, 1024) 9438208     conv2d_8[0][0]
# __________________________________________________________________________________________________
# batch_normalization_4 (BatchNor (None, 16, 16, 1024) 4096        conv2d_9[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, 16, 16, 1024) 0           batch_normalization_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 32, 32, 1024) 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 32, 32, 512)  2097664     up_sampling2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 32, 32, 1024) 0           conv2d_7[0][0]
#                                                                  conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 32, 32, 512)  4719104     concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 32, 32, 512)  2359808     conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 32, 32, 512)  2048        conv2d_12[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, 32, 32, 512)  0           batch_normalization_5[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 512)  0           activation_5[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 64, 64, 256)  524544      up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 64, 64, 512)  0           conv2d_5[0][0]
#                                                                  conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 64, 64, 256)  1179904     concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 64, 64, 256)  590080      conv2d_14[0][0]
# __________________________________________________________________________________________________
# batch_normalization_6 (BatchNor (None, 64, 64, 256)  1024        conv2d_15[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, 64, 64, 256)  0           batch_normalization_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 256 0           activation_6[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 131200      up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 128, 128, 256 0           conv2d_3[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 128 295040      concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 128 147584      conv2d_17[0][0]
# __________________________________________________________________________________________________
# batch_normalization_7 (BatchNor (None, 128, 128, 128 512         conv2d_18[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, 128, 128, 128 0           batch_normalization_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 128 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 256, 256, 64) 32832       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 256, 256, 128 0           conv2d_1[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 256, 256, 64) 73792       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 256, 256, 64) 36928       conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 256, 256, 2)  1154        conv2d_21[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 256, 256, 2)  8           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, 256, 256, 2)  0           batch_normalization_8[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 256, 256, 1)  3           activation_8[0][0]
# ==================================================================================================
# Total params: 31,044,365
# Trainable params: 31,038,601
# Non-trainable params: 5,764
# __________________________________________________________________________________________________

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">UNet Model architecture</span> <a id=5></a>

# %%
plot_model(model, to_file='unet_model.png', show_shapes=True)
Image("unet_model.png")

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Callbacks</span> <a id=5.1></a> <br>
#
# The Callbacks used are
# * Learning Rate reduction
# * Early Stopping
# * Model Checkpoint

# %%
lr_reduction = ReduceLROnPlateau(monitor='val_iou',patience=8, verbose=1,
                                 factor=0.4, min_lr=0.0001)

early_stop = EarlyStopping(monitor='val_iou', min_delta=0.00001, patience=6, 
                           mode='auto', restore_best_weights=True)

model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', verbose=1,monitor='val_iou',
                                   save_best_only=True)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Performance Metrics</span> <a id=5.2></a>

# %%
smooth =100
def iou(y_true, y_pred):
    intersection = K.sum(y_true * y_pred)
    sum_ = K.sum(y_true + y_pred)
    jac = (intersection + smooth) / (sum_ - intersection + smooth)
    return jac

# %%
def dice_coef(y_true, y_pred):
    y_truef=K.flatten(y_true)
    y_predf=K.flatten(y_pred)
    And=K.sum(y_truef* y_predf)
    return((2* And + smooth) / (K.sum(y_truef) + K.sum(y_predf) + smooth))

def dice_coef_loss(y_true, y_pred):
    return 1-dice_coef(y_true, y_pred)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Model Fit</span> <a id=5.3></a>

# %%
EPOCH = 100
learning_rate = 1e-3

# %%
model.compile(optimizer=Adam(learning_rate=1e-3, beta_1=0.9, beta_2=0.999, epsilon=None, decay=1e-3/32, amsgrad=False), 
              loss=dice_coef_loss, metrics=["binary_accuracy", iou, dice_coef])

# %%
history = model.fit(train_gen,steps_per_epoch=len(mri_train)/32,
                    epochs=EPOCH ,validation_data=val_gen,validation_steps=len(mri_val) / 32,
                    callbacks=[model_checkpoint])
# Out:
# Found 2828 validated image filenames.
# Found 2828 validated image filenames.
# 2022-10-27 19:44:31.608653: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/100
# 2022-10-27 19:44:34.831486: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 2022-10-27 19:44:49.470358: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 1.02GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-27 19:44:49.551564: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2022-10-27 19:44:49.707328: W tensorflow/core/common_runtime/bfc_allocator.cc:272] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.39GiB with freed_by_count=0. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 89/88 [==============================] - ETA: 0s - loss: 0.9533 - binary_accuracy: 0.8912 - iou: 0.0242 - dice_coef: 0.0470Found 708 validated image filenames.
# Found 708 validated image filenames.
# 88/88 [==============================] - 139s 1s/step - loss: 0.9533 - binary_accuracy: 0.8912 - iou: 0.0242 - dice_coef: 0.0470 - val_loss: 0.9780 - val_binary_accuracy: 0.8405 - val_iou: 0.0118 - val_dice_coef: 0.0232
#
# Epoch 00001: val_iou improved from inf to 0.01183, saving model to unet_membrane.hdf5
# Epoch 2/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.9439 - binary_accuracy: 0.9468 - iou: 0.0290 - dice_coef: 0.0561 - val_loss: 0.9262 - val_binary_accuracy: 0.9111 - val_iou: 0.0398 - val_dice_coef: 0.0762
#
# Epoch 00002: val_iou did not improve from 0.01183
# Epoch 3/100
# 88/88 [==============================] - 101s 1s/step - loss: 0.9327 - binary_accuracy: 0.9596 - iou: 0.0350 - dice_coef: 0.0672 - val_loss: 0.9167 - val_binary_accuracy: 0.9490 - val_iou: 0.0423 - val_dice_coef: 0.0802
#
# Epoch 00003: val_iou did not improve from 0.01183
# Epoch 4/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.9557 - binary_accuracy: 0.8273 - iou: 0.0227 - dice_coef: 0.0442 - val_loss: 0.9015 - val_binary_accuracy: 0.9277 - val_iou: 0.0502 - val_dice_coef: 0.0948
#
# Epoch 00004: val_iou did not improve from 0.01183
# Epoch 5/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.9115 - binary_accuracy: 0.9506 - iou: 0.0471 - dice_coef: 0.0893 - val_loss: 0.9033 - val_binary_accuracy: 0.9085 - val_iou: 0.0492 - val_dice_coef: 0.0931
#
# Epoch 00005: val_iou did not improve from 0.01183
# Epoch 6/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.8754 - binary_accuracy: 0.9749 - iou: 0.0671 - dice_coef: 0.1248 - val_loss: 0.7593 - val_binary_accuracy: 0.9830 - val_iou: 0.1416 - val_dice_coef: 0.2455
#
# Epoch 00006: val_iou did not improve from 0.01183
# Epoch 7/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.8239 - binary_accuracy: 0.9830 - iou: 0.0980 - dice_coef: 0.1761 - val_loss: 0.6602 - val_binary_accuracy: 0.9751 - val_iou: 0.2025 - val_dice_coef: 0.3288
#
# Epoch 00007: val_iou did not improve from 0.01183
# Epoch 8/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.7405 - binary_accuracy: 0.9877 - iou: 0.1517 - dice_coef: 0.2587 - val_loss: 0.4950 - val_binary_accuracy: 0.9929 - val_iou: 0.3372 - val_dice_coef: 0.4902
#
# Epoch 00008: val_iou did not improve from 0.01183
# Epoch 9/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.6343 - binary_accuracy: 0.9915 - iou: 0.2290 - dice_coef: 0.3664 - val_loss: 0.4163 - val_binary_accuracy: 0.9934 - val_iou: 0.4089 - val_dice_coef: 0.5674
#
# Epoch 00009: val_iou did not improve from 0.01183
# Epoch 10/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.5406 - binary_accuracy: 0.9928 - iou: 0.3058 - dice_coef: 0.4612 - val_loss: 0.7803 - val_binary_accuracy: 0.9939 - val_iou: 0.1207 - val_dice_coef: 0.2121
#
# Epoch 00010: val_iou did not improve from 0.01183
# Epoch 11/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.4733 - binary_accuracy: 0.9935 - iou: 0.3657 - dice_coef: 0.5275 - val_loss: 0.8019 - val_binary_accuracy: 0.9936 - val_iou: 0.1166 - val_dice_coef: 0.2045
#
# Epoch 00011: val_iou did not improve from 0.01183
# Epoch 12/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.4304 - binary_accuracy: 0.9940 - iou: 0.4080 - dice_coef: 0.5691 - val_loss: 0.6050 - val_binary_accuracy: 0.9933 - val_iou: 0.2457 - val_dice_coef: 0.3810
#
# Epoch 00012: val_iou did not improve from 0.01183
# Epoch 13/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.4149 - binary_accuracy: 0.9935 - iou: 0.4211 - dice_coef: 0.5854 - val_loss: 0.9313 - val_binary_accuracy: 0.9932 - val_iou: 0.0345 - val_dice_coef: 0.0662
#
# Epoch 00013: val_iou did not improve from 0.01183
# Epoch 14/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.3802 - binary_accuracy: 0.9944 - iou: 0.4611 - dice_coef: 0.6207 - val_loss: 0.6585 - val_binary_accuracy: 0.9925 - val_iou: 0.2247 - val_dice_coef: 0.3522
#
# Epoch 00014: val_iou did not improve from 0.01183
# Epoch 15/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.3440 - binary_accuracy: 0.9950 - iou: 0.4950 - dice_coef: 0.6532 - val_loss: 0.3455 - val_binary_accuracy: 0.9950 - val_iou: 0.5003 - val_dice_coef: 0.6618
#
# Epoch 00015: val_iou did not improve from 0.01183
# Epoch 16/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.3220 - binary_accuracy: 0.9953 - iou: 0.5217 - dice_coef: 0.6788 - val_loss: 0.4360 - val_binary_accuracy: 0.9947 - val_iou: 0.3977 - val_dice_coef: 0.5597
#
# Epoch 00016: val_iou did not improve from 0.01183
# Epoch 17/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.3033 - binary_accuracy: 0.9954 - iou: 0.5434 - dice_coef: 0.6974 - val_loss: 0.3589 - val_binary_accuracy: 0.9950 - val_iou: 0.4639 - val_dice_coef: 0.6183
#
# Epoch 00017: val_iou did not improve from 0.01183
# Epoch 18/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2957 - binary_accuracy: 0.9956 - iou: 0.5523 - dice_coef: 0.7052 - val_loss: 0.3471 - val_binary_accuracy: 0.9953 - val_iou: 0.5013 - val_dice_coef: 0.6590
#
# Epoch 00018: val_iou did not improve from 0.01183
# Epoch 19/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2648 - binary_accuracy: 0.9959 - iou: 0.5882 - dice_coef: 0.7358 - val_loss: 0.3170 - val_binary_accuracy: 0.9957 - val_iou: 0.5291 - val_dice_coef: 0.6849
#
# Epoch 00019: val_iou did not improve from 0.01183
# Epoch 20/100
# 88/88 [==============================] - 101s 1s/step - loss: 0.2737 - binary_accuracy: 0.9958 - iou: 0.5778 - dice_coef: 0.7269 - val_loss: 0.2666 - val_binary_accuracy: 0.9953 - val_iou: 0.5768 - val_dice_coef: 0.7253
#
# Epoch 00020: val_iou did not improve from 0.01183
# Epoch 21/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2666 - binary_accuracy: 0.9960 - iou: 0.5910 - dice_coef: 0.7343 - val_loss: 0.2831 - val_binary_accuracy: 0.9950 - val_iou: 0.5549 - val_dice_coef: 0.7094
#
# Epoch 00021: val_iou did not improve from 0.01183
# Epoch 22/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2463 - binary_accuracy: 0.9963 - iou: 0.6121 - dice_coef: 0.7545 - val_loss: 0.3135 - val_binary_accuracy: 0.9954 - val_iou: 0.5158 - val_dice_coef: 0.6636
#
# Epoch 00022: val_iou did not improve from 0.01183
# Epoch 23/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2459 - binary_accuracy: 0.9958 - iou: 0.6094 - dice_coef: 0.7489 - val_loss: 0.2494 - val_binary_accuracy: 0.9960 - val_iou: 0.6111 - val_dice_coef: 0.7527
#
# Epoch 00023: val_iou did not improve from 0.01183
# Epoch 24/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2401 - binary_accuracy: 0.9963 - iou: 0.6207 - dice_coef: 0.7602 - val_loss: 0.3057 - val_binary_accuracy: 0.9943 - val_iou: 0.5389 - val_dice_coef: 0.6958
#
# Epoch 00024: val_iou did not improve from 0.01183
# Epoch 25/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2264 - binary_accuracy: 0.9965 - iou: 0.6365 - dice_coef: 0.7738 - val_loss: 0.2289 - val_binary_accuracy: 0.9962 - val_iou: 0.6136 - val_dice_coef: 0.7487
#
# Epoch 00025: val_iou did not improve from 0.01183
# Epoch 26/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2345 - binary_accuracy: 0.9963 - iou: 0.6257 - dice_coef: 0.7651 - val_loss: 0.2680 - val_binary_accuracy: 0.9956 - val_iou: 0.5739 - val_dice_coef: 0.7151
#
# Epoch 00026: val_iou did not improve from 0.01183
# Epoch 27/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2208 - binary_accuracy: 0.9965 - iou: 0.6458 - dice_coef: 0.7789 - val_loss: 0.2822 - val_binary_accuracy: 0.9956 - val_iou: 0.5835 - val_dice_coef: 0.7223
#
# Epoch 00027: val_iou did not improve from 0.01183
# Epoch 28/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2142 - binary_accuracy: 0.9965 - iou: 0.6530 - dice_coef: 0.7865 - val_loss: 0.2015 - val_binary_accuracy: 0.9967 - val_iou: 0.6737 - val_dice_coef: 0.8007
#
# Epoch 00028: val_iou did not improve from 0.01183
# Epoch 29/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1978 - binary_accuracy: 0.9969 - iou: 0.6754 - dice_coef: 0.8026 - val_loss: 0.2234 - val_binary_accuracy: 0.9967 - val_iou: 0.6304 - val_dice_coef: 0.7590
#
# Epoch 00029: val_iou did not improve from 0.01183
# Epoch 30/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2032 - binary_accuracy: 0.9967 - iou: 0.6672 - dice_coef: 0.7970 - val_loss: 0.2109 - val_binary_accuracy: 0.9968 - val_iou: 0.6444 - val_dice_coef: 0.7723
#
# Epoch 00030: val_iou did not improve from 0.01183
# Epoch 31/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1959 - binary_accuracy: 0.9968 - iou: 0.6774 - dice_coef: 0.8036 - val_loss: 0.2418 - val_binary_accuracy: 0.9961 - val_iou: 0.6059 - val_dice_coef: 0.7449
#
# Epoch 00031: val_iou did not improve from 0.01183
# Epoch 32/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2059 - binary_accuracy: 0.9967 - iou: 0.6636 - dice_coef: 0.7914 - val_loss: 0.2283 - val_binary_accuracy: 0.9960 - val_iou: 0.6231 - val_dice_coef: 0.7622
#
# Epoch 00032: val_iou did not improve from 0.01183
# Epoch 33/100
# 88/88 [==============================] - 101s 1s/step - loss: 0.1971 - binary_accuracy: 0.9969 - iou: 0.6777 - dice_coef: 0.8028 - val_loss: 0.1982 - val_binary_accuracy: 0.9972 - val_iou: 0.6638 - val_dice_coef: 0.7850
#
# Epoch 00033: val_iou did not improve from 0.01183
# Epoch 34/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1856 - binary_accuracy: 0.9971 - iou: 0.6934 - dice_coef: 0.8150 - val_loss: 0.1813 - val_binary_accuracy: 0.9969 - val_iou: 0.6761 - val_dice_coef: 0.7917
#
# Epoch 00034: val_iou did not improve from 0.01183
# Epoch 35/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1760 - binary_accuracy: 0.9972 - iou: 0.7036 - dice_coef: 0.8230 - val_loss: 0.1964 - val_binary_accuracy: 0.9969 - val_iou: 0.6828 - val_dice_coef: 0.8077
#
# Epoch 00035: val_iou did not improve from 0.01183
# Epoch 36/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1940 - binary_accuracy: 0.9969 - iou: 0.6831 - dice_coef: 0.8064 - val_loss: 0.2109 - val_binary_accuracy: 0.9962 - val_iou: 0.6658 - val_dice_coef: 0.7931
#
# Epoch 00036: val_iou did not improve from 0.01183
# Epoch 37/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1990 - binary_accuracy: 0.9967 - iou: 0.6772 - dice_coef: 0.8018 - val_loss: 0.2298 - val_binary_accuracy: 0.9951 - val_iou: 0.6393 - val_dice_coef: 0.7751
#
# Epoch 00037: val_iou did not improve from 0.01183
# Epoch 38/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1977 - binary_accuracy: 0.9967 - iou: 0.6776 - dice_coef: 0.8024 - val_loss: 0.1910 - val_binary_accuracy: 0.9966 - val_iou: 0.6863 - val_dice_coef: 0.8106
#
# Epoch 00038: val_iou did not improve from 0.01183
# Epoch 39/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1758 - binary_accuracy: 0.9970 - iou: 0.7069 - dice_coef: 0.8247 - val_loss: 0.1743 - val_binary_accuracy: 0.9973 - val_iou: 0.7124 - val_dice_coef: 0.8295
#
# Epoch 00039: val_iou did not improve from 0.01183
# Epoch 40/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1697 - binary_accuracy: 0.9972 - iou: 0.7140 - dice_coef: 0.8301 - val_loss: 0.1601 - val_binary_accuracy: 0.9970 - val_iou: 0.7319 - val_dice_coef: 0.8430
#
# Epoch 00040: val_iou did not improve from 0.01183
# Epoch 41/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1543 - binary_accuracy: 0.9974 - iou: 0.7369 - dice_coef: 0.8462 - val_loss: 0.1717 - val_binary_accuracy: 0.9970 - val_iou: 0.7153 - val_dice_coef: 0.8311
#
# Epoch 00041: val_iou did not improve from 0.01183
# Epoch 42/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1582 - binary_accuracy: 0.9974 - iou: 0.7334 - dice_coef: 0.8422 - val_loss: 0.1614 - val_binary_accuracy: 0.9973 - val_iou: 0.7281 - val_dice_coef: 0.8396
#
# Epoch 00042: val_iou did not improve from 0.01183
# Epoch 43/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.9437 - binary_accuracy: 0.9465 - iou: 0.0300 - dice_coef: 0.0562 - val_loss: 0.8054 - val_binary_accuracy: 0.9236 - val_iou: 0.1111 - val_dice_coef: 0.1979
#
# Epoch 00043: val_iou did not improve from 0.01183
# Epoch 44/100
# 88/88 [==============================] - 101s 1s/step - loss: 0.2580 - binary_accuracy: 0.9895 - iou: 0.6228 - dice_coef: 0.7419 - val_loss: 0.1978 - val_binary_accuracy: 0.9966 - val_iou: 0.6645 - val_dice_coef: 0.7951
#
# Epoch 00044: val_iou did not improve from 0.01183
# Epoch 45/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1782 - binary_accuracy: 0.9970 - iou: 0.7072 - dice_coef: 0.8206 - val_loss: 0.2210 - val_binary_accuracy: 0.9961 - val_iou: 0.6396 - val_dice_coef: 0.7761
#
# Epoch 00045: val_iou did not improve from 0.01183
# Epoch 46/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1684 - binary_accuracy: 0.9971 - iou: 0.7176 - dice_coef: 0.8310 - val_loss: 0.2029 - val_binary_accuracy: 0.9965 - val_iou: 0.6472 - val_dice_coef: 0.7690
#
# Epoch 00046: val_iou did not improve from 0.01183
# Epoch 47/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1748 - binary_accuracy: 0.9970 - iou: 0.7106 - dice_coef: 0.8257 - val_loss: 0.1921 - val_binary_accuracy: 0.9966 - val_iou: 0.6834 - val_dice_coef: 0.8072
#
# Epoch 00047: val_iou did not improve from 0.01183
# Epoch 48/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1625 - binary_accuracy: 0.9973 - iou: 0.7287 - dice_coef: 0.8371 - val_loss: 0.1626 - val_binary_accuracy: 0.9972 - val_iou: 0.7297 - val_dice_coef: 0.8415
#
# Epoch 00048: val_iou did not improve from 0.01183
# Epoch 49/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1559 - binary_accuracy: 0.9973 - iou: 0.7363 - dice_coef: 0.8440 - val_loss: 0.1574 - val_binary_accuracy: 0.9971 - val_iou: 0.7323 - val_dice_coef: 0.8436
#
# Epoch 00049: val_iou did not improve from 0.01183
# Epoch 50/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1521 - binary_accuracy: 0.9974 - iou: 0.7420 - dice_coef: 0.8475 - val_loss: 0.1605 - val_binary_accuracy: 0.9971 - val_iou: 0.7300 - val_dice_coef: 0.8421
#
# Epoch 00050: val_iou did not improve from 0.01183
# Epoch 51/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1622 - binary_accuracy: 0.9972 - iou: 0.7250 - dice_coef: 0.8371 - val_loss: 0.1716 - val_binary_accuracy: 0.9973 - val_iou: 0.6892 - val_dice_coef: 0.7989
#
# Epoch 00051: val_iou did not improve from 0.01183
# Epoch 52/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.9444 - binary_accuracy: 0.9815 - iou: 0.0312 - dice_coef: 0.0552 - val_loss: 0.2008 - val_binary_accuracy: 0.9959 - val_iou: 0.6722 - val_dice_coef: 0.8013
#
# Epoch 00052: val_iou did not improve from 0.01183
# Epoch 53/100
# 88/88 [==============================] - 101s 1s/step - loss: 0.1674 - binary_accuracy: 0.9971 - iou: 0.7183 - dice_coef: 0.8332 - val_loss: 0.4529 - val_binary_accuracy: 0.9851 - val_iou: 0.3962 - val_dice_coef: 0.5557
#
# Epoch 00053: val_iou did not improve from 0.01183
# Epoch 54/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1813 - binary_accuracy: 0.9969 - iou: 0.7007 - dice_coef: 0.8191 - val_loss: 0.1812 - val_binary_accuracy: 0.9969 - val_iou: 0.7034 - val_dice_coef: 0.8231
#
# Epoch 00054: val_iou did not improve from 0.01183
# Epoch 55/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1553 - binary_accuracy: 0.9973 - iou: 0.7384 - dice_coef: 0.8448 - val_loss: 0.1718 - val_binary_accuracy: 0.9969 - val_iou: 0.7169 - val_dice_coef: 0.8325
#
# Epoch 00055: val_iou did not improve from 0.01183
# Epoch 56/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1459 - binary_accuracy: 0.9975 - iou: 0.7495 - dice_coef: 0.8544 - val_loss: 0.1704 - val_binary_accuracy: 0.9969 - val_iou: 0.7154 - val_dice_coef: 0.8313
#
# Epoch 00056: val_iou did not improve from 0.01183
# Epoch 57/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.9508 - binary_accuracy: 0.9742 - iou: 0.0270 - dice_coef: 0.0498 - val_loss: 0.6694 - val_binary_accuracy: 0.9645 - val_iou: 0.2014 - val_dice_coef: 0.3296
#
# Epoch 00057: val_iou did not improve from 0.01183
# Epoch 58/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.2440 - binary_accuracy: 0.9929 - iou: 0.6370 - dice_coef: 0.7562 - val_loss: 0.1865 - val_binary_accuracy: 0.9965 - val_iou: 0.6915 - val_dice_coef: 0.8144
#
# Epoch 00058: val_iou did not improve from 0.01183
# Epoch 59/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1534 - binary_accuracy: 0.9973 - iou: 0.7395 - dice_coef: 0.8468 - val_loss: 0.1573 - val_binary_accuracy: 0.9970 - val_iou: 0.7283 - val_dice_coef: 0.8387
#
# Epoch 00059: val_iou did not improve from 0.01183
# Epoch 60/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1470 - binary_accuracy: 0.9974 - iou: 0.7519 - dice_coef: 0.8534 - val_loss: 0.1389 - val_binary_accuracy: 0.9976 - val_iou: 0.7655 - val_dice_coef: 0.8649
#
# Epoch 00060: val_iou did not improve from 0.01183
# Epoch 61/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1514 - binary_accuracy: 0.9973 - iou: 0.7430 - dice_coef: 0.8479 - val_loss: 0.1908 - val_binary_accuracy: 0.9960 - val_iou: 0.6840 - val_dice_coef: 0.8041
#
# Epoch 00061: val_iou did not improve from 0.01183
# Epoch 62/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1476 - binary_accuracy: 0.9975 - iou: 0.7492 - dice_coef: 0.8526 - val_loss: 0.1529 - val_binary_accuracy: 0.9973 - val_iou: 0.7254 - val_dice_coef: 0.8360
#
# Epoch 00062: val_iou did not improve from 0.01183
# Epoch 63/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1425 - binary_accuracy: 0.9975 - iou: 0.7547 - dice_coef: 0.8578 - val_loss: 0.1655 - val_binary_accuracy: 0.9971 - val_iou: 0.7015 - val_dice_coef: 0.8093
#
# Epoch 00063: val_iou did not improve from 0.01183
# Epoch 64/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.9462 - binary_accuracy: 0.9665 - iou: 0.0295 - dice_coef: 0.0545 - val_loss: 0.4695 - val_binary_accuracy: 0.9827 - val_iou: 0.3807 - val_dice_coef: 0.5413
#
# Epoch 00064: val_iou did not improve from 0.01183
# Epoch 65/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1875 - binary_accuracy: 0.9954 - iou: 0.7014 - dice_coef: 0.8134 - val_loss: 0.1618 - val_binary_accuracy: 0.9973 - val_iou: 0.7241 - val_dice_coef: 0.8309
#
# Epoch 00065: val_iou did not improve from 0.01183
# Epoch 66/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1437 - binary_accuracy: 0.9975 - iou: 0.7504 - dice_coef: 0.8507 - val_loss: 0.1510 - val_binary_accuracy: 0.9971 - val_iou: 0.7423 - val_dice_coef: 0.8498
#
# Epoch 00066: val_iou did not improve from 0.01183
# Epoch 67/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1410 - binary_accuracy: 0.9974 - iou: 0.7589 - dice_coef: 0.8593 - val_loss: 0.1475 - val_binary_accuracy: 0.9971 - val_iou: 0.7447 - val_dice_coef: 0.8453
#
# Epoch 00067: val_iou did not improve from 0.01183
# Epoch 68/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1433 - binary_accuracy: 0.9974 - iou: 0.7551 - dice_coef: 0.8563 - val_loss: 0.2013 - val_binary_accuracy: 0.9965 - val_iou: 0.6740 - val_dice_coef: 0.8009
#
# Epoch 00068: val_iou did not improve from 0.01183
# Epoch 69/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1342 - binary_accuracy: 0.9977 - iou: 0.7689 - dice_coef: 0.8662 - val_loss: 0.1400 - val_binary_accuracy: 0.9973 - val_iou: 0.7575 - val_dice_coef: 0.8604
#
# Epoch 00069: val_iou did not improve from 0.01183
# Epoch 70/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1351 - binary_accuracy: 0.9975 - iou: 0.7669 - dice_coef: 0.8644 - val_loss: 0.1453 - val_binary_accuracy: 0.9973 - val_iou: 0.7585 - val_dice_coef: 0.8589
#
# Epoch 00070: val_iou did not improve from 0.01183
# Epoch 71/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1344 - binary_accuracy: 0.9975 - iou: 0.7679 - dice_coef: 0.8659 - val_loss: 0.1468 - val_binary_accuracy: 0.9971 - val_iou: 0.7548 - val_dice_coef: 0.8570
#
# Epoch 00071: val_iou did not improve from 0.01183
# Epoch 72/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1344 - binary_accuracy: 0.9976 - iou: 0.7695 - dice_coef: 0.8660 - val_loss: 0.1532 - val_binary_accuracy: 0.9970 - val_iou: 0.7366 - val_dice_coef: 0.8452
#
# Epoch 00072: val_iou did not improve from 0.01183
# Epoch 73/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1297 - binary_accuracy: 0.9977 - iou: 0.7732 - dice_coef: 0.8696 - val_loss: 0.1324 - val_binary_accuracy: 0.9974 - val_iou: 0.7710 - val_dice_coef: 0.8691
#
# Epoch 00073: val_iou did not improve from 0.01183
# Epoch 74/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1297 - binary_accuracy: 0.9975 - iou: 0.7789 - dice_coef: 0.8708 - val_loss: 0.1472 - val_binary_accuracy: 0.9975 - val_iou: 0.7478 - val_dice_coef: 0.8479
#
# Epoch 00074: val_iou did not improve from 0.01183
# Epoch 75/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1339 - binary_accuracy: 0.9976 - iou: 0.7694 - dice_coef: 0.8664 - val_loss: 0.1461 - val_binary_accuracy: 0.9973 - val_iou: 0.7529 - val_dice_coef: 0.8551
#
# Epoch 00075: val_iou did not improve from 0.01183
# Epoch 76/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.9549 - binary_accuracy: 0.9794 - iou: 0.0247 - dice_coef: 0.0448 - val_loss: 0.2453 - val_binary_accuracy: 0.9946 - val_iou: 0.6141 - val_dice_coef: 0.7573
#
# Epoch 00076: val_iou did not improve from 0.01183
# Epoch 77/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1481 - binary_accuracy: 0.9974 - iou: 0.7478 - dice_coef: 0.8519 - val_loss: 0.1919 - val_binary_accuracy: 0.9965 - val_iou: 0.6863 - val_dice_coef: 0.8053
#
# Epoch 00077: val_iou did not improve from 0.01183
# Epoch 78/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1429 - binary_accuracy: 0.9975 - iou: 0.7594 - dice_coef: 0.8576 - val_loss: 0.1499 - val_binary_accuracy: 0.9972 - val_iou: 0.7432 - val_dice_coef: 0.8507
#
# Epoch 00078: val_iou did not improve from 0.01183
# Epoch 79/100
# 88/88 [==============================] - 99s 1s/step - loss: 0.1246 - binary_accuracy: 0.9977 - iou: 0.7811 - dice_coef: 0.8749 - val_loss: 0.1594 - val_binary_accuracy: 0.9973 - val_iou: 0.7339 - val_dice_coef: 0.8372
#
# Epoch 00079: val_iou did not improve from 0.01183
# Epoch 80/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1367 - binary_accuracy: 0.9976 - iou: 0.7661 - dice_coef: 0.8636 - val_loss: 0.1434 - val_binary_accuracy: 0.9970 - val_iou: 0.7547 - val_dice_coef: 0.8587
#
# Epoch 00080: val_iou did not improve from 0.01183
# Epoch 81/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1304 - binary_accuracy: 0.9977 - iou: 0.7738 - dice_coef: 0.8685 - val_loss: 0.1356 - val_binary_accuracy: 0.9976 - val_iou: 0.7695 - val_dice_coef: 0.8670
#
# Epoch 00081: val_iou did not improve from 0.01183
# Epoch 82/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1248 - binary_accuracy: 0.9977 - iou: 0.7812 - dice_coef: 0.8748 - val_loss: 0.1864 - val_binary_accuracy: 0.9967 - val_iou: 0.6947 - val_dice_coef: 0.8121
#
# Epoch 00082: val_iou did not improve from 0.01183
# Epoch 83/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1334 - binary_accuracy: 0.9975 - iou: 0.7706 - dice_coef: 0.8665 - val_loss: 0.1433 - val_binary_accuracy: 0.9972 - val_iou: 0.7518 - val_dice_coef: 0.8568
#
# Epoch 00083: val_iou did not improve from 0.01183
# Epoch 84/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1413 - binary_accuracy: 0.9974 - iou: 0.7583 - dice_coef: 0.8589 - val_loss: 0.1961 - val_binary_accuracy: 0.9969 - val_iou: 0.6659 - val_dice_coef: 0.7846
#
# Epoch 00084: val_iou did not improve from 0.01183
# Epoch 85/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1299 - binary_accuracy: 0.9977 - iou: 0.7752 - dice_coef: 0.8701 - val_loss: 0.3735 - val_binary_accuracy: 0.9941 - val_iou: 0.4808 - val_dice_coef: 0.6328
#
# Epoch 00085: val_iou did not improve from 0.01183
# Epoch 86/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.8254 - binary_accuracy: 0.9834 - iou: 0.1107 - dice_coef: 0.1736 - val_loss: 0.1802 - val_binary_accuracy: 0.9970 - val_iou: 0.6996 - val_dice_coef: 0.8178
#
# Epoch 00086: val_iou did not improve from 0.01183
# Epoch 87/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1350 - binary_accuracy: 0.9975 - iou: 0.7694 - dice_coef: 0.8653 - val_loss: 0.1217 - val_binary_accuracy: 0.9975 - val_iou: 0.7912 - val_dice_coef: 0.8815
#
# Epoch 00087: val_iou did not improve from 0.01183
# Epoch 88/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1285 - binary_accuracy: 0.9976 - iou: 0.7762 - dice_coef: 0.8716 - val_loss: 0.2224 - val_binary_accuracy: 0.9963 - val_iou: 0.6548 - val_dice_coef: 0.7841
#
# Epoch 00088: val_iou did not improve from 0.01183
# Epoch 89/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.9432 - binary_accuracy: 0.9563 - iou: 0.0306 - dice_coef: 0.0567 - val_loss: 0.4842 - val_binary_accuracy: 0.9846 - val_iou: 0.3521 - val_dice_coef: 0.5044
#
# Epoch 00089: val_iou did not improve from 0.01183
# Epoch 90/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.2010 - binary_accuracy: 0.9942 - iou: 0.6871 - dice_coef: 0.7996 - val_loss: 0.1608 - val_binary_accuracy: 0.9971 - val_iou: 0.7136 - val_dice_coef: 0.8185
#
# Epoch 00090: val_iou did not improve from 0.01183
# Epoch 91/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1290 - binary_accuracy: 0.9976 - iou: 0.7771 - dice_coef: 0.8711 - val_loss: 0.1396 - val_binary_accuracy: 0.9974 - val_iou: 0.7519 - val_dice_coef: 0.8555
#
# Epoch 00091: val_iou did not improve from 0.01183
# Epoch 92/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1305 - binary_accuracy: 0.9977 - iou: 0.7707 - dice_coef: 0.8655 - val_loss: 0.1557 - val_binary_accuracy: 0.9972 - val_iou: 0.7393 - val_dice_coef: 0.8472
#
# Epoch 00092: val_iou did not improve from 0.01183
# Epoch 93/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1281 - binary_accuracy: 0.9977 - iou: 0.7790 - dice_coef: 0.8721 - val_loss: 0.1386 - val_binary_accuracy: 0.9975 - val_iou: 0.7517 - val_dice_coef: 0.8524
#
# Epoch 00093: val_iou did not improve from 0.01183
# Epoch 94/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1234 - binary_accuracy: 0.9976 - iou: 0.7872 - dice_coef: 0.8762 - val_loss: 0.1322 - val_binary_accuracy: 0.9973 - val_iou: 0.7722 - val_dice_coef: 0.8703
#
# Epoch 00094: val_iou did not improve from 0.01183
# Epoch 95/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1252 - binary_accuracy: 0.9977 - iou: 0.7871 - dice_coef: 0.8752 - val_loss: 0.1550 - val_binary_accuracy: 0.9971 - val_iou: 0.7346 - val_dice_coef: 0.8445
#
# Epoch 00095: val_iou did not improve from 0.01183
# Epoch 96/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1263 - binary_accuracy: 0.9977 - iou: 0.7821 - dice_coef: 0.8741 - val_loss: 0.1407 - val_binary_accuracy: 0.9974 - val_iou: 0.7629 - val_dice_coef: 0.8617
#
# Epoch 00096: val_iou did not improve from 0.01183
# Epoch 97/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1194 - binary_accuracy: 0.9978 - iou: 0.7919 - dice_coef: 0.8809 - val_loss: 0.1171 - val_binary_accuracy: 0.9976 - val_iou: 0.7944 - val_dice_coef: 0.8815
#
# Epoch 00097: val_iou did not improve from 0.01183
# Epoch 98/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1205 - binary_accuracy: 0.9978 - iou: 0.7894 - dice_coef: 0.8796 - val_loss: 0.1854 - val_binary_accuracy: 0.9967 - val_iou: 0.6951 - val_dice_coef: 0.8156
#
# Epoch 00098: val_iou did not improve from 0.01183
# Epoch 99/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1190 - binary_accuracy: 0.9978 - iou: 0.7921 - dice_coef: 0.8811 - val_loss: 0.1317 - val_binary_accuracy: 0.9972 - val_iou: 0.7747 - val_dice_coef: 0.8712
#
# Epoch 00099: val_iou did not improve from 0.01183
# Epoch 100/100
# 88/88 [==============================] - 100s 1s/step - loss: 0.1137 - binary_accuracy: 0.9979 - iou: 0.7989 - dice_coef: 0.8859 - val_loss: 0.1210 - val_binary_accuracy: 0.9976 - val_iou: 0.7605 - val_dice_coef: 0.8464
#
# Epoch 00100: val_iou did not improve from 0.01183

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Save Model</span> <a id=5.4></a>

# %%
# !mkdir -p saved_model
model.save('saved_model/my_model.h5')

# %%
# saving model achitecture in json file
model_json = model.to_json()
with open("UNet-seg-model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Evaluation</span> <a id=6></a>
#
# Evaluation metrics are listed below

# %%
history.history.keys()
# Out:
# dict_keys(['loss', 'binary_accuracy', 'iou', 'dice_coef', 'val_loss', 'val_binary_accuracy', 'val_iou', 'val_dice_coef'])

# %% [markdown]
# **Loss function** :  IOU - Intersection over Union

# %% [markdown]
# ![Performance metric : Intersection over Union](data:image/png;base64,...)
#
# ![IOU](data:image/png;base64,...)

# %%
plt.figure(figsize=(12,5))
plt.subplot(1,2,1)
plt.plot(history.history['iou']);
plt.plot(history.history['val_iou']);
plt.title("Segmentation Model IOU Loss");
plt.ylabel("IOU loss");
plt.xlabel("Epochs");
plt.legend(['train', 'val']);

# %% [markdown]
# # <span class="list-group-item list-group-item-action active" style="color:#FF0000;background-color:white;font-size:25px">Prediction</span> <a id=7></a>

# %%
test_ids = list(mri_test.img_path)
test_mask = list(mri_test.mask_path)

# %%
def prediction(test, model_seg):
  
    # empty list to store results
    mask, image_id,has_mask = [], [], []
    
    #itetrating through each image in test data
    for i in test.img_path:
        

        
        #Creating a empty array of shape 1,256,256,1
        X = np.empty((1,256,256,3))
        # read the image
        img = io.imread(i)
        #resizing the image and coverting them to array of type float64
        img = cv2.resize(img, (256,256))
        img = np.array(img, dtype=np.float64)
        
        # standardising the image
        img -= img.mean()
        img /= img.std()
        #converting the shape of image from 256,256,3 to 1,256,256,3
        X[0,] = img
        
        #make prediction of mask
        predict = model_seg.predict(X)
        
        # if sum of predicted mask is 0 then there is not tumour
        if predict.round().astype(int).sum()==0:
            image_id.append(i)
            has_mask.append(0)
            mask.append('No mask :)')
        else:
        #if the sum of pixel values are more than 0, then there is tumour
            image_id.append(i)
            has_mask.append(1)
            mask.append(predict)
            
    return pd.DataFrame({'img_path': image_id,'predicted_mask': mask,'has_mask': has_mask})

# %%
df_pred = prediction(mri_test, model)
df_pred
# Out:
#                                               img_path  \
# 0    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4    /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# ..                                                 ...
# 388  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 389  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 390  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 391  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 392  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                         predicted_mask  has_mask
# 0                                           No mask :)         0
# 1                                           No mask :)         0
# 2                                           No mask :)         0
# 3    [[[[0.00783279], [0.00783279], [0.00783279], [...         1
# 4    [[[[0.00783279], [0.00783279], [0.00783279], [...         1
# ..                                                 ...       ...
# 388  [[[[0.00783279], [0.00783279], [0.00783279], [...         1
# 389                                         No mask :)         0
# 390                                         No mask :)         0
# 391                                         No mask :)         0
# 392                                         No mask :)         0
#
# [393 rows x 3 columns]

# %%
df_pred = mri_test.merge(df_pred, on='img_path')
df_pred.head()
# Out:
#                                             img_path  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...
#
#                                            mask_path  mask  \
# 0  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 1  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 2  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
# 3  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     1
# 4  /kaggle/input/lgg-mri-segmentation/kaggle_3m/T...     0
#
#                                       predicted_mask  has_mask
# 0                                         No mask :)         0
# 1                                         No mask :)         0
# 2                                         No mask :)         0
# 3  [[[[0.00783279], [0.00783279], [0.00783279], [...         1
# 4  [[[[0.00783279], [0.00783279], [0.00783279], [...         1

# %%
count = 0
fig, axs = plt.subplots(3,5, figsize=(30,15))

for i in range(len(df_pred)):
    if df_pred.has_mask[i]==1 and count<15:
        #read mri images
        img = io.imread(df_pred.img_path[i])
        img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
        axs[count][0].imshow(img)
        axs[count][0].title.set_text('Brain MRI')
        
        #read original mask
        mask = io.imread(df_pred.mask_path[i])
        axs[count][1].imshow(mask)
        axs[count][1].title.set_text('Ground Truth')
        
        #read predicted mask
        pred = np.array(df_pred.predicted_mask[i]).squeeze().round()
        axs[count][2].imshow(pred)
        axs[count][2].title.set_text('predicted mask')
        
        #overlay original mask with MRI
        img[mask==255] = (255,0,0)
        axs[count][3].imshow(img)
        axs[count][3].title.set_text('Brain MRI with original mask (Ground Truth)')
        
        #overlay predicted mask and MRI
        img_ = io.imread(df_pred.img_path[i])
        img_ = cv2.cvtColor(img_, cv2.COLOR_BGR2RGB)
        img_[pred==1] = (0,255,150)
        axs[count][4].imshow(img_)
        axs[count][4].title.set_text('MRI with PREDICTED MASK')
        
        count +=1
    if (count==3):
        break

fig.tight_layout()

# %% [markdown]
# **Reference:**
# * [UNet model Original creator Reference link](https://github.com/zhixuhao/unet)
# * [Kaggle Notebook - SAMUEL CORTINHAS](https://www.kaggle.com/code/samuelcortinhas/case-study-u-net-from-scratch#Application:-Tumor-detection)
